# %% [markdown]
# # Frequent Itemset Mining
# **Prepared by Christian Alis**

# %% [markdown]
# Frequent Itemset Mining is also known as Frequent Pattern Mining. In practice, we don't usually end with frequent itemset mining but instead continues on to association pattern mining.
#
# Frequent Itemset Mining and Association Pattern Mining (aka Association Rule Mining) were born out of market basket analysis. Hence, many of the terms used are relevant to that original problem.
#
# Consider a _database_ $\mathscr{T}$, which is an unordered set of $N$ transactions $\{T_1, T_2, ..., T_N\}$. Each transaction $T_i$ is a set of $n_i = \left|T_i\right|$ items drawn from a universe $\mathscr{U}$ of items. Instead of using a sequence of sets, we may represent $\mathscr{T}$ as a matrix of $d=\left|\mathscr{U}\right|$ dimensions where 0 represents the absence and, a positive number, the presence of the item in the transaction.
#
# In this notebook, we will only consider the presence of an item in a transaction and will ignore the actual amount (as long as it's nonzero, of course). Furthermore, in the real world, $d$ is large.
#
# The following is an example of a database:
#
# | tid |           items             |
# |-----|-----------------------------|
# |  1  | {bread, butter, milk}       |
# |  2  | {eggs, milk, yogurt}        |
# |  3  | {bread, cheese, eggs, milk} |
# |  4  | {eggs, milk, yogurt}        |
# |  5  | {cheese, milk, yogurt}      |
#
# In Python, we may represent the database as a list of sets, making use of the fact that the `tid` is sequential.

# %% [markdown]
# **Exercise 1**
#
# Give three examples of business problems that can be solved using Frequent Itemset Mining or Associative Pattern Mining.

# %% [markdown]
# 1. Choosing what to bundle in a supermarket
# 2. Recommending a course to a student. Assuming students choose what courses they will take. Assuming courses do not have precedence.
# 3. Detecting crimes from unusual patterns (least frequent "items")

# %%
import numpy as np
import pandas as pd
from scipy.sparse.csr import csr_matrix
from numpy.testing import assert_equal, assert_array_equal

# %%
db = [{"bread", "butter", "milk"},
      {"eggs", "milk", "yogurt"},
      {"bread", "cheese", "eggs", "milk"},
      {"eggs", "milk", "yogurt"},
      {"cheese", "milk", "yogurt"}]

# %% [markdown]
# We may also represent the database as a sparse matrix.

# %% [markdown]
# **Exercise 2**
#
# Create a function `to_sparse` that reads `db` and returns a numpy sparse matrix representation of the database. Sort the columns in alphabetical order.

# %%
def to_sparse(db):
    flat_list = [item for sublist in [list(x) for x in db] for item in sublist]
    db_list = [list(x) for x in db]
    sorted_items = sorted(list(set(flat_list)))
    zeros = np.zeros((len(db), len(sorted_items)))  
    for t, t_elem in enumerate(db_list):
        for elem in t_elem:
            zeros[t,sorted_items.index(elem)] = 1 
    return csr_matrix(zeros)

# %%
db_sparse = to_sparse(db)
assert isinstance(db_sparse, csr_matrix)
assert_equal(db_sparse.shape, (5, 6))
assert_array_equal(db_sparse[0,:].toarray().squeeze(), 
                   [1., 1., 0., 0., 1., 0.])

# %% [markdown]
# An **itemset** $X$ is a subset of items, $X \subseteq \mathscr{U}$. A length $k = |X|$ itemset is also known as a **$k$-itemset**. For example, the subset itemsets of {bread, butter, milk} are {bread}, {butter}, {milk}, {bread, butter}, {bread, milk}, {butter, milk}, {bread, butter, milk}. It consists of three 1-itemsets, three 2-itemsets and one 3-itemset.
#
# For our course, we define the **support** $sup(X)$ of an itemset $X$ as the number of transactions having $X$ as a subset,
# $$
# sup(X) = \left|{T_i|X \subseteq T_i}\right|.
# $$
# This is known as the **absolute support**. We define **relative support** $relSup(X)$ as the fraction of transactions having $X$ as a subset,
# $$
# relSup(X) = \frac{sup(X)}{N}.
# $$
# For many references and libraries, support is defined as the _relative_ support so be careful when reading or using other materials. It's quite easy to convert between absolute support and relative support, though. To illustrate, the (absolute) support for {bread, milk} is 2 and its relative support is $2/5=0.4$.
#
# We define **frequent itemsets** (or frequent patterns) as those itemsets that have a support at least equal to a given minimum support ($minsup$). The task of frequent itemset mining is to find all frequent itemsets in the database.
#
# In this notebook, we look at four methods for finding the frequent itemsets:
# * Brute force
# * Apriori
# * ECLAT
# * FP-growth

# %% [markdown]
# ## Brute force algorithm

# %% [markdown]
# The brute force approach to frequent itemset mining is to compute the support of each possible itemset of $\mathscr{U}$ then return only those itemsets whose support pass the threshold $minsup$.

# %% [markdown]
# **Exercise 3**
#
# Create a function `brute` that accepts `db` and `minsup` then returns the frequent itemsets as a list of tuples with their support using the brute force algorithm. Sort the items in each tuple alphabetically. Sort the results, first by decreasing support, then by decreasing number of items then alphabetically. Use only the Python Standard Library.

# %%
def brute(db, minsup):
    from itertools import combinations
    flat_list = [item for sublist in [list(x) for x in db] for item in sublist]
    sorted_items = sorted(list(set(flat_list)))
    li = []
    length = list(range(len(sorted_items),0,-1))
    for l in length:
        for i in combinations(sorted_items, l):
            count = 0
            for t in db:
                if set(i).issubset(t):
                    count += 1
            if count > 0:
                li.append((i, count))
    sorted_items_list = [(sorted(x), sup) for x,sup in li]
    nonzero_itemmsets = [(tuple(elem[0]), elem[1]) for elem in sorted(sorted_items_list, key=lambda x: (-x[1], -len(x[0]), x[0]))]
    return [itemmset for itemmset in nonzero_itemmsets if itemmset[1]>=minsup]

# %%
fi_brute = brute(db, 2)
assert_equal(len(fi_brute), 11)
assert_equal(fi_brute[0], (('milk',), 5))

# %% [markdown]
# Although it took you a few loops, the brute force algorithm is relatively simple. It doesn't scale well though.

# %% [markdown]
# **Exercise 4**
#
# Estimate the runtime for `brute`, relative to the runtime for the current case, when the number of items is 1000 but the number of transactions remains the same, and when the number of transactions is 1000 but the number of items remains the same.

# %% [markdown]
# The runtime would take a lot longer since the number of combinations of 1000 items is a lot compared to just 4 items.

# %% [markdown]
# ## Apriori algorithm (better for memory)
#
# - Not totally parallelizable
# - raw data can be split to different "workers", where each split needs a new adjusted absolute support (or just use rel support so no adjustment)

# %% [markdown]
# Clearly, generating all the possible itemsets from a universe of items could take a while. Coupled with scanning through the entire dataset for each possible itemset, the brute force algorithm is simply untenable for large databases. To make progress in making frequent itemset mining scalable, one should realize that generating the itemsets can be thought of as doing a search. Figure 1 shows the search space for a 5-item database.
#
#
# <img src="search-space.png" style="width: 25em"/>
# <strong>Figure 1</strong>. The $k$-th layer corresponds to the $k$-itemsets for the 5-item database. A line connects a $k$-itemset to a $(k+1)$-itemset generated by adding a unique item to the latter. The tree can be partitioned into frequent and infrequent itemsets using a border (blue broken line).
#
#
# We now introduce the following important properties of itemsets:
#
# * **Support monoticity property**: The support of every subset $Y$ of itemset $X$ is at least equal to that of the support for $X$, $sup(Y) \geq sup(X), \forall Y \subseteq X$.
# * **Downward closure property**: Every subset of a frequent itemset is also frequent.
# * **Maximal frequent itemsets**: A frequent itemset is maximal at a given minimum support $minsup$ if it is frequent and no superset of it is frequent.
#
# Using the properties above, what we can do is to perform a breadth-first search on the tree starting from the 1-itemsets, **we check whether the itemset is frequent and we only go deeper if it is**. This is the gist of the Apriori algorithm which we formally write down below.
#
# <img src="apriori.png" style="width: 40em" />
#
# An implication of the Apriori algorithm is that we would be able partition the search space by a border (Figure 1). The frequent itemsets along the border are the maximal frequent itemsets.

# %% [markdown]
# **Exercise 5**
#
# Create a function `apriori` that accepts `db` and `minsup` then returns the frequent itemsets as a list of tuples with their support using the Apriori algorithm. Sort the items in each tuple alphabetically. Sort the results, first by decreasing support, then by decreasing number of items then alphabetically. Use only the Python Standard Library.

# %%
def apriori(db, minsup):
    from itertools import combinations
    li = []
    flat_list = [item for sublist in [list(x) for x in db] for item in sublist]
    sorted_items = sorted(list(set(flat_list)))
    for l in range(1, len(sorted_items)+1):
        scope=[]
        for i in combinations(sorted_items, l):
            count=0
            for t in db:
                if set(i).issubset(t):
                    count+=1
            if count >= minsup:
                li.append((tuple(sorted(i)), count))
                scope.append(i)

        sorted_items = set([item for sublist in [list(x) for x in scope] for item in sublist])
    return sorted(li, key=lambda x: (-x[1], -len(x[0]), x[0]))

# %%
db
# Out:
# [{'bread', 'butter', 'milk'},
#  {'eggs', 'milk', 'yogurt'},
#  {'bread', 'cheese', 'eggs', 'milk'},
#  {'eggs', 'milk', 'yogurt'},
#  {'cheese', 'milk', 'yogurt'}]

# %%
fi_apriori = apriori(db, 2)
assert_equal(len(fi_apriori), 11)
assert_equal(fi_apriori[0], (('milk',), 5))

# %% [markdown]
# **Exercise 6**
#
# Create a function `apriori2` that accepts `db` and `minsup` then returns the maximal frequent itemsets as a list of tuples with their support using the Apriori algorithm. Sort the items in each tuple alphabetically. Sort the results, first by decreasing support, then by decreasing number of items then alphabetically. Use only the Python Standard Library.

# %%
def apriori2(db, minsup):
    from itertools import combinations
    li = []
    flat_list = [item for sublist in [list(x) for x in db] for item in sublist]
    
    sorted_items = sorted(list(set(flat_list)))
    maximal = []
    checker = []
    for l in range(1, len(sorted_items)+1):
        scope=[]
        for i in combinations(sorted_items, l):
            count=0
            for t in db:
                if set(i).issubset(t):
                    count+=1
            if count >= minsup:
                li.append((tuple(sorted(i)), count))
                scope.append(i)
        iter_set = [set(x) for x in scope]
        sorted_items = set([item for sublist in [list(x) for x in scope] for item in sublist])
#         print('-----------------------------------------')
#         print(f'list at iteration {l}\n:',iter_set)
#         print('-----')
#         print('checker:\n', checker)

        for set_ in checker:

            if not any([set_.issubset(i_iter) for i_iter in iter_set]):
                maximal.append(set_)
        checker = iter_set

#         print('new sorted items\n', sorted_items)

    apriori = sorted(li, key=lambda x: -x[1])
#     display(apriori)

    sorted_maximal = [tuple(sorted(m)) for m in maximal]
    return sorted([(x, dict(li)[x]) for x in sorted_maximal], key=lambda i: (-i[1], -len(i[0]), i[0]))

# %%
maxfi_apriori = apriori2(db, 2)
assert_equal(len(maxfi_apriori), 3)
assert_equal(maxfi_apriori[0], (('eggs', 'milk', 'yogurt'), 2))

# %%
maxfi_apriori
# Out:
# [(('eggs', 'milk', 'yogurt'), 2),
#  (('bread', 'milk'), 2),
#  (('cheese', 'milk'), 2)]

# %% [markdown]
# ## ECLAT (better for speed)
#
#  - not ideal to be parallelized since it will eat up a lot of resources
#
# A problem of the Apriori algorithm is that one has to scan the entire database to compute the support of each candidate itemset. Equivalence Class Clustering and Bottom-up Lattice Traversal (ECLAT) avoids this problem by using a vertical database, which is a database where the item is the key and the values are the set of `tid`s where it is found. To illustrate, the vertical database representation of the example horizontal database above is
#
# |  item  |       tids      |
# |--------|-----------------|
# | bread  | {1,3}           |
# | butter | {1}             |
# | milk   | {1, 2, 3, 4, 5} |
# | eggs   | {2, 3, 4}       |
# | yogurt | {2, 4, 5}       |
# | cheese | {3, 5}          |
#
# From the vertical database, the `tid` list of the itemset $X \cup Y$ is $tid(X \cup Y) = tid(X) \cap tid(Y)$. The support is simply $sup(X \cup Y) = |tid(X \cup Y)|$. Thus, the original horizontal database need not be scanned anymore as long as the vertical database is given.
#
# ECLAT performs one pass over the database to create the vertical database then performs a depth-first search using the vertical database. The algorithm is shown below.
#
# <img src="eclat.png" style="width: 40em" />

# %% [markdown]
# **Exercise 7**
#
# Create a function `eclat` that accepts `db` and `minsup` then returns the frequent itemsets as a list of tuples with their support using the ECLAT algorithm. Sort the items in each tuple alphabetically. Sort the results, first by decreasing support, then by decreasing number of items then alphabetically. Use only the Python Standard Library.

# %%
def eclat(db, minsup):
    from itertools import combinations
    flat_list = [item for sublist in [list(x) for x in db] for item in sublist]
    sorted_items = sorted(list(set(flat_list)))
    # print(sorted_items)
    dict_ = {}
    for item in sorted_items:
        li = []
        for index, t in enumerate(db):
    #         print(t)
            if item in t:
                li.append(index)
        if len(set(li)) >= minsup:
            dict_[item] = set(li)
    final_dict = {}
    final_dict.update(dict_)
    li_to_comb = dict_.keys()
    for l in range(2, len(db)):
        tempo_dict = {}
        for i in combinations(li_to_comb, l):
            if len(set.intersection(*[dict_[x] for x in i])) >= minsup:
    #             print(i, len(set.intersection(*[dict_[x] for x in i])))
                tempo_dict[i] = set.intersection(*[dict_[x] for x in i])
            final_dict.update(tempo_dict)
        li_to_comb = set([item for sublist in [list(x) for x in tempo_dict.keys()] for item in sublist])
        
#         print('li to comb', li_to_comb)

    return_dict = {k if isinstance(k, tuple) else (k,) : len(v) for k,v in final_dict.items()}
    return_tuple = sorted([(tuple(sorted(k)),v) for k,v in return_dict.items()], key=lambda x: (-x[1], -len(x[0]), x[0]))
    return return_tuple

# %%
fi_eclat = eclat(db, 2)
assert_equal(len(fi_eclat), 11)
assert_equal(fi_eclat[0], (('milk',), 5))

# %%
fi_eclat
# Out:
# [(('milk',), 5),
#  (('eggs', 'milk'), 3),
#  (('milk', 'yogurt'), 3),
#  (('eggs',), 3),
#  (('yogurt',), 3),
#  (('eggs', 'milk', 'yogurt'), 2),
#  (('bread', 'milk'), 2),
#  (('cheese', 'milk'), 2),
#  (('eggs', 'yogurt'), 2),
#  (('bread',), 2),
#  (('cheese',), 2)]

# %% [markdown]
# ## FP-Growth Algorithm
#
#  - slightly more efficient in candidate generation (faster)
#  - parallelizable
#  - yt vids that helped me : https://www.youtube.com/watch?v=VB8KWm8MXss&t=634s , https://www.youtube.com/watch?v=7oGz4PCp9jI

# %% [markdown]
# Although ECLAT improves the Apriori algorithm by avoiding multiple database scans, it still suffers from generating candidate itemsets that may not be in the database at all. FP-Growth, a pattern growth algorithm, avoids this problem by using projected databases.
#
# FP-Growth, like any other pattern growth algorithm, uses an enumeration tree. This algorithm employs a particular kind of enumeration known as a prefix tree. Assume that there's a defined lexicographical order among items i.e., items can be sorted. For example, if we define the lexicographical order as alphabetical, then {milk, cheese} will be transformed to {cheese, milk} after sorting. A prefix tree is a tree where each node is an item and a higher-level node can only be connected to a lower-level node of later order (Figure 2).
#
# <div style="width: 40em; margin: 0 auto">
#     <img src="prefix-tree.png" style="width: 25em" />
#     <strong>Figure 2</strong>. A higher-level prefix tree node can only be connected to a lower-level prefix tree node of later lexicographical order.
# </div>
#
# What FP-growth does is it recursively scans the database to find the frequent items (not itemsets) but instead of scanning the entire database, it will only scan the subset of the database that contains the prefix of the itemsets and with the prefix removed from the values. This is known as the projected database.
#
# To illustrate, FP-Growth will scan the database and finds that bread, with $minsup=2$, is a frequent itemset. The resulting projected database would then be:
#
# | tid |           items      |
# |-----|----------------------|
# |  1  | {butter, milk}       |
# |  3  | {cheese, eggs, milk} |
#
# The algorithm would repeat the process but scanning the projected database instead. It would find that butter has only a support of 1 hence {bread, butter} is not a frequent itemset. It would then look at the other items (cheese, eggs, milk, in order) but it would find that only milk has a support passing the $minsup$ threshold. Thus, it would add {bread, milk} as a frequent itemset. However, the resulting projected database is empty so it won't go deeper. Instead it would go up, back to the original dataset where it would find that butter is not a frequent itemset but cheese is so it would repeat the same process for the projected database of cheese and so on.
#
# The FP-growth algorithm is summarized below.
#
# <img src="fp-growth.png" style="width: 40em" />

# %% [markdown]
# **Exercise 8**
#
# Create a function `fpgrowth` that accepts `db` and `minsup` then returns the frequent itemsets as a list of tuples with their support using the FP-Growth algorithm. Sort the items in each tuple alphabetically. Sort the results, first by decreasing support, then by decreasing number of items then alphabetically. Use only the Python Standard Library.

# %%
def fpgrowth(db, minsup):
    minsup=2
    flat_list = [item for sublist in [list(x) for x in db] for item in sublist]

    from collections import Counter

    ### add to generated frequent itemsets
    to_add = sorted([(k,v) for k,v in Counter(flat_list).items() if v>=minsup], key=lambda x: (-x[1], x[0]))
    print('Frequent Items that met MinSup\n################')
    display(to_add)

    ### sort and filter transaction table using relevant items
    sorted_filtered=[sorted(itemset, key=lambda a: -dict(to_add)[a]) for itemset in [set([b[0] for b in to_add]).intersection(x) for x in db]]
    print('Sorted and Filtered Transaction table\n################')
    display(sorted_filtered)


    item_list = [x[0] for x in to_add][::-1]
    dict_ = {k:[] for k in item_list}

    for t in sorted_filtered:
        counter = Counter(t)

        for k in dict_:
            try:
                t.index(k)
            except:
                continue
            else:
                index_of_k = t.index(k)
                dict_[k].append({tuple(t[:index_of_k]):counter[k]})

    dict_ = {k:v for k,v in sorted(dict_.items(), key=lambda x: dict(to_add)[x[0]])}
    display(dict_)

    conditional_base ={}
    for k,v in dict_.items():
        final_dict = {}
        for elem in v:
            for key in elem.keys():

                if key in final_dict:
                    final_dict[key] = final_dict[key] + elem[key]
                else:
                    final_dict[key] = elem[key]

        conditional_base[k] = final_dict
    display(conditional_base)

    conditional_FP = {k:{} for k in conditional_base.keys()}
    for k,v in conditional_base.items():
        li = []
        for key in v.keys():
            for item in key:
                li.append(item)
        set_li = set(li)
        for x in set_li:
            count = 0
            for key in v.keys():
                if x in key:
                    count += v[key]
            if count >= minsup:
                conditional_FP[k][x] = count
    display(conditional_FP)    

    freq_itemset = []
    for k,v in conditional_FP.items():
        li = []
        for elem in v.keys():
            li.append(elem)
    #     print(li)

        from itertools import combinations
        for i in range(1, len(li)+1):
            for c in combinations(li,i):
    #             print(c)
                if len(c) > 1:
                    supp = min([v[a] for a in c])
                elif len(c) == 1:
                    supp = v[c[0]]

                list_ = list(c)
                list_.append(k)
                freq_itemset.append((tuple(list_), supp))
    print(freq_itemset,'\n')
    
   
    
    output = freq_itemset + [((x[0],), x[1]) for x in to_add]
    print('Final\n###################\n', sorted(output, key=lambda x: (-x[1], -len(x[0]), x[0])))
    return sorted(output, key=lambda x: (-x[1], -len(x[0]), x[0]))

# %%
db
# Out:
# [{'bread', 'butter', 'milk'},
#  {'eggs', 'milk', 'yogurt'},
#  {'bread', 'cheese', 'eggs', 'milk'},
#  {'eggs', 'milk', 'yogurt'},
#  {'cheese', 'milk', 'yogurt'}]

# %%
fi_fpgrowth = fpgrowth(db, 2)
assert_equal(len(fi_fpgrowth), 11)
assert_equal(fi_fpgrowth[0], (('milk',), 5))
# Out:
# Frequent Items that met MinSup
# ################
# [('milk', 5), ('eggs', 3), ('yogurt', 3), ('bread', 2), ('cheese', 2)]
# Sorted and Filtered Transaction table
# ################
# [['milk', 'bread'],
#  ['milk', 'yogurt', 'eggs'],
#  ['milk', 'eggs', 'bread', 'cheese'],
#  ['milk', 'yogurt', 'eggs'],
#  ['milk', 'yogurt', 'cheese']]
# {'cheese': [{('milk', 'eggs', 'bread'): 1}, {('milk', 'yogurt'): 1}],
#  'bread': [{('milk',): 1}, {('milk', 'eggs'): 1}],
#  'yogurt': [{('milk',): 1}, {('milk',): 1}, {('milk',): 1}],
#  'eggs': [{('milk', 'yogurt'): 1}, {('milk',): 1}, {('milk', 'yogurt'): 1}],
#  'milk': [{(): 1}, {(): 1}, {(): 1}, {(): 1}, {(): 1}]}
# {'cheese': {('milk', 'eggs', 'bread'): 1, ('milk', 'yogurt'): 1},
#  'bread': {('milk',): 1, ('milk', 'eggs'): 1},
#  'yogurt': {('milk',): 3},
#  'eggs': {('milk', 'yogurt'): 2, ('milk',): 1},
#  'milk': {(): 5}}
# {'cheese': {'milk': 2},
#  'bread': {'milk': 2},
#  'yogurt': {'milk': 3},
#  'eggs': {'milk': 3, 'yogurt': 2},
#  'milk': {}}
# [(('milk', 'cheese'), 2), (('milk', 'bread'), 2), (('milk', 'yogurt'), 3), (('milk', 'eggs'), 3), (('yogurt', 'eggs'), 2), (('milk', 'yogurt', 'eggs'), 2)]
#
# Final
# ###################
#  [(('milk',), 5), (('milk', 'eggs'), 3), (('milk', 'yogurt'), 3), (('eggs',), 3), (('yogurt',), 3), (('milk', 'yogurt', 'eggs'), 2), (('milk', 'bread'), 2), (('milk', 'cheese'), 2), (('yogurt', 'eggs'), 2), (('bread',), 2), (('cheese',), 2)]

# %% [markdown]
# # Association Pattern Mining

# %% [markdown]
# For many applications, frequent itemset analysis is not the final analysis performed but rather continues on to association pattern mining. Let us define a few terms first.
#
# The **confidence** of an **association rule** $A \rightarrow B$ is the conditional probability that $B$ is in a transaction given that it contains $A$,
# $$
# conf(A \rightarrow B) = \Pr(B \in T_i | A \in T_i) = \frac{sup(A \cup B)}{sup(A)}.
# $$
# We say that $A$ is the **antecedent** and $B$ as the **consequent** of the rule. The objective of association pattern mining is to find the rules that have a confidence at least equal to a given minimum confidence $minconf$. **Lift** is the increase in the likelihood of $B$ in a transaction given that $A$ is already included,
# $$
# lift(A \rightarrow B) = \frac{conf(A \rightarrow B)}{relSup(B)}.
# $$
# A lift greater than 1 means $A$ and $B$ are more likely to be found together than just $B$ alone, a value of 1 means there is no association between $A$ and $B$, and a lift of less than 1 implies that $A$ and $B$ are unlikely to be together (negative association).
#
# We find the association rules for a database of transactions by first looking for all frequent itemsets in the database with the minimum support. For all frequent itemsets, we generate the candidate association rules by setting one of the items as the consequent then all possible subsets of the remaining items as antecedent. The confidence of each candidate association rule is computed and only those that reached the minimum support is returned.

# %% [markdown]
# **Exercise 9**
#
# Create a function `assoc` that accepts the list of frequent itemsets returned by the functions above, minimum confidence $minconf$ and number of transactions in the database then returns the list of association rules with $minconf$ minimum confidence as a list of dicts. Each dict corresponds to a rule and it should have the following keys: `antecedent`, `consequent`, `support`, `confidence` and `lift`. Sort the rules by decreasing lift.

# %%
### LT7
# def assoc(fi, minconf, db_size):
#     fi = sorted(fi, key=lambda x:len(x[0]))   
#     sup_dict = {fi_pair[0]: fi_pair[1] for fi_pair in fi}

#     # Generate candidate rules
#     cand_rules = set()
#     for fi_pair in fi:
#         if len(fi_pair[0]) > 1:
#             itemset = list(fi_pair[0])
#             for item in itemset:
#                 cons_fi = item
#                 ante_list = itemset.copy()
#                 ante_list.remove(item)
#                 r = len(ante_list)
#                 ante_list = (
#                     [ante for ante in itertools.combinations(ante_list, r)]
#                 )
#                 for ante_fi in ante_list:
#                     cand_rules.add((ante_fi, cons_fi, fi_pair[1]))
    
#     # Compute for the confidence and lift
#     rules = []
#     for cand_rule in cand_rules:
#         confidence = cand_rule[2] / sup_dict[cand_rule[0]]
#         if confidence < minconf:
#             continue
#         lift = confidence / (sup_dict[tuple(cand_rule[1])] / db_size)
#         rule_dict = {
#             'antecedent': cand_rule[0],
#             'consequent': cand_rule[1],
#             'support': cand_rule[2],
#             'confidence': confidence,
#             'lift': lift
#         }
#         rules.append(rule_dict)
                
#     return sorted(rules, key=lambda x: -x['lift'])

# %%
# ## LT Pat
# def assoc(fi, minconf, db_size):
#     revised_fi = [p[0] for p in fi if len(p[0]) >= 2]

#     antecedents = []
#     consequents = []

#     for itemset in revised_fi:
#         for item in itemset:
#             antecedent_tmp = list(itemset)
#             antecedent_tmp.remove(item)

#             antecedent_comb = []
#             for r in range(1, len(antecedent_tmp)+1):
#                 antecedent_comb += [c for c in combinations(antecedent_tmp, r)]

#             for subset in antecedent_comb:
#                 consequents += [item]
#                 antecedents += [subset]

#     candidates = list(set(tuple(zip(antecedents, consequents))))
#     dict_fi = dict(fi)

#     strong_rules = []
#     for candidate in candidates:
#         antecedent = candidate[0]
#         consequent = candidate[1]
#         support = dict_fi[tuple(sorted(antecedent + tuple(consequent)))]
#         confidence = support/dict_fi[tuple(sorted(antecedent))]
#         lift = confidence/(dict_fi[tuple(sorted(consequent))]/db_size)

#         measures = dict(zip(['antecedent','consequent', 'support', 'confidence', 'lift'],
#                             [antecedent, consequent, support, confidence, lift]))

#         if confidence >= minconf:
#             strong_rules += [measures]

#     return sorted(strong_rules, key=lambda x:
#                  (-x['lift'], x['consequent'], x['antecedent']))

# %%
def assoc(fi, minconf, db_size):
    from itertools import combinations
    
    fi = [(tuple(sorted(k)),v) for k,v in fi]
    
    dict_fi = {k:v for k,v in fi}

    return_dict = {}
    for key in dict_fi.keys():

        if len(key) > 1:
            print('\nKEY: ', key)
            for length in range(1, len(key)+1):
                for ante in combinations(key, length):
                    ante=list(ante)
                    cons_li = list(key)
                    for a in ante:
                        cons_li.remove(a)
                    cons = cons_li
                    if len(cons) > 0:
                        for con in combinations(cons, 1):
                            print(f'Ante:{ante}, cons:{list(con)}')
                            conf = dict_fi[tuple(sorted(ante + list(con)))] / dict_fi[tuple(ante)]
                            lift = conf/(dict_fi[con] / db_size)

                            if conf >= minconf:

                                print(f'\t CONF: {conf}')
                                print(f'\t LIFT: {lift}')
                                supp = dict_fi[key]
                                return_dict[(tuple(ante), con)] = (supp, conf, lift)
                            else:
                                print('DID NOT REACH MINCONF')

    output_list = []
    for k,v in return_dict.items():
        output_list.append(
        {'antecedent': tuple(sorted(k[0])), 
         'consequent': k[1][0], 
         'support': v[0], 
         'confidence': v[1], 
         'lift': v[2]}
        )
    return sorted(output_list, key=lambda x: (-x['lift'], x['consequent'], x['antecedent']))

# %%
rules = assoc([
    (('a',), 5),
    (('a', 'b'), 3),
    (('a', 'c'), 3),
    (('b',), 3),
    (('c',), 3),
    (('a', 'b', 'c'), 2),
    (('a', 'd'), 2),
    (('a', 'e'), 2),
    (('b', 'c'), 2),
    (('d',), 2),
    (('e',), 2)], 
    0.2, 5)
assert_equal(len(rules), 13)
assert_equal(rules[0],
             {'antecedent': ('a', 'c'),
              'consequent': 'b',
              'support': 2,
              'confidence': 0.6666666666666666,
              'lift': 1.1111111111111112})
# Out:
# KEY:  ('a', 'b')
# Ante:['a'], cons:['b']
# 	 CONF: 0.6
# 	 LIFT: 1.0
# Ante:['b'], cons:['a']
# 	 CONF: 1.0
# 	 LIFT: 1.0
#
# KEY:  ('a', 'c')
# Ante:['a'], cons:['c']
# 	 CONF: 0.6
# 	 LIFT: 1.0
# Ante:['c'], cons:['a']
# 	 CONF: 1.0
# 	 LIFT: 1.0
#
# KEY:  ('a', 'b', 'c')
# Ante:['a'], cons:['b']
# 	 CONF: 0.6
# 	 LIFT: 1.0
# Ante:['a'], cons:['c']
# 	 CONF: 0.6
# 	 LIFT: 1.0
# Ante:['b'], cons:['a']
# 	 CONF: 1.0
# 	 LIFT: 1.0
# Ante:['b'], cons:['c']
# 	 CONF: 0.6666666666666666
# 	 LIFT: 1.1111111111111112
# Ante:['c'], cons:['a']
# 	 CONF: 1.0
# 	 LIFT: 1.0
# Ante:['c'], cons:['b']
# 	 CONF: 0.6666666666666666
# 	 LIFT: 1.1111111111111112
# Ante:['a', 'b'], cons:['c']
# 	 CONF: 0.6666666666666666
# 	 LIFT: 1.1111111111111112
# Ante:['a', 'c'], cons:['b']
# 	 CONF: 0.6666666666666666
# 	 LIFT: 1.1111111111111112
# Ante:['b', 'c'], cons:['a']
# 	 CONF: 1.0
# 	 LIFT: 1.0
#
# KEY:  ('a', 'd')
# Ante:['a'], cons:['d']
# 	 CONF: 0.4
# 	 LIFT: 1.0
# Ante:['d'], cons:['a']
# 	 CONF: 1.0
# 	 LIFT: 1.0
#
# KEY:  ('a', 'e')
# Ante:['a'], cons:['e']
# 	 CONF: 0.4
# 	 LIFT: 1.0
# Ante:['e'], cons:['a']
# 	 CONF: 1.0
# 	 LIFT: 1.0
#
# KEY:  ('b', 'c')
# Ante:['b'], cons:['c']
# 	 CONF: 0.6666666666666666
# 	 LIFT: 1.1111111111111112
# Ante:['c'], cons:['b']
# 	 CONF: 0.6666666666666666
# 	 LIFT: 1.1111111111111112

# %% [markdown]
# # pyFIM

# %% [markdown]
# Pandas and scikit-learn do not have a frequent itemset analysis module. We could instead use [pyFIM](http://www.borgelt.net/pyfim.html), which is a rather comprehensive FIM library.
#
# Here is an example of its usage:

# %%
import fim
fim.apriori(db)
# Out:
# [(('milk',), 5),
#  (('butter', 'milk', 'bread'), 1),
#  (('butter', 'milk'), 1),
#  (('butter', 'bread'), 1),
#  (('butter',), 1),
#  (('bread', 'milk'), 2),
#  (('bread',), 2),
#  (('bread', 'cheese', 'milk', 'eggs'), 1),
#  (('bread', 'cheese', 'milk'), 1),
#  (('bread', 'cheese', 'eggs'), 1),
#  (('bread', 'cheese'), 1),
#  (('bread', 'eggs', 'milk'), 1),
#  (('bread', 'eggs'), 1),
#  (('cheese', 'milk'), 2),
#  (('cheese',), 2),
#  (('cheese', 'yogurt', 'milk'), 1),
#  (('cheese', 'yogurt'), 1),
#  (('cheese', 'eggs', 'milk'), 1),
#  (('cheese', 'eggs'), 1),
#  (('yogurt', 'milk'), 3),
#  (('yogurt',), 3),
#  (('yogurt', 'eggs', 'milk'), 2),
#  (('yogurt', 'eggs'), 2),
#  (('eggs', 'milk'), 3),
#  (('eggs',), 3)]

# %% [markdown]
# Note that in `fim`, a positive argument to `supp` (support) is treated as a percentage and a negative value is considered as absolute support.

# %%
fim.eclat(db, supp=-2)
# Out:
# [(('yogurt', 'milk'), 3),
#  (('yogurt',), 3),
#  (('eggs', 'yogurt', 'milk'), 2),
#  (('eggs', 'yogurt'), 2),
#  (('eggs', 'milk'), 3),
#  (('eggs',), 3),
#  (('bread', 'milk'), 2),
#  (('bread',), 2),
#  (('cheese', 'milk'), 2),
#  (('cheese',), 2),
#  (('milk',), 5)]

# %% [markdown]
# The minimum length of an itemset can be specified with `zmin`.

# %%
fim.fpgrowth(db, supp=20, zmin=2)
# Out:
# [(('eggs', 'milk'), 3),
#  (('yogurt', 'eggs', 'milk'), 2),
#  (('yogurt', 'eggs'), 2),
#  (('yogurt', 'milk'), 3),
#  (('bread', 'eggs', 'milk'), 1),
#  (('bread', 'eggs'), 1),
#  (('bread', 'milk'), 2),
#  (('cheese', 'eggs', 'milk'), 1),
#  (('cheese', 'eggs'), 1),
#  (('cheese', 'yogurt', 'milk'), 1),
#  (('cheese', 'yogurt'), 1),
#  (('cheese', 'bread', 'milk', 'eggs'), 1),
#  (('cheese', 'bread', 'milk'), 1),
#  (('cheese', 'bread', 'eggs'), 1),
#  (('cheese', 'bread'), 1),
#  (('cheese', 'milk'), 2),
#  (('butter', 'milk', 'bread'), 1),
#  (('butter', 'milk'), 1),
#  (('butter', 'bread'), 1)]

# %% [markdown]
# The `report` parameter is quite powerful and can be used, for example, to return the rules along with their lift as a fraction.

# %%
fim.fpgrowth(db, target='r', supp=20, conf=30, report='l')
# Out:
# [('milk', (), 1.0),
#  ('milk', ('eggs',), 1.0),
#  ('eggs', ('milk',), 1.0),
#  ('eggs', (), 1.0),
#  ('milk', ('yogurt',), 1.0),
#  ('yogurt', ('milk',), 1.0),
#  ('milk', ('yogurt', 'eggs'), 1.0),
#  ('eggs', ('yogurt', 'milk'), 1.1111111111111112),
#  ('yogurt', ('eggs', 'milk'), 1.1111111111111112),
#  ('eggs', ('yogurt',), 1.1111111111111112),
#  ('yogurt', ('eggs',), 1.1111111111111112),
#  ('yogurt', (), 1.0),
#  ('milk', ('bread',), 1.0),
#  ('bread', ('milk',), 1.0),
#  ('milk', ('bread', 'eggs'), 1.0),
#  ('eggs', ('bread', 'milk'), 0.8333333333333334),
#  ('bread', ('eggs', 'milk'), 0.8333333333333334),
#  ('eggs', ('bread',), 0.8333333333333334),
#  ('bread', ('eggs',), 0.8333333333333334),
#  ('bread', (), 1.0),
#  ('milk', ('cheese',), 1.0),
#  ('cheese', ('milk',), 1.0),
#  ('milk', ('cheese', 'eggs'), 1.0),
#  ('eggs', ('cheese', 'milk'), 0.8333333333333334),
#  ('cheese', ('eggs', 'milk'), 0.8333333333333334),
#  ('eggs', ('cheese',), 0.8333333333333334),
#  ('cheese', ('eggs',), 0.8333333333333334),
#  ('milk', ('cheese', 'yogurt'), 1.0),
#  ('yogurt', ('cheese', 'milk'), 0.8333333333333334),
#  ('cheese', ('yogurt', 'milk'), 0.8333333333333334),
#  ('yogurt', ('cheese',), 0.8333333333333334),
#  ('cheese', ('yogurt',), 0.8333333333333334),
#  ('milk', ('cheese', 'bread'), 1.0),
#  ('bread', ('cheese', 'milk'), 1.25),
#  ('cheese', ('bread', 'milk'), 1.25),
#  ('milk', ('cheese', 'bread', 'eggs'), 1.0),
#  ('eggs', ('cheese', 'bread', 'milk'), 1.6666666666666667),
#  ('bread', ('cheese', 'eggs', 'milk'), 2.5),
#  ('cheese', ('bread', 'eggs', 'milk'), 2.5),
#  ('eggs', ('cheese', 'bread'), 1.6666666666666667),
#  ('bread', ('cheese', 'eggs'), 2.5),
#  ('cheese', ('bread', 'eggs'), 2.5),
#  ('bread', ('cheese',), 1.25),
#  ('cheese', ('bread',), 1.25),
#  ('cheese', (), 1.0),
#  ('milk', ('butter',), 1.0),
#  ('milk', ('butter', 'bread'), 1.0),
#  ('bread', ('butter', 'milk'), 2.5),
#  ('butter', ('bread', 'milk'), 2.5),
#  ('bread', ('butter',), 2.5),
#  ('butter', ('bread',), 2.5)]

# %% [markdown]
# **Exercise 10**
#
# Compare the runtime of Apriori, ECLAT and FP-growth when the number of items is large, and when the number of transactions is large.

# %% [markdown]
# In terms of runtime, FP-growth is the best with ECLAT coming in second, and Apriori coming last. This is because FP-growth does not require candidate generation unlike ECLAT and Apriori, ECLAT is faster than apriori simply because ECLAT only scans the projected database, while apriori scans the original database.

# %% [markdown]
# **Exercise 11**
#
# Suppose the owner of a store provided you their POS data (`/mnt/data/public/retaildata/Online Retail.csv`). Provide three suggestions to the owner of the store based on the results of FIM. More information about the dataset is available [here](https://archive.ics.uci.edu/ml/datasets/online+retail).

# %%
import fim
df = pd.read_csv('/mnt/data/public/retaildata/Online Retail.csv').dropna()
db = df.groupby('InvoiceNo')['Description'].agg(lambda x: set(x))
results_eclat = fim.eclat(db, supp=1, zmin=1)
fim_ = sorted(results_eclat, key=lambda x: (-x[1], -len(x[0]), x[0]))
fim_
# Out:
# [(('WHITE HANGING HEART T-LIGHT HOLDER',), 2013),
#  (('REGENCY CAKESTAND 3 TIER',), 1884),
#  (('JUMBO BAG RED RETROSPOT',), 1643),
#  (('PARTY BUNTING',), 1399),
#  (('ASSORTED COLOUR BIRD ORNAMENT',), 1385),
#  (('LUNCH BAG RED RETROSPOT',), 1329),
#  (('SET OF 3 CAKE TINS PANTRY DESIGN ',), 1218),
#  (('POSTAGE',), 1194),
#  (('LUNCH BAG  BLACK SKULL.',), 1073),
#  (('PACK OF 72 RETROSPOT CAKE CASES',), 1041),
#  (('SPOTTY BUNTING',), 1015),
#  (('LUNCH BAG SPACEBOY DESIGN ',), 1001),
#  (("PAPER CHAIN KIT 50'S CHRISTMAS ",), 990),
#  (('LUNCH BAG CARS BLUE',), 989),
#  (('NATURAL SLATE HEART CHALKBOARD ',), 984),
#  (('HEART OF WICKER SMALL',), 972),
#  (('JAM MAKING SET WITH JARS',), 965),
#  (('LUNCH BAG PINK POLKADOT',), 951),
#  (('LUNCH BAG SUKI DESIGN ',), 916),
#  (('ALARM CLOCK BAKELIKE RED ',), 907),
#  (('WOODEN PICTURE FRAME WHITE FINISH',), 894),
#  (('JUMBO BAG PINK POLKADOT',), 884),
#  (('BAKING SET 9 PIECE RETROSPOT ',), 881),
#  (('JAM MAKING SET PRINTED',), 880),
#  (('LUNCH BAG APPLE DESIGN',), 878),
#  (('RECIPE BOX PANTRY YELLOW DESIGN',), 875),
#  (('SET OF 4 PANTRY JELLY MOULDS',), 875),
#  (('REX CASH+CARRY JUMBO SHOPPER',), 862),
#  (('LUNCH BAG WOODLAND',), 839),
#  (('RETROSPOT TEA SET CERAMIC 11 PC ',), 839),
#  (('VICTORIAN GLASS HANGING T-LIGHT',), 839),
#  (('ROSES REGENCY TEACUP AND SAUCER ',), 836),
#  (('WOODEN FRAME ANTIQUE WHITE ',), 826),
#  (('HEART OF WICKER LARGE',), 817),
#  (('RABBIT NIGHT LIGHT',), 816),
#  (('ALARM CLOCK BAKELIKE GREEN',), 809),
#  (('JUMBO SHOPPER VINTAGE RED PAISLEY',), 801),
#  (('SET/5 RED RETROSPOT LID GLASS BOWLS',), 797),
#  (('JUMBO STORAGE BAG SUKI',), 791),
#  (('JUMBO BAG VINTAGE LEAF',), 778),
#  (('GARDENERS KNEELING PAD KEEP CALM ',), 767),
#  (('JUMBO BAG ALPHABET',), 766),
#  (('RED RETROSPOT CHARLOTTE BAG',), 755),
#  (('SET OF 3 REGENCY CAKE TINS',), 755),
#  (('JUMBO BAG APPLES',), 739),
#  (('SET/20 RED RETROSPOT PAPER NAPKINS ',), 734),
#  (('GREEN REGENCY TEACUP AND SAUCER',), 733),
#  (('6 RIBBONS RUSTIC CHARM',), 732),
#  (('HOT WATER BOTTLE KEEP CALM',), 726),
#  (('VINTAGE SNAP CARDS',), 725),
#  (('SPACEBOY LUNCH BOX ',), 712),
#  (('PAPER CHAIN KIT VINTAGE CHRISTMAS',), 709),
#  (('CHOCOLATE HOT WATER BOTTLE',), 707),
#  (('PLEASE ONE PERSON METAL SIGN',), 704),
#  (('HOME BUILDING BLOCK WORD',), 700),
#  (('RED HANGING HEART T-LIGHT HOLDER',), 692),
#  (('PACK OF 60 PINK PAISLEY CAKE CASES',), 675),
#  (('POPCORN HOLDER',), 668),
#  (('JUMBO BAG STRAWBERRY',), 667),
#  (('SET OF 6 SPICE TINS PANTRY DESIGN',), 665),
#  (('60 TEATIME FAIRY CAKE CASES',), 664),
#  (('JUMBO  BAG BAROQUE BLACK WHITE',), 663),
#  (('SCOTTIE DOG HOT WATER BOTTLE',), 663),
#  (('GIN + TONIC DIET METAL SIGN',), 662),
#  (('LUNCH BAG ALPHABET DESIGN',), 660),
#  (('DOORMAT KEEP CALM AND COME IN',), 655),
#  (('CLOTHES PEGS RETROSPOT PACK 24 ',), 650),
#  (('GARDENERS KNEELING PAD CUP OF TEA ',), 642),
#  (('JUMBO BAG VINTAGE DOILY ',), 634),
#  (('ALARM CLOCK BAKELIKE PINK',), 629),
#  (('IVORY KITCHEN SCALES',), 629),
#  (('DOLLY GIRL LUNCH BOX',), 625),
#  (('WOOD BLACK BOARD ANT WHITE FINISH',), 615),
#  (('JUMBO BAG PINK VINTAGE PAISLEY',), 614),
#  (('COOK WITH WINE METAL SIGN ',), 613),
#  (('ROUND SNACK BOXES SET OF4 WOODLAND ',), 612),
#  (('LUNCH BAG DOLLY GIRL DESIGN',), 605),
#  (('HANGING HEART JAR T-LIGHT HOLDER',), 602),
#  (('LUNCH BAG VINTAGE LEAF DESIGN',), 601),
#  (('GUMBALL COAT RACK',), 599),
#  (('CHARLOTTE BAG SUKI DESIGN',), 597),
#  (('HAND OVER THE CHOCOLATE   SIGN ',), 593),
#  (("JUMBO BAG 50'S CHRISTMAS ",), 593),
#  (('PLASTERS IN TIN WOODLAND ANIMALS',), 592),
#  (('PINK REGENCY TEACUP AND SAUCER',), 591),
#  (('PLASTERS IN TIN SPACEBOY',), 587),
#  (('SMALL WHITE HEART OF WICKER',), 586),
#  (('DOORMAT RED RETROSPOT',), 583),
#  (('HAND WARMER OWL DESIGN',), 583),
#  (('PAPER BUNTING RETROSPOT',), 575),
#  (('RED  HARMONICA IN BOX ',), 569),
#  (('STRAWBERRY CERAMIC TRINKET BOX',), 559),
#  (('GREEN REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER '),
#   557),
#  (('ANTIQUE SILVER T-LIGHT GLASS',), 557),
#  (('LOVE BUILDING BLOCK WORD',), 557),
#  (('GINGERBREAD MAN COOKIE CUTTER',), 556),
#  (('JUMBO BAG PINK POLKADOT', 'JUMBO BAG RED RETROSPOT'), 554),
#  (('WOOD 2 DRAWER CABINET WHITE FINISH',), 549),
#  (('LUNCH BAG VINTAGE DOILY ',), 545),
#  (('RETROSPOT HEART HOT WATER BOTTLE',), 541),
#  (('COLOUR GLASS T-LIGHT HOLDER HANGING',), 540),
#  (('WOODLAND CHARLOTTE BAG',), 539),
#  (('PACK OF 20 NAPKINS PANTRY DESIGN',), 538),
#  (('PINK CREAM FELT CRAFT TRINKET BOX ',), 537),
#  (('ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE RED '), 536),
#  (('DOORMAT NEW ENGLAND',), 533),
#  (('RED TOADSTOOL LED NIGHT LIGHT',), 533),
#  (('PACK OF 60 DINOSAUR CAKE CASES',), 532),
#  (('PLASTERS IN TIN CIRCUS PARADE ',), 531),
#  (('LUNCH BAG PINK POLKADOT', 'LUNCH BAG RED RETROSPOT'), 530),
#  (('HOMEMADE JAM SCENTED CANDLES',), 526),
#  (('CHILLI LIGHTS',), 525),
#  (('SET OF 3 HEART COOKIE CUTTERS',), 525),
#  (('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG RED RETROSPOT'), 523),
#  (('DOORMAT UNION FLAG',), 523),
#  (('LUNCH BOX I LOVE LONDON',), 522),
#  (('LARGE WHITE HEART OF WICKER',), 521),
#  (('BLUE HARMONICA IN BOX ',), 519),
#  (('HOT WATER BOTTLE TEA AND SYMPATHY',), 518),
#  (('GREY HEART HOT WATER BOTTLE',), 515),
#  (('TRADITIONAL KNITTING NANCY',), 513),
#  (('HOT WATER BOTTLE I AM SO POORLY',), 510),
#  (('SET OF 60 PANTRY DESIGN CAKE CASES ',), 509),
#  (('72 SWEETHEART FAIRY CAKE CASES',), 505),
#  (('SET OF 3 BUTTERFLY COOKIE CUTTERS',), 505),
#  (('CHARLOTTE BAG PINK POLKADOT',), 504),
#  (('STRAWBERRY CHARLOTTE BAG',), 504),
#  (('JUMBO BAG WOODLAND ANIMALS',), 501),
#  (('PACK OF 72 SKULL CAKE CASES',), 500),
#  (('SET OF 20 VINTAGE CHRISTMAS NAPKINS',), 496),
#  (('VINTAGE HEADS AND TAILS CARD GAME ',), 488),
#  (('PLASTERS IN TIN VINTAGE PAISLEY ',), 484),
#  (('DOORMAT HEARTS',), 482),
#  (('JUMBO BAG SPACEBOY DESIGN',), 482),
#  (('ALARM CLOCK BAKELIKE IVORY',), 480),
#  (('HAND WARMER BIRD DESIGN',), 480),
#  (('ZINC METAL HEART DECORATION',), 478),
#  (('WORLD WAR 2 GLIDERS ASSTD DESIGNS',), 477),
#  (('JUMBO BAG PEARS',), 476),
#  (('HAND WARMER SCOTTY DOG DESIGN',), 475),
#  (('WOODEN FRAME ANTIQUE WHITE ', 'WOODEN PICTURE FRAME WHITE FINISH'), 474),
#  (('JUMBO STORAGE BAG SKULLS',), 474),
#  (('ROUND SNACK BOXES SET OF 4 FRUITS ',), 473),
#  (('PINK REGENCY TEACUP AND SAUCER', 'GREEN REGENCY TEACUP AND SAUCER'), 471),
#  (('LUNCH BAG SPACEBOY DESIGN ', 'LUNCH BAG RED RETROSPOT'), 470),
#  (('60 CAKE CASES VINTAGE CHRISTMAS',), 470),
#  (('CREAM SWEETHEART MINI CHEST',), 470),
#  (('FELTCRAFT 6 FLOWER FRIENDS',), 470),
#  (('SET OF 12 FAIRY CAKE BAKING CASES',), 470),
#  (('PHOTO FRAME CORNICE',), 469),
#  (('LUNCH BAG DOILEY PATTERN ',), 468),
#  (('LUNCH BAG PINK POLKADOT', 'LUNCH BAG  BLACK SKULL.'), 467),
#  (('RED KITCHEN SCALES',), 467),
#  (('GARDENERS KNEELING PAD CUP OF TEA ', 'GARDENERS KNEELING PAD KEEP CALM '),
#   466),
#  (('LUNCH BAG CARS BLUE', 'LUNCH BAG RED RETROSPOT'), 465),
#  (('WOODEN HEART CHRISTMAS SCANDINAVIAN',), 465),
#  (('RECIPE BOX RETROSPOT ',), 462),
#  (('RED RETROSPOT CAKE STAND',), 462),
#  (('PINK BLUE FELT CRAFT TRINKET BOX',), 461),
#  (('RED HANGING HEART T-LIGHT HOLDER', 'WHITE HANGING HEART T-LIGHT HOLDER'),
#   460),
#  (('CHILDRENS APRON SPACEBOY DESIGN',), 459),
#  (('JUMBO BAG SCANDINAVIAN BLUE PAISLEY',), 459),
#  (('JUMBO BAG DOILEY PATTERNS',), 458),
#  (('LUNCH BAG SUKI DESIGN ', 'LUNCH BAG RED RETROSPOT'), 457),
#  (('CREAM HEART CARD HOLDER',), 457),
#  (('PAPER CHAIN KIT VINTAGE CHRISTMAS', "PAPER CHAIN KIT 50'S CHRISTMAS "),
#   454),
#  (('ENAMEL FLOWER JUG CREAM',), 453),
#  (('PLASTERS IN TIN STRONGMAN',), 453),
#  (('PINK REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER '), 451),
#  (('LOVE HOT WATER BOTTLE',), 451),
#  (('WOODEN BOX OF DOMINOES',), 451),
#  (('HAND WARMER UNION JACK',), 448),
#  (('PAPER CHAIN KIT RETROSPOT',), 448),
#  (('TRAVEL CARD WALLET KEEP CALM',), 448),
#  (('PLASTERS IN TIN SKULLS',), 447),
#  (('FELTCRAFT BUTTERFLY HEARTS',), 444),
#  (('JUMBO STORAGE BAG SUKI', 'JUMBO BAG RED RETROSPOT'), 443),
#  (('LUNCH BAG WOODLAND', 'LUNCH BAG RED RETROSPOT'), 439),
#  (('BAKING SET SPACEBOY DESIGN',), 439),
#  (('STRAWBERRY LUNCH BOX WITH CUTLERY',), 436),
#  (('WOODEN STAR CHRISTMAS SCANDINAVIAN',), 436),
#  (('LUNCH BAG RED RETROSPOT', 'JUMBO BAG RED RETROSPOT'), 434),
#  (('CHARLOTTE BAG APPLES DESIGN',), 433),
#  (('LUNCH BAG PINK POLKADOT', 'LUNCH BAG CARS BLUE'), 432),
#  (('ROSES REGENCY TEACUP AND SAUCER ', 'REGENCY CAKESTAND 3 TIER'), 432),
#  (('LUNCH BAG CARS BLUE', 'LUNCH BAG  BLACK SKULL.'), 425),
#  (('RED DINER WALL CLOCK',), 425),
#  (('DOLLY GIRL LUNCH BOX', 'SPACEBOY LUNCH BOX '), 424),
#  (('CHRISTMAS CRAFT LITTLE FRIENDS',), 424),
#  (('FELTCRAFT CUSHION OWL',), 424),
#  (('JUMBO BAG STRAWBERRY', 'JUMBO BAG RED RETROSPOT'), 422),
#  (('LUNCH BAG SPACEBOY DESIGN ', 'LUNCH BAG  BLACK SKULL.'), 419),
#  (('SET OF TEA COFFEE SUGAR TINS PANTRY',), 419),
#  (('HANGING HEART ZINC T-LIGHT HOLDER',), 418),
#  (('SET OF 20 KIDS COOKIE CUTTERS',), 418),
#  (('JUMBO BAG OWLS',), 417),
#  (('SMALL POPCORN HOLDER',), 417),
#  (('Manual',), 412),
#  (('RECYCLING BAG RETROSPOT ',), 412),
#  (('LUNCH BAG SUKI DESIGN ', 'LUNCH BAG  BLACK SKULL.'), 411),
#  (('LUNCH BAG WOODLAND', 'LUNCH BAG SPACEBOY DESIGN '), 409),
#  (('PACK OF 60 SPACEBOY CAKE CASES',), 409),
#  (('HEART OF WICKER LARGE', 'HEART OF WICKER SMALL'), 408),
#  (('DOORMAT SPOTTY HOME SWEET HOME',), 408),
#  (('SWEETHEART CERAMIC TRINKET BOX',), 408),
#  (('IVORY DINER WALL CLOCK',), 407),
#  (('3 STRIPEY MICE FELTCRAFT',), 406),
#  (('ALARM CLOCK BAKELIKE PINK', 'ALARM CLOCK BAKELIKE RED '), 403),
#  (('FELTCRAFT PRINCESS CHARLOTTE DOLL',), 401),
#  (('DOORMAT FANCY FONT HOME SWEET HOME',), 400),
#  (('JUMBO SHOPPER VINTAGE RED PAISLEY', 'JUMBO BAG RED RETROSPOT'), 399),
#  (('PINK FAIRY CAKE CHILDRENS APRON',), 399),
#  (('TRAVEL SEWING KIT',), 399),
#  (('WOODEN SCHOOL COLOURING SET',), 398),
#  (('PINK REGENCY TEACUP AND SAUCER',
#    'GREEN REGENCY TEACUP AND SAUCER',
#    'ROSES REGENCY TEACUP AND SAUCER '),
#   397),
#  (('RED RETROSPOT PICNIC BAG',), 397),
#  (('WHITE WOOD GARDEN PLANT LADDER',), 396),
#  (('LUNCH BAG CARS BLUE', 'LUNCH BAG SPACEBOY DESIGN '), 395),
#  (('SPACEBOY BIRTHDAY CARD',), 395),
#  (('VINTAGE UNION JACK BUNTING',), 395),
#  (('LUNCH BAG SUKI DESIGN ', 'LUNCH BAG CARS BLUE'), 394),
#  (('SET OF 3 WOODEN HEART DECORATIONS',), 394),
#  (('SPOTTY BUNTING', 'PARTY BUNTING'), 393),
#  (('HOT BATHS METAL SIGN',), 393),
#  (('LUNCH BAG APPLE DESIGN', 'LUNCH BAG RED RETROSPOT'), 392),
#  (('JUMBO BAG VINTAGE CHRISTMAS ',), 392),
#  (('WOOD S/3 CABINET ANT WHITE FINISH',), 389),
#  (('BATHROOM METAL SIGN',), 388),
#  (('NO SINGING METAL SIGN',), 388),
#  (('PANTRY MAGNETIC  SHOPPING LIST',), 388),
#  (('RED RETROSPOT SHOPPER BAG',), 388),
#  (('FAWN BLUE HOT WATER BOTTLE',), 386),
#  (('EDWARDIAN PARASOL NATURAL',), 384),
#  (('PACK OF 12 LONDON TISSUES ',), 384),
#  (('GREEN REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER'), 383),
#  (('LUNCH BAG SUKI DESIGN ', 'LUNCH BAG SPACEBOY DESIGN '), 382),
#  (('SMALL GLASS HEART TRINKET POT',), 382),
#  (('WHITE SKULL HOT WATER BOTTLE ',), 382),
#  (('FELTCRAFT PRINCESS LOLA DOLL',), 380),
#  (('AREA PATROLLED METAL SIGN',), 378),
#  (('CHOCOLATE THIS WAY METAL SIGN',), 377),
#  (('ALARM CLOCK BAKELIKE ORANGE',), 376),
#  (('PAPER CHAIN KIT EMPIRE',), 376),
#  (('PARTY METAL SIGN ',), 373),
#  (('ASSORTED COLOUR MINI CASES',), 371),
#  (("BOX OF 6 MINI 50'S CRACKERS",), 371),
#  (('BREAD BIN DINER STYLE IVORY',), 371),
#  (('HAND WARMER RED LOVE HEART',), 371),
#  (('LADIES & GENTLEMEN METAL SIGN',), 371),
#  (('POTTERING IN THE SHED METAL SIGN',), 371),
#  (('JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG RED RETROSPOT'), 370),
#  (('LUNCH BAG PINK POLKADOT', 'LUNCH BAG SPACEBOY DESIGN '), 370),
#  (('SET OF 72 RETROSPOT PAPER  DOILIES',), 370),
#  (('LUNCH BAG WOODLAND', 'LUNCH BAG CARS BLUE'), 369),
#  (('RED RETROSPOT MINI CASES',), 369),
#  (('SET OF 10 LED DOLLY LIGHTS',), 369),
#  (('RED RETROSPOT PEG BAG',), 367),
#  (('REGENCY TEAPOT ROSES ',), 367),
#  (('BOX OF 24 COCKTAIL PARASOLS',), 366),
#  (('4 TRADITIONAL SPINNING TOPS',), 365),
#  (('SET OF 12 MINI LOAF BAKING CASES',), 364),
#  (('PINK HAPPY BIRTHDAY BUNTING',), 363),
#  (('LUNCH BAG APPLE DESIGN', 'LUNCH BAG SUKI DESIGN '), 362),
#  (('LUNCH BAG SUKI DESIGN ', 'LUNCH BAG PINK POLKADOT'), 362),
#  (('SMALL DOLLY MIX DESIGN ORANGE BOWL',), 362),
#  (('BLUE STRIPE CERAMIC DRAWER KNOB',), 361),
#  (('VINTAGE CHRISTMAS BUNTING',), 361),
#  (('JUMBO BAG APPLES', 'JUMBO BAG RED RETROSPOT'), 360),
#  (('BEWARE OF THE CAT METAL SIGN ',), 360),
#  (('60 CAKE CASES DOLLY GIRL DESIGN',), 359),
#  (('DOORMAT ENGLISH ROSE ',), 359),
#  (('BLUE HAPPY BIRTHDAY BUNTING',), 358),
#  (('LUNCH BAG DOLLY GIRL DESIGN', 'LUNCH BAG SPACEBOY DESIGN '), 356),
#  (('SWEETHEART CAKESTAND 3 TIER',), 355),
#  (('METAL SIGN TAKE IT OR LEAVE IT ',), 354),
#  (('PACK OF 12 HEARTS DESIGN TISSUES ',), 354),
#  (('PAINTED METAL PEARS ASSORTED',), 354),
#  (('MEMO BOARD RETROSPOT  DESIGN',), 353),
#  (('LUNCH BAG WOODLAND', 'LUNCH BAG  BLACK SKULL.'), 352),
#  (('VINTAGE DOILY TRAVEL SEWING KIT',), 352),
#  (('CHRISTMAS CRAFT TREE TOP ANGEL',), 351),
#  (("POPPY'S PLAYHOUSE KITCHEN",), 349),
#  (('CANDLEHOLDER PINK HANGING HEART',), 348),
#  (('HAND WARMER RED RETROSPOT',), 348),
#  (('JUMBO BAG VINTAGE LEAF', 'JUMBO BAG RED RETROSPOT'), 347),
#  (('CHARLOTTE BAG DOLLY GIRL DESIGN',), 347),
#  (("YOU'RE CONFUSING ME METAL SIGN ",), 347),
#  (('BLUE DINER WALL CLOCK',), 345),
#  (('TRADITIONAL WOODEN SKIPPING ROPE',), 345),
#  (('ZINC FOLKART SLEIGH BELLS',), 345),
#  (('ALARM CLOCK BAKELIKE PINK', 'ALARM CLOCK BAKELIKE GREEN'), 344),
#  (('ENAMEL BREAD BIN CREAM',), 343),
#  (('METAL 4 HOOK HANGER FRENCH CHATEAU',), 343),
#  (('RED STRIPE CERAMIC DRAWER KNOB',), 343),
#  (('OPEN CLOSED METAL SIGN',), 342),
#  (('SET OF 6 SOLDIER SKITTLES',), 341),
#  (('DOORMAT WELCOME TO OUR HOME',), 340),
#  (('REGENCY TEA PLATE ROSES ',), 340),
#  (('PACK OF 60 PINK PAISLEY CAKE CASES', 'PACK OF 72 RETROSPOT CAKE CASES'),
#   338),
#  (('SET/10 RED POLKADOT PARTY CANDLES',), 338),
#  (('RED RETROSPOT WRAP ',), 337),
#  (('SCANDINAVIAN REDS RIBBONS',), 337),
#  (('SINGLE HEART ZINC T-LIGHT HOLDER',), 337),
#  (('TRADITIONAL MODELLING CLAY',), 337),
#  (('BOX OF 6 MINI VINTAGE CRACKERS',), 336),
#  (('RIBBON REEL STRIPES DESIGN ',), 336),
#  (('JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG RED RETROSPOT'), 335),
#  (('ALARM CLOCK BAKELIKE CHOCOLATE',), 335),
#  (('MINI PAINT SET VINTAGE ',), 335),
#  (('NATURAL SLATE CHALKBOARD LARGE ',), 335),
#  (('SOLDIERS EGG CUP ',), 335),
#  (('60 TEATIME FAIRY CAKE CASES', 'PACK OF 72 RETROSPOT CAKE CASES'), 334),
#  (('CARD BILLBOARD FONT',), 334),
#  (('LUNCH BOX WITH CUTLERY RETROSPOT ',), 333),
#  (('SET OF 6 RIBBONS VINTAGE CHRISTMAS',), 333),
#  (('CHARLOTTE BAG VINTAGE ALPHABET ',), 331),
#  (('GINGHAM HEART DECORATION',), 331),
#  (("I'M ON HOLIDAY METAL SIGN",), 331),
#  (('SET/3 RED GINGHAM ROSE STORAGE BOX',), 331),
#  (('ENAMEL MEASURING JUG CREAM',), 330),
#  (('PLAYING CARDS KEEP CALM & CARRY ON',), 329),
#  (('ASSORTED COLOURS SILK FAN',), 328),
#  (('FELTCRAFT CUSHION RABBIT',), 327),
#  (('CHARLOTTE BAG PINK POLKADOT', 'RED RETROSPOT CHARLOTTE BAG'), 326),
#  (('RED RETROSPOT SMALL MILK JUG',), 326),
#  (('RED WOOLLY HOTTIE WHITE HEART.',), 326),
#  (('CLEAR DRAWER KNOB ACRYLIC EDWARDIAN',), 325),
#  (('SET OF 6 TEA TIME BAKING CASES',), 325),
#  (('SET/6 RED SPOTTY PAPER PLATES',), 325),
#  (('CHILDRENS CUTLERY POLKADOT PINK',), 324),
#  (('CHILDRENS CUTLERY SPACEBOY ',), 324),
#  (('MULTI COLOUR SILVER T-LIGHT HOLDER',), 324),
#  (('LUNCH BAG WOODLAND', 'LUNCH BAG PINK POLKADOT'), 323),
#  (('CHRISTMAS CRAFT WHITE FAIRY ',), 323),
#  (('KNITTED UNION FLAG HOT WATER BOTTLE',), 323),
#  (('PACK OF 6 BIRDY GIFT TAGS',), 322),
#  (('SCANDINAVIAN PAISLEY PICNIC BAG',), 322),
#  (('SET OF 4 KNICK KNACK TINS DOILY ',), 322),
#  (('RETROSPOT LARGE MILK JUG',), 321),
#  (('SET OF 3 NOTEBOOKS IN PARCEL',), 321),
#  (('LUNCH BAG APPLE DESIGN', 'LUNCH BAG  BLACK SKULL.'), 320),
#  (('WOODEN STAR CHRISTMAS SCANDINAVIAN',
#    'WOODEN HEART CHRISTMAS SCANDINAVIAN'),
#   320),
#  (('3 HOOK PHOTO SHELF ANTIQUE WHITE',), 320),
#  (('HANGING JAM JAR T-LIGHT HOLDER',), 320),
#  (('PACK OF 12 TRADITIONAL CRAYONS',), 320),
#  (('TEA TIME PARTY BUNTING',), 320),
#  (('PINK REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER'), 319),
#  (('JUMBO BAG DOLLY GIRL DESIGN',), 319),
#  (("POPPY'S PLAYHOUSE BEDROOM ",), 319),
#  (('ALARM CLOCK BAKELIKE IVORY', 'ALARM CLOCK BAKELIKE RED '), 318),
#  (('BLACK RECORD COVER FRAME',), 318),
#  (('NATURAL SLATE RECTANGLE CHALKBOARD',), 318),
#  (('MINT KITCHEN SCALES',), 317),
#  (('GREEN REGENCY TEACUP AND SAUCER',
#    'ROSES REGENCY TEACUP AND SAUCER ',
#    'REGENCY CAKESTAND 3 TIER'),
#   316),
#  (('JUMBO BAG PEARS', 'JUMBO BAG APPLES'), 316),
#  (('PACK OF 20 NAPKINS RED APPLES',), 315),
#  (('SET 2 PANTRY DESIGN TEA TOWELS',), 315),
#  (('BUNDLE OF 3 ALPHABET EXERCISE BOOKS',), 314),
#  (('LOVEBIRD HANGING DECORATION WHITE ',), 314),
#  (('WHITE SPOT RED CERAMIC DRAWER KNOB',), 314),
#  (('BAKING SET SPACEBOY DESIGN', 'BAKING SET 9 PIECE RETROSPOT '), 312),
#  (('LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG APPLE DESIGN'), 312),
#  (('LUNCH BAG APPLE DESIGN', 'LUNCH BAG SPACEBOY DESIGN '), 312),
#  (("GIANT 50'S CHRISTMAS CRACKER",), 312),
#  (('JAM MAKING SET PRINTED', 'JAM MAKING SET WITH JARS'), 311),
#  (('12 PENCILS SMALL TUBE RED RETROSPOT',), 311),
#  (('DOUGHNUT LIP GLOSS ',), 311),
#  (('LUNCH BAG WOODLAND', 'LUNCH BAG SUKI DESIGN '), 310),
#  (('WOODEN PICTURE FRAME WHITE FINISH', 'WHITE HANGING HEART T-LIGHT HOLDER'),
#   310),
#  (('JINGLE BELL HEART DECORATION',), 310),
#  (('LUNCH BAG PINK POLKADOT',
#    'LUNCH BAG  BLACK SKULL.',
#    'LUNCH BAG RED RETROSPOT'),
#   309),
#  (('LUNCH BAG DOLLY GIRL DESIGN', 'LUNCH BAG RED RETROSPOT'), 309),
#  (('PANTRY WASHING UP BRUSH',), 309),
#  (('SET OF 72 PINK HEART PAPER DOILIES',), 309),
#  (('HOME SWEET HOME MUG',), 308),
#  (('ROTATING SILVER ANGELS T-LIGHT HLDR',), 308),
#  (('SET/10 PINK POLKADOT PARTY CANDLES',), 307),
#  (('TOILET METAL SIGN',), 307),
#  (('WICKER STAR ',), 307),
#  (('WOODEN ROUNDERS GARDEN SET ',), 307),
#  (('LUNCH BAG VINTAGE LEAF DESIGN', 'LUNCH BAG APPLE DESIGN'), 306),
#  (('FELTCRAFT CHRISTMAS FAIRY',), 306),
#  (('JUMBO BAG PAISLEY PARK',), 306),
#  (('RED RETROSPOT UMBRELLA',), 305),
#  (('SET OF 60 VINTAGE LEAF CAKE CASES ',), 305),
#  (('3 PIECE SPACEBOY COOKIE CUTTER SET',), 303),
#  (('JUMBO BAG ALPHABET', 'JUMBO BAG RED RETROSPOT'), 302),
#  (('FAMILY ALBUM WHITE PICTURE FRAME',), 302),
#  (('SET 7 BABUSHKA NESTING BOXES',), 302),
#  (('CHARLOTTE BAG SUKI DESIGN', 'RED RETROSPOT CHARLOTTE BAG'), 301),
#  (('RED RETROSPOT BOWL',), 301),
#  (('LUNCH BAG WOODLAND', 'LUNCH BAG APPLE DESIGN'), 300),
#  (('SET OF 6 SPICE TINS PANTRY DESIGN', 'SET OF 3 CAKE TINS PANTRY DESIGN '),
#   300),
#  (('STRAWBERRY CHARLOTTE BAG', 'RED RETROSPOT CHARLOTTE BAG'), 300),
#  (('RETROSPOT CHILDRENS APRON',), 300),
#  (('VINTAGE CREAM DOG FOOD CONTAINER',), 300),
#  (('LUNCH BAG PAISLEY PARK  ',), 299),
#  (('FELTCRAFT DOLL MOLLY',), 298),
#  (('SET OF 60 I LOVE LONDON CAKE CASES ',), 298),
#  (('WOODEN UNION JACK BUNTING',), 298),
#  (('JUMBO BAG APPLES', 'LUNCH BAG APPLE DESIGN'), 297),
#  (('FELTCRAFT CUSHION BUTTERFLY',), 297),
#  (('TRADITIONAL WOODEN CATCH CUP GAME ',), 297),
#  (('BLUE SPOT CERAMIC DRAWER KNOB',), 296),
#  (('EDWARDIAN PARASOL BLACK',), 296),
#  (('TOY TIDY PINK POLKADOT',), 296),
#  (('TRAVEL CARD WALLET VINTAGE TICKET',), 296),
#  (('JUMBO BAG VINTAGE DOILY ', 'JUMBO BAG RED RETROSPOT'), 295),
#  (('HAND WARMER BABUSHKA DESIGN',), 295),
#  (('SET OF 6 SNACK LOAF BAKING CASES',), 295),
#  (('JUMBO BAG STRAWBERRY', 'JUMBO BAG PINK POLKADOT'), 294),
#  (('PLASTERS IN TIN SPACEBOY', 'PLASTERS IN TIN WOODLAND ANIMALS'), 294),
#  (('12 PENCILS SMALL TUBE SKULL',), 294),
#  (('PLACE SETTING WHITE HEART',), 294),
#  (('RED SPOT CERAMIC DRAWER KNOB',), 293),
#  (('LUNCH BAG APPLE DESIGN', 'LUNCH BAG PINK POLKADOT'), 292),
#  (('REVOLVER WOODEN RULER ',), 292),
#  (('WASHROOM METAL SIGN',), 292),
#  (('LUNCH BAG APPLE DESIGN', 'LUNCH BAG CARS BLUE'), 291),
#  (('HEART OF WICKER LARGE', 'WHITE HANGING HEART T-LIGHT HOLDER'), 290),
#  (('HOT WATER BOTTLE I AM SO POORLY', 'CHOCOLATE HOT WATER BOTTLE'), 290),
#  (('WOODLAND CHARLOTTE BAG', 'RED RETROSPOT CHARLOTTE BAG'), 290),
#  (('SWEETHEART RECIPE BOOK STAND',), 290),
#  (('HANGING METAL HEART LANTERN',), 289),
#  (('SMALL MARSHMALLOWS PINK BOWL',), 289),
#  (('TREASURE TIN GYMKHANA DESIGN',), 289),
#  (('ANTIQUE SILVER TEA GLASS ENGRAVED',), 288),
#  (('CERAMIC STRAWBERRY CAKE MONEY BANK',), 288),
#  (('SET 20 NAPKINS FAIRY CAKES DESIGN ',), 288),
#  (('JUMBO BAG APPLES', 'JUMBO BAG VINTAGE LEAF'), 286),
#  (('LANTERN CREAM GAZEBO ',), 286),
#  (('PINK VINTAGE PAISLEY PICNIC BAG',), 286),
#  (('RED RETROSPOT CUP',), 286),
#  (('SET 6 SCHOOL MILK BOTTLES IN CRATE',), 286),
#  (('PIGGY BANK RETROSPOT ',), 285),
#  (('REGENCY SUGAR BOWL GREEN',), 285),
#  (('SET 12 KIDS COLOUR  CHALK STICKS',), 285),
#  (('SET/6 RED SPOTTY PAPER CUPS',), 285),
#  (('SILVER HANGING T-LIGHT HOLDER',), 285),
#  (('JUMBO STORAGE BAG SUKI', 'JUMBO BAG PINK POLKADOT'), 284),
#  (('CHICK GREY HOT WATER BOTTLE',), 284),
#  (('VINTAGE CHRISTMAS STOCKING ',), 284),
#  (('WHITE SPOT BLUE CERAMIC DRAWER KNOB',), 284),
#  (('RED RETROSPOT CHARLOTTE BAG', 'JUMBO BAG RED RETROSPOT'), 283),
#  (('BINGO SET',), 283),
#  (('REGENCY MILK JUG PINK ',), 283),
#  (('LUNCH BAG PINK POLKADOT',
#    'LUNCH BAG CARS BLUE',
#    'LUNCH BAG RED RETROSPOT'),
#   282),
#  (('JUMBO BAG APPLES', 'JUMBO BAG ALPHABET'), 282),
#  (('LARGE WHITE HEART OF WICKER', 'SMALL WHITE HEART OF WICKER'), 282),
#  (('LUNCH BAG PINK POLKADOT', 'JUMBO BAG RED RETROSPOT'), 282),
#  (('AGED GLASS SILVER T-LIGHT HOLDER',), 282),
#  (('CLASSIC GLASS COOKIE JAR',), 282),
#  (('HAND WARMER SCOTTY DOG DESIGN', 'HAND WARMER OWL DESIGN'), 281),
#  (('SAVE THE PLANET MUG',), 281),
#  (('60 TEATIME FAIRY CAKE CASES', 'PACK OF 60 PINK PAISLEY CAKE CASES'), 280),
#  (('LUNCH BAG  BLACK SKULL.', 'JUMBO BAG RED RETROSPOT'), 280),
#  (('PARTY BUNTING', 'WHITE HANGING HEART T-LIGHT HOLDER'), 280),
#  (('COOK WITH WINE METAL SIGN ', 'GIN + TONIC DIET METAL SIGN'), 279),
#  (('ENGLISH ROSE HOT WATER BOTTLE',), 279),
#  (('LONDON BUS COFFEE MUG',), 279),
#  (('12 PENCIL SMALL TUBE WOODLAND',), 278),
#  (('PACK OF 60 MUSHROOM CAKE CASES',), 278),
#  (('RETROSPOT PARTY BAG + STICKER SET',), 278),
#  (('WATERING CAN BLUE ELEPHANT',), 278),
#  (('CHILDRENS APRON APPLES DESIGN',), 277),
#  (('WOODEN TREE CHRISTMAS SCANDINAVIAN',), 277),
#  (('ALARM CLOCK BAKELIKE IVORY', 'ALARM CLOCK BAKELIKE GREEN'), 276),
#  (("BISCUIT TIN 50'S CHRISTMAS",), 276),
#  (('CHILDRENS CUTLERY DOLLY GIRL ',), 276),
#  (('LOVE BUILDING BLOCK WORD', 'HOME BUILDING BLOCK WORD'), 275),
#  (('REGENCY TEA PLATE GREEN ',), 275),
#  (('SET OF 3 WOODEN STOCKING DECORATION',), 275),
#  (('PINK REGENCY TEACUP AND SAUCER',
#    'GREEN REGENCY TEACUP AND SAUCER',
#    'REGENCY CAKESTAND 3 TIER'),
#   274),
#  (('PICNIC BASKET WICKER LARGE',), 274),
#  (('SET OF 3 HANGING OWLS OLLIE BEAK',), 274),
#  (('CHRISTMAS LIGHTS 10 REINDEER',), 273),
#  (('EDWARDIAN PARASOL RED',), 273),
#  (("ROLL WRAP 50'S CHRISTMAS",), 273),
#  (('WHITE WICKER STAR ',), 273),
#  (('BLUE HARMONICA IN BOX ', 'RED  HARMONICA IN BOX '), 272),
#  (('JUMBO BAG SCANDINAVIAN BLUE PAISLEY', 'JUMBO BAG RED RETROSPOT'), 272),
#  (('PINK REGENCY TEACUP AND SAUCER',
#    'ROSES REGENCY TEACUP AND SAUCER ',
#    'REGENCY CAKESTAND 3 TIER'),
#   271),
#  (('ASSORTED COLOUR BIRD ORNAMENT', 'WHITE HANGING HEART T-LIGHT HOLDER'),
#   271),
#  (('HEART IVORY TRELLIS LARGE',), 271),
#  (('COOK WITH WINE METAL SIGN ', 'PLEASE ONE PERSON METAL SIGN'), 270),
#  (('RED KITCHEN SCALES', 'IVORY KITCHEN SCALES'), 270),
#  (('T-LIGHT GLASS FLUTED ANTIQUE',), 270),
#  (('JUMBO BAG SPACEBOY DESIGN', 'JUMBO BAG RED RETROSPOT'), 269),
#  (('RECIPE BOX PANTRY YELLOW DESIGN', 'SET OF 3 CAKE TINS PANTRY DESIGN '),
#   269),
#  (('3 HEARTS HANGING DECORATION RUSTIC',), 269),
#  (('SET 6 PAPER TABLE LANTERN HEARTS ',), 269),
#  (('SKULL LUNCH BOX WITH CUTLERY ',), 269),
#  (('ALARM CLOCK BAKELIKE PINK',
#    'ALARM CLOCK BAKELIKE GREEN',
#    'ALARM CLOCK BAKELIKE RED '),
#   268),
#  (('HAND WARMER BIRD DESIGN', 'HAND WARMER OWL DESIGN'), 268),
#  (('HEART OF WICKER SMALL', 'WHITE HANGING HEART T-LIGHT HOLDER'), 268),
#  (('PACK OF 60 DINOSAUR CAKE CASES', 'PACK OF 72 RETROSPOT CAKE CASES'), 268),
#  (('IVORY WICKER HEART LARGE',), 268),
#  (('VINTAGE SNAKES & LADDERS',), 268),
#  (('ROUND SNACK BOXES SET OF 4 FRUITS ',
#    'ROUND SNACK BOXES SET OF4 WOODLAND '),
#   267),
#  (('JAM JAR WITH PINK LID',), 267),
#  (('KEY FOB , SHED',), 267),
#  (('MEMO BOARD COTTAGE DESIGN',), 267),
#  (('TRADITIONAL CHRISTMAS RIBBONS',), 267),
#  (('NATURAL SLATE HEART CHALKBOARD ', 'WHITE HANGING HEART T-LIGHT HOLDER'),
#   266),
#  (('BREAD BIN DINER STYLE RED ',), 266),
#  (('CLASSIC METAL BIRDCAGE PLANT HOLDER',), 266),
#  (('RED RETROSPOT OVEN GLOVE ',), 266),
#  (('JUMBO BAG WOODLAND ANIMALS', 'JUMBO BAG RED RETROSPOT'), 265),
#  (('LUNCH BAG VINTAGE LEAF DESIGN', 'LUNCH BAG RED RETROSPOT'), 265),
#  (('DOORMAT HOME SWEET HOME BLUE ',), 265),
#  (('PAPER BUNTING WHITE LACE',), 265),
#  (('ROUND CAKE TIN VINTAGE RED',), 265),
#  (('TEA PARTY BIRTHDAY CARD',), 265),
#  (('HAND OVER THE CHOCOLATE   SIGN ', 'COOK WITH WINE METAL SIGN '), 264),
#  (('LUNCH BAG DOLLY GIRL DESIGN', 'LUNCH BAG  BLACK SKULL.'), 264),
#  (('RED RETROSPOT ROUND CAKE TINS',), 264),
#  (('LUNCH BAG CARS BLUE',
#    'LUNCH BAG  BLACK SKULL.',
#    'LUNCH BAG RED RETROSPOT'),
#   263),
#  (('JUMBO BAG ALPHABET', 'JUMBO BAG VINTAGE LEAF'), 263),
#  (("6 GIFT TAGS 50'S CHRISTMAS ",), 263),
#  (("CHILDREN'S APRON DOLLY GIRL ",), 263),
#  (('LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG RED RETROSPOT'), 262),
#  (('LUNCH BAG PINK POLKADOT',
#    'LUNCH BAG CARS BLUE',
#    'LUNCH BAG  BLACK SKULL.'),
#   261),
#  (('HOT WATER BOTTLE TEA AND SYMPATHY', 'CHOCOLATE HOT WATER BOTTLE'), 261),
#  (('LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG SUKI DESIGN '), 261),
#  (('CIRCUS PARADE LUNCH BOX ',), 261),
#  (('FELTCRAFT GIRL AMELIE KIT',), 261),
#  (('LUNCH BAG WOODLAND',
#    'LUNCH BAG SPACEBOY DESIGN ',
#    'LUNCH BAG RED RETROSPOT'),
#   260),
#  (('JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO SHOPPER VINTAGE RED PAISLEY'),
#   260),
#  (('FOUR HOOK  WHITE LOVEBIRDS',), 260),
#  (('PACK OF 12 SUKI TISSUES ',), 260),
#  (('TOILET SIGN OCCUPIED OR VACANT',), 260),
#  (('RED FLORAL FELTCRAFT SHOULDER BAG',), 259),
#  (('LUNCH BAG CARS BLUE', 'JUMBO BAG RED RETROSPOT'), 258),
#  (('FAMILY PHOTO FRAME CORNICE',), 258),
#  (('FELTCRAFT DOLL ROSIE',), 258),
#  (('LUNCH BAG SPACEBOY DESIGN ',
#    'LUNCH BAG  BLACK SKULL.',
#    'LUNCH BAG RED RETROSPOT'),
#   257),
#  (('JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG PINK POLKADOT'), 257),
#  (('WOODEN FRAME ANTIQUE WHITE ', 'WHITE HANGING HEART T-LIGHT HOLDER'), 257),
#  (('BLACK/BLUE POLKADOT UMBRELLA',), 257),
#  (('GRAND CHOCOLATECANDLE',), 257),
#  (('ROBOT BIRTHDAY CARD',), 257),
#  (('BLUE HAPPY BIRTHDAY BUNTING', 'PINK HAPPY BIRTHDAY BUNTING'), 256),
#  (('LUNCH BAG DOLLY GIRL DESIGN', 'LUNCH BAG SUKI DESIGN '), 256),
#  (('PAINTED METAL PEARS ASSORTED', 'ASSORTED COLOUR BIRD ORNAMENT'), 256),
#  (('PLASTERS IN TIN CIRCUS PARADE ', 'PLASTERS IN TIN WOODLAND ANIMALS'), 256),
#  (('AIRLINE BAG VINTAGE TOKYO 78',), 256),
#  (('LAUNDRY 15C METAL SIGN',), 256),
#  (('SINGLE ANTIQUE ROSE HOOK IVORY',), 256),
#  (('LUNCH BAG SUKI DESIGN ',
#    'LUNCH BAG PINK POLKADOT',
#    'LUNCH BAG RED RETROSPOT'),
#   255),
#  (('CANDLEHOLDER PINK HANGING HEART', 'WHITE HANGING HEART T-LIGHT HOLDER'),
#   255),
#  (("POPPY'S PLAYHOUSE BEDROOM ", "POPPY'S PLAYHOUSE KITCHEN"), 255),
#  (('SET OF 3 REGENCY CAKE TINS', 'REGENCY CAKESTAND 3 TIER'), 255),
#  (('DOORMAT WELCOME PUPPIES',), 255),
#  (('TEA BAG PLATE RED RETROSPOT',), 255),
#  (('LUNCH BAG SUKI DESIGN ',
#    'LUNCH BAG  BLACK SKULL.',
#    'LUNCH BAG RED RETROSPOT'),
#   254),
#  (('ALARM CLOCK BAKELIKE ORANGE', 'ALARM CLOCK BAKELIKE RED '), 254),
#  (('JUMBO BAG RED RETROSPOT', 'WHITE HANGING HEART T-LIGHT HOLDER'), 254),
#  (('JUMBO STORAGE BAG SUKI', 'JUMBO SHOPPER VINTAGE RED PAISLEY'), 254),
#  (('6 GIFT TAGS VINTAGE CHRISTMAS ',), 254),
#  (("POPPY'S PLAYHOUSE LIVINGROOM ",), 254),
#  (('LUNCH BAG PINK POLKADOT',
#    'LUNCH BAG SPACEBOY DESIGN ',
#    'LUNCH BAG RED RETROSPOT'),
#   253),
#  (('JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG PINK POLKADOT'), 253),
#  (('LUNCH BAG DOLLY GIRL DESIGN', 'LUNCH BAG WOODLAND'), 253),
#  (('LUNCH BAG VINTAGE LEAF DESIGN', 'LUNCH BAG SUKI DESIGN '), 253),
#  (('HAPPY STENCIL CRAFT',), 253),
#  (('FELTCRAFT PRINCESS OLIVIA DOLL',), 252),
#  (('JUMBO BAG TOYS ',), 252),
#  (('PACK OF 12 RED RETROSPOT TISSUES ',), 252),
#  (('FANCY FONT BIRTHDAY CARD, ',), 251),
#  (('SET 3 RETROSPOT TEA,COFFEE,SUGAR',), 251),
#  (('SMALL HEART MEASURING SPOONS',), 251),
#  (('HAND OVER THE CHOCOLATE   SIGN ', 'GIN + TONIC DIET METAL SIGN'), 250),
#  (('VINTAGE HEADS AND TAILS CARD GAME ', 'VINTAGE SNAP CARDS'), 250),
#  (('ICE CREAM SUNDAE LIP GLOSS',), 250),
#  (('SET OF 3 WOODEN SLEIGH DECORATIONS',), 250),
#  (('JUMBO STORAGE BAG SKULLS', 'JUMBO BAG RED RETROSPOT'), 249),
#  (('10 COLOUR SPACEBOY PEN',), 249),
#  (('HEART FILIGREE DOVE  SMALL',), 249),
#  (('SET 12 RETRO WHITE CHALK STICKS',), 249),
#  (('WRAP ENGLISH ROSE ',), 249),
#  (('JUMBO SHOPPER VINTAGE RED PAISLEY', 'JUMBO BAG PINK POLKADOT'), 248),
#  (('LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG SPACEBOY DESIGN '), 248),
#  (('PACK OF 72 SKULL CAKE CASES', 'PACK OF 72 RETROSPOT CAKE CASES'), 248),
#  (('BAG 125g SWIRLY MARBLES',), 248),
#  (('PANTRY SCRUBBING BRUSH',), 248),
#  (('SET OF 3 WOODEN TREE DECORATIONS',), 248),
#  (('CHOCOLATE HOT WATER BOTTLE', 'HOT WATER BOTTLE KEEP CALM'), 247),
#  (('JAM MAKING SET WITH JARS', 'SET OF 3 CAKE TINS PANTRY DESIGN '), 247),
#  (('JUMBO BAG VINTAGE CHRISTMAS ', "JUMBO BAG 50'S CHRISTMAS "), 247),
#  (('LUNCH BAG DOLLY GIRL DESIGN', 'LUNCH BAG CARS BLUE'), 247),
#  (('LUNCH BAG VINTAGE LEAF DESIGN', 'LUNCH BAG ALPHABET DESIGN'), 247),
#  (('SET OF 12 MINI LOAF BAKING CASES', 'SET OF 12 FAIRY CAKE BAKING CASES'),
#   247),
#  (('CREAM CUPID HEARTS COAT HANGER',), 247),
#  (('FRENCH ENAMEL CANDLEHOLDER',), 247),
#  (('HOME SWEET HOME METAL SIGN ',), 247),
#  (('PARISIENNE KEY CABINET ',), 247),
#  (('ROLL WRAP VINTAGE CHRISTMAS',), 247),
#  (('ROLL WRAP VINTAGE SPOT ',), 247),
#  (('WHITE METAL LANTERN',), 247),
#  (('WOODEN CROQUET GARDEN SET',), 247),
#  (('JUMBO BAG PINK POLKADOT', 'LUNCH BAG PINK POLKADOT'), 246),
#  (('LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG  BLACK SKULL.'), 246),
#  (('PLASTERS IN TIN CIRCUS PARADE ', 'PLASTERS IN TIN SPACEBOY'), 246),
#  (('36 PENCILS TUBE RED RETROSPOT',), 246),
#  (('SET OF 3 CAKE TINS SKETCHBOOK',), 246),
#  (('LUNCH BAG VINTAGE DOILY ', 'LUNCH BAG RED RETROSPOT'), 245),
#  (('SET OF 3 BUTTERFLY COOKIE CUTTERS', 'SET OF 3 HEART COOKIE CUTTERS'), 245),
#  (('WOODLAND CHARLOTTE BAG', 'CHARLOTTE BAG SUKI DESIGN'), 245),
#  (('COLOUR GLASS. STAR T-LIGHT HOLDER',), 245),
#  (('LUNCH BAG VINTAGE LEAF DESIGN', 'LUNCH BAG  BLACK SKULL.'), 244),
#  (('DOORMAT FAIRY CAKE',), 244),
#  (('JAZZ HEARTS PURSE NOTEBOOK',), 244),
#  (('PICTURE DOMINOES',), 244),
#  (('VICTORIAN SEWING BOX SMALL ',), 244),
#  (('VINTAGE CREAM CAT FOOD CONTAINER',), 244),
#  (('JUMBO BAG SCANDINAVIAN BLUE PAISLEY', 'JUMBO BAG PINK VINTAGE PAISLEY'),
#   243),
#  (('RED RETROSPOT CHARLOTTE BAG', 'LUNCH BAG RED RETROSPOT'), 243),
#  (('BATH BUILDING BLOCK WORD',), 243),
#  (('SET OF 36 TEATIME PAPER DOILIES',), 243),
#  (('TEA TIME OVEN GLOVE',), 243),
#  (('JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO STORAGE BAG SUKI'), 242),
#  (('BUNDLE OF 3 RETRO NOTE BOOKS',), 242),
#  (('PARISIENNE JEWELLERY DRAWER ',), 242),
#  (('POTTING SHED TEA MUG',), 242),
#  (('SWALLOWS GREETING CARD',), 242),
#  (('PINK REGENCY TEACUP AND SAUCER',
#    'GREEN REGENCY TEACUP AND SAUCER',
#    'ROSES REGENCY TEACUP AND SAUCER ',
#    'REGENCY CAKESTAND 3 TIER'),
#   241),
#  (('GIN + TONIC DIET METAL SIGN', 'PLEASE ONE PERSON METAL SIGN'), 241),
#  (('HAND WARMER SCOTTY DOG DESIGN', 'HAND WARMER BIRD DESIGN'), 241),
#  (('JUMBO BAG PEARS', 'JUMBO BAG VINTAGE LEAF'), 241),
#  (('SCOTTIE DOG HOT WATER BOTTLE', 'CHOCOLATE HOT WATER BOTTLE'), 241),
#  (('GROW A FLYTRAP OR SUNFLOWER IN TIN',), 241),
#  (('PICNIC BASKET WICKER SMALL',), 241),
#  (('SET OF 4 KNICK KNACK TINS LONDON ',), 241),
#  (('LUNCH BAG WOODLAND', 'LUNCH BAG PINK POLKADOT', 'LUNCH BAG RED RETROSPOT'),
#   240),
#  (('JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO SHOPPER VINTAGE RED PAISLEY'),
#   240),
#  (('JUMBO STORAGE BAG SUKI', 'LUNCH BAG RED RETROSPOT'), 240),
#  (('CHRISTMAS STAR WISH LIST CHALKBOARD',), 240),
#  (('DOORSTOP RETROSPOT HEART',), 240),
#  (('RECIPE BOX BLUE SKETCHBOOK DESIGN',), 240),
#  (('RETROSPOT RED WASHING UP GLOVES',), 240),
#  (('ZINC T-LIGHT HOLDER STARS SMALL',), 240),
#  (('LUNCH BAG SUKI DESIGN ', 'LUNCH BAG CARS BLUE', 'LUNCH BAG RED RETROSPOT'),
#   239),
#  (('JUMBO BAG PINK POLKADOT', 'LUNCH BAG RED RETROSPOT'), 239),
#  (('REGENCY CAKESTAND 3 TIER', 'WHITE HANGING HEART T-LIGHT HOLDER'), 239),
#  (('COFFEE MUG APPLES DESIGN',), 239),
#  (('GIRAFFE WOODEN RULER',), 239),
#  (('SET OF 2 TEA TOWELS APPLE AND PEARS',), 239),
#  (('FELTCRAFT PRINCESS LOLA DOLL', 'FELTCRAFT PRINCESS CHARLOTTE DOLL'), 238),
#  (('LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG CARS BLUE'), 238),
#  (('ROUND SNACK BOXES SET OF4 WOODLAND ', 'POSTAGE'), 238),
#  (('BISCUIT TIN VINTAGE CHRISTMAS',), 238),
#  (('LARGE CERAMIC TOP STORAGE JAR',), 238),
#  (('QUEENS GUARD COFFEE MUG',), 238),
#  (('LUNCH BAG CARS BLUE',
#    'LUNCH BAG SPACEBOY DESIGN ',
#    'LUNCH BAG RED RETROSPOT'),
#   237),
#  (('ALARM CLOCK BAKELIKE IVORY', 'ALARM CLOCK BAKELIKE PINK'), 237),
#  (('STRAWBERRY CHARLOTTE BAG', 'CHARLOTTE BAG SUKI DESIGN'), 237),
#  (('12 PENCILS TALL TUBE RED RETROSPOT',), 237),
#  (('CERAMIC HEART FAIRY CAKE MONEY BANK',), 237),
#  (('MINIATURE ANTIQUE ROSE HOOK IVORY',), 237),
#  (('SET OF 6 HERB TINS SKETCHBOOK',), 237),
#  (('VINTAGE DOILY JUMBO BAG RED ',), 237),
#  (('WATERING CAN PINK BUNNY',), 237),
#  (('HAND OVER THE CHOCOLATE   SIGN ', 'PLEASE ONE PERSON METAL SIGN'), 236),
#  (('LUNCH BAG DOLLY GIRL DESIGN', 'LUNCH BAG PINK POLKADOT'), 236),
#  (('PINK BLUE FELT CRAFT TRINKET BOX', 'PINK CREAM FELT CRAFT TRINKET BOX '),
#   236),
#  (('SET/6 RED SPOTTY PAPER CUPS', 'SET/6 RED SPOTTY PAPER PLATES'), 236),
#  (('15CM CHRISTMAS GLASS BALL 20 LIGHTS',), 236),
#  (('BOX OF VINTAGE ALPHABET BLOCKS',), 236),
#  (('DELUXE SEWING KIT ',), 236),
#  (('LUNCH BAG WOODLAND', 'LUNCH BAG CARS BLUE', 'LUNCH BAG RED RETROSPOT'),
#   235),
#  (('LUNCH BAG SUKI DESIGN ', 'JUMBO BAG RED RETROSPOT'), 235),
#  (('CALENDAR PAPER CUT DESIGN',), 235),
#  (('KEY FOB , BACK DOOR ',), 235),
#  (('SET OF 36 PAISLEY FLOWER DOILIES',), 235),
#  (('LUNCH BAG ALPHABET DESIGN', 'JUMBO BAG ALPHABET'), 234),
#  (('PHOTO FRAME 3 CLASSIC HANGING',), 234),
#  (('WRAP ALPHABET DESIGN',), 234),
#  (('JUMBO BAG STRAWBERRY',
#    'JUMBO BAG PINK POLKADOT',
#    'JUMBO BAG RED RETROSPOT'),
#   233),
#  (('RETROSPOT TEA SET CERAMIC 11 PC ', 'BAKING SET 9 PIECE RETROSPOT '), 233),
#  (('FELTCRAFT DOLL EMILY',), 233),
#  (('REGENCY TEA PLATE PINK',), 233),
#  (('TRIPLE HOOK ANTIQUE IVORY ROSE',), 233),
#  (('WOODEN HAPPY BIRTHDAY GARLAND',), 233),
#  (('LUNCH BAG WOODLAND', 'LUNCH BAG  BLACK SKULL.', 'LUNCH BAG RED RETROSPOT'),
#   232),
#  (('CHARLOTTE BAG PINK POLKADOT', 'CHARLOTTE BAG SUKI DESIGN'), 232),
#  (('PARTY BUNTING', 'REGENCY CAKESTAND 3 TIER'), 232),
#  (('REGENCY TEA PLATE GREEN ', 'REGENCY TEA PLATE ROSES '), 232),
#  (('PINK FLORAL FELTCRAFT SHOULDER BAG',), 232),
#  (('SET 12 COLOUR PENCILS SPACEBOY ',), 232),
#  (('STRAWBERRY SHOPPER BAG',), 232),
#  (('LUNCH BAG SUKI DESIGN ',
#    'LUNCH BAG SPACEBOY DESIGN ',
#    'LUNCH BAG RED RETROSPOT'),
#   231),
#  (('ASSORTED COLOUR BIRD ORNAMENT', 'REGENCY CAKESTAND 3 TIER'), 231),
#  (('MAGNETS PACK OF 4 SWALLOWS',), 231),
#  (('TRADITIONAL PICK UP STICKS GAME ',), 231),
#  (('ALARM CLOCK BAKELIKE CHOCOLATE', 'ALARM CLOCK BAKELIKE RED '), 230),
#  (('CHILDRENS CUTLERY RETROSPOT RED ',), 230),
#  (('FANCY FONTS BIRTHDAY WRAP',), 230),
#  (('PICTURE FRAME WOOD TRIPLE PORTRAIT',), 230),
#  (('SET/10 BLUE POLKADOT PARTY CANDLES',), 230),
#  (('HOT WATER BOTTLE TEA AND SYMPATHY', 'HOT WATER BOTTLE KEEP CALM'), 229),
#  (('SET/6 RED SPOTTY PAPER PLATES', 'SET/20 RED RETROSPOT PAPER NAPKINS '),
#   229),
#  (('CHOCOLATE BOX RIBBONS ',), 229),
#  (('72 SWEETHEART FAIRY CAKE CASES', 'PACK OF 72 RETROSPOT CAKE CASES'), 228),
#  (('JUMBO BAG VINTAGE DOILY ', 'JUMBO BAG VINTAGE LEAF'), 228),
#  (('LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG PINK POLKADOT'), 228),
#  (('LUNCH BAG VINTAGE LEAF DESIGN', 'LUNCH BAG SPACEBOY DESIGN '), 228),
#  (('RED METAL BOX TOP SECRET',), 228),
#  (('RIBBON REEL HEARTS DESIGN ',), 228),
#  (('JUMBO BAG APPLES', 'JUMBO BAG PINK POLKADOT'), 227),
#  (('LUNCH BAG RED RETROSPOT', 'WHITE HANGING HEART T-LIGHT HOLDER'), 227),
#  (('LUNCH BAG VINTAGE DOILY ', 'JUMBO BAG VINTAGE DOILY '), 227),
#  (('TOILET METAL SIGN', 'BATHROOM METAL SIGN'), 227),
#  (('WOODEN TREE CHRISTMAS SCANDINAVIAN', 'WOODEN STAR CHRISTMAS SCANDINAVIAN'),
#   227),
#  (('RED RETROSPOT BUTTER DISH',), 227),
#  (('LUNCH BAG PINK POLKADOT',
#    'LUNCH BAG SPACEBOY DESIGN ',
#    'LUNCH BAG  BLACK SKULL.'),
#   226),
#  (('SET OF 3 CAKE TINS PANTRY DESIGN ', 'REGENCY CAKESTAND 3 TIER'), 226),
#  (('SMALL MARSHMALLOWS PINK BOWL', 'SMALL DOLLY MIX DESIGN ORANGE BOWL'), 226),
#  (('CHILDS BREAKFAST SET SPACEBOY ',), 226),
#  (('CLASSIC CAFE SUGAR DISPENSER',), 226),
#  (('RED GINGHAM ROSE JEWELLERY BOX',), 226),
#  (('RED RETROSPOT PLATE ',), 226),
#  (('LUNCH BAG PINK POLKADOT',
#    'LUNCH BAG CARS BLUE',
#    'LUNCH BAG SPACEBOY DESIGN '),
#   225),
#  (('LUNCH BAG WOODLAND', 'LUNCH BAG SUKI DESIGN ', 'LUNCH BAG RED RETROSPOT'),
#   225),
#  (('LUNCH BAG APPLE DESIGN', 'JUMBO BAG RED RETROSPOT'), 225),
#  (('BLUE POLKADOT BOWL',), 225),
#  (('TRIPLE PHOTO FRAME CORNICE ',), 225),
#  (('LUNCH BAG CARS BLUE',
#    'LUNCH BAG SPACEBOY DESIGN ',
#    'LUNCH BAG  BLACK SKULL.'),
#   224),
#  (('ALARM CLOCK BAKELIKE ORANGE', 'ALARM CLOCK BAKELIKE GREEN'), 224),
#  (('BOX OF VINTAGE JIGSAW BLOCKS ',), 224),
#  (('JUMBO STORAGE BAG SUKI',
#    'JUMBO BAG PINK POLKADOT',
#    'JUMBO BAG RED RETROSPOT'),
#   223),
#  (('LUNCH BAG SUKI DESIGN ', 'LUNCH BAG CARS BLUE', 'LUNCH BAG  BLACK SKULL.'),
#   223),
#  (('LUNCH BAG SUKI DESIGN ',
#    'LUNCH BAG PINK POLKADOT',
#    'LUNCH BAG  BLACK SKULL.'),
#   223),
#  (('72 SWEETHEART FAIRY CAKE CASES', '60 TEATIME FAIRY CAKE CASES'), 223),
#  (('JUMBO STORAGE BAG SUKI', 'LUNCH BAG SUKI DESIGN '), 223),
#  (('PACK OF 60 DINOSAUR CAKE CASES', '60 TEATIME FAIRY CAKE CASES'), 223),
#  (('RETROSPOT HEART HOT WATER BOTTLE', 'SCOTTIE DOG HOT WATER BOTTLE'), 222),
#  (('ENGLISH ROSE NOTEBOOK A7 SIZE',), 222),
#  (('PEG BAG APPLES DESIGN',), 222),
#  (('RECYCLED ACAPULCO MAT TURQUOISE',), 222)]

# %%
assoc_ex11 = assoc(fim_, 0.2, len(db))
# Out:
# KEY:  ('GREEN REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER ')
# Ante:['GREEN REGENCY TEACUP AND SAUCER'], cons:['ROSES REGENCY TEACUP AND SAUCER ']
# 	 CONF: 0.7598908594815825
# 	 LIFT: 20.16983034915827
# Ante:['ROSES REGENCY TEACUP AND SAUCER '], cons:['GREEN REGENCY TEACUP AND SAUCER']
# 	 CONF: 0.666267942583732
# 	 LIFT: 20.16983034915827
#
# KEY:  ('JUMBO BAG PINK POLKADOT', 'JUMBO BAG RED RETROSPOT')
# Ante:['JUMBO BAG PINK POLKADOT'], cons:['JUMBO BAG RED RETROSPOT']
# 	 CONF: 0.6266968325791855
# 	 LIFT: 8.464030867274575
# Ante:['JUMBO BAG RED RETROSPOT'], cons:['JUMBO BAG PINK POLKADOT']
# 	 CONF: 0.3371880706025563
# 	 LIFT: 8.464030867274575
#
# KEY:  ('ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE RED ')
# Ante:['ALARM CLOCK BAKELIKE GREEN'], cons:['ALARM CLOCK BAKELIKE RED ']
# 	 CONF: 0.6625463535228677
# 	 LIFT: 16.20937550680533
# Ante:['ALARM CLOCK BAKELIKE RED '], cons:['ALARM CLOCK BAKELIKE GREEN']
# 	 CONF: 0.5909592061742006
# 	 LIFT: 16.20937550680533
#
# KEY:  ('LUNCH BAG PINK POLKADOT', 'LUNCH BAG RED RETROSPOT')
# Ante:['LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.5573080967402734
# 	 LIFT: 9.305242036619012
# Ante:['LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.39879608728367194
# 	 LIFT: 9.305242036619012
#
# KEY:  ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG RED RETROSPOT')
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.4874184529356943
# 	 LIFT: 8.138311114103129
# Ante:['LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.3935289691497366
# 	 LIFT: 8.138311114103127
#
# KEY:  ('WOODEN FRAME ANTIQUE WHITE ', 'WOODEN PICTURE FRAME WHITE FINISH')
# Ante:['WOODEN FRAME ANTIQUE WHITE '], cons:['WOODEN PICTURE FRAME WHITE FINISH']
# 	 CONF: 0.5738498789346247
# 	 LIFT: 14.243544534182687
# Ante:['WOODEN PICTURE FRAME WHITE FINISH'], cons:['WOODEN FRAME ANTIQUE WHITE ']
# 	 CONF: 0.5302013422818792
# 	 LIFT: 14.243544534182686
#
# KEY:  ('GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER')
# Ante:['GREEN REGENCY TEACUP AND SAUCER'], cons:['PINK REGENCY TEACUP AND SAUCER']
# 	 CONF: 0.6425648021828103
# 	 LIFT: 24.12607945928352
# Ante:['PINK REGENCY TEACUP AND SAUCER'], cons:['GREEN REGENCY TEACUP AND SAUCER']
# 	 CONF: 0.7969543147208121
# 	 LIFT: 24.12607945928352
#
# KEY:  ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG SPACEBOY DESIGN ')
# Ante:['LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG SPACEBOY DESIGN ']
# 	 CONF: 0.35364936042136946
# 	 LIFT: 7.839639668082106
# Ante:['LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.4695304695304695
# 	 LIFT: 7.839639668082106
#
# KEY:  ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG PINK POLKADOT')
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.43522833178005593
# 	 LIFT: 10.155327741534638
# Ante:['LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.491062039957939
# 	 LIFT: 10.155327741534638
#
# KEY:  ('GARDENERS KNEELING PAD CUP OF TEA ', 'GARDENERS KNEELING PAD KEEP CALM ')
# Ante:['GARDENERS KNEELING PAD CUP OF TEA '], cons:['GARDENERS KNEELING PAD KEEP CALM ']
# 	 CONF: 0.7258566978193146
# 	 LIFT: 20.999687255033365
# Ante:['GARDENERS KNEELING PAD KEEP CALM '], cons:['GARDENERS KNEELING PAD CUP OF TEA ']
# 	 CONF: 0.6075619295958279
# 	 LIFT: 20.999687255033365
#
# KEY:  ('LUNCH BAG CARS BLUE', 'LUNCH BAG RED RETROSPOT')
# Ante:['LUNCH BAG CARS BLUE'], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.47017189079878663
# 	 LIFT: 7.850349327934595
# Ante:['LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.34988713318284426
# 	 LIFT: 7.850349327934595
#
# KEY:  ('RED HANGING HEART T-LIGHT HOLDER', 'WHITE HANGING HEART T-LIGHT HOLDER')
# Ante:['RED HANGING HEART T-LIGHT HOLDER'], cons:['WHITE HANGING HEART T-LIGHT HOLDER']
# 	 CONF: 0.6647398843930635
# 	 LIFT: 7.327659232330889
# Ante:['WHITE HANGING HEART T-LIGHT HOLDER'], cons:['RED HANGING HEART T-LIGHT HOLDER']
# 	 CONF: 0.22851465474416294
# 	 LIFT: 7.327659232330889
#
# KEY:  ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG SUKI DESIGN ')
# Ante:['LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG SUKI DESIGN ']
# 	 CONF: 0.3438675696012039
# 	 LIFT: 8.330154333461477
# Ante:['LUNCH BAG SUKI DESIGN '], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.49890829694323147
# 	 LIFT: 8.33015433346148
#
# KEY:  ("PAPER CHAIN KIT 50'S CHRISTMAS ", 'PAPER CHAIN KIT VINTAGE CHRISTMAS')
# Ante:["PAPER CHAIN KIT 50'S CHRISTMAS "], cons:['PAPER CHAIN KIT VINTAGE CHRISTMAS']
# 	 CONF: 0.4585858585858586
# 	 LIFT: 14.352637802567282
# Ante:['PAPER CHAIN KIT VINTAGE CHRISTMAS'], cons:["PAPER CHAIN KIT 50'S CHRISTMAS "]
# 	 CONF: 0.6403385049365303
# 	 LIFT: 14.35263780256728
#
# KEY:  ('PINK REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER ')
# Ante:['PINK REGENCY TEACUP AND SAUCER'], cons:['ROSES REGENCY TEACUP AND SAUCER ']
# 	 CONF: 0.7631133671742809
# 	 LIFT: 20.25536557128863
# Ante:['ROSES REGENCY TEACUP AND SAUCER '], cons:['PINK REGENCY TEACUP AND SAUCER']
# 	 CONF: 0.5394736842105263
# 	 LIFT: 20.25536557128863
#
# KEY:  ('JUMBO BAG RED RETROSPOT', 'JUMBO STORAGE BAG SUKI')
# Ante:['JUMBO BAG RED RETROSPOT'], cons:['JUMBO STORAGE BAG SUKI']
# 	 CONF: 0.2696287279367012
# 	 LIFT: 7.563920951852591
# Ante:['JUMBO STORAGE BAG SUKI'], cons:['JUMBO BAG RED RETROSPOT']
# 	 CONF: 0.5600505689001264
# 	 LIFT: 7.563920951852589
#
# KEY:  ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG WOODLAND')
# Ante:['LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG WOODLAND']
# 	 CONF: 0.3303235515425132
# 	 LIFT: 8.736447686207827
# Ante:['LUNCH BAG WOODLAND'], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.5232419547079857
# 	 LIFT: 8.736447686207828
#
# KEY:  ('JUMBO BAG RED RETROSPOT', 'LUNCH BAG RED RETROSPOT')
# Ante:['JUMBO BAG RED RETROSPOT'], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.2641509433962264
# 	 LIFT: 4.41046609026506
# Ante:['LUNCH BAG RED RETROSPOT'], cons:['JUMBO BAG RED RETROSPOT']
# 	 CONF: 0.326561324303988
# 	 LIFT: 4.41046609026506
#
# KEY:  ('LUNCH BAG CARS BLUE', 'LUNCH BAG PINK POLKADOT')
# Ante:['LUNCH BAG CARS BLUE'], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.4368048533872599
# 	 LIFT: 10.19211324570273
# Ante:['LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.45425867507886436
# 	 LIFT: 10.19211324570273
#
# KEY:  ('REGENCY CAKESTAND 3 TIER', 'ROSES REGENCY TEACUP AND SAUCER ')
# Ante:['REGENCY CAKESTAND 3 TIER'], cons:['ROSES REGENCY TEACUP AND SAUCER ']
# 	 CONF: 0.22929936305732485
# 	 LIFT: 6.086307256270381
# Ante:['ROSES REGENCY TEACUP AND SAUCER '], cons:['REGENCY CAKESTAND 3 TIER']
# 	 CONF: 0.5167464114832536
# 	 LIFT: 6.0863072562703815
#
# KEY:  ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG CARS BLUE')
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.3960857409133271
# 	 LIFT: 8.886898474081626
# Ante:['LUNCH BAG CARS BLUE'], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.42972699696663297
# 	 LIFT: 8.886898474081628
#
# KEY:  ('DOLLY GIRL LUNCH BOX', 'SPACEBOY LUNCH BOX ')
# Ante:['DOLLY GIRL LUNCH BOX'], cons:['SPACEBOY LUNCH BOX ']
# 	 CONF: 0.6784
# 	 LIFT: 21.142831460674156
# Ante:['SPACEBOY LUNCH BOX '], cons:['DOLLY GIRL LUNCH BOX']
# 	 CONF: 0.5955056179775281
# 	 LIFT: 21.142831460674156
#
# KEY:  ('JUMBO BAG RED RETROSPOT', 'JUMBO BAG STRAWBERRY')
# Ante:['JUMBO BAG RED RETROSPOT'], cons:['JUMBO BAG STRAWBERRY']
# 	 CONF: 0.25684723067559345
# 	 LIFT: 8.544887629222517
# Ante:['JUMBO BAG STRAWBERRY'], cons:['JUMBO BAG RED RETROSPOT']
# 	 CONF: 0.6326836581709145
# 	 LIFT: 8.544887629222515
#
# KEY:  ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG SPACEBOY DESIGN ')
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['LUNCH BAG SPACEBOY DESIGN ']
# 	 CONF: 0.39049394221808015
# 	 LIFT: 8.656404173645553
# Ante:['LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.41858141858141856
# 	 LIFT: 8.656404173645553
#
# KEY:  ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG SUKI DESIGN ')
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['LUNCH BAG SUKI DESIGN ']
# 	 CONF: 0.3830382106244175
# 	 LIFT: 9.279058835977974
# Ante:['LUNCH BAG SUKI DESIGN '], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.44868995633187775
# 	 LIFT: 9.279058835977976
#
# KEY:  ('LUNCH BAG SPACEBOY DESIGN ', 'LUNCH BAG WOODLAND')
# Ante:['LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG WOODLAND']
# 	 CONF: 0.4085914085914086
# 	 LIFT: 10.806487910182783
# Ante:['LUNCH BAG WOODLAND'], cons:['LUNCH BAG SPACEBOY DESIGN ']
# 	 CONF: 0.48748510131108463
# 	 LIFT: 10.806487910182785
#
# KEY:  ('HEART OF WICKER LARGE', 'HEART OF WICKER SMALL')
# Ante:['HEART OF WICKER LARGE'], cons:['HEART OF WICKER SMALL']
# 	 CONF: 0.49938800489596086
# 	 LIFT: 11.40063768378742
# Ante:['HEART OF WICKER SMALL'], cons:['HEART OF WICKER LARGE']
# 	 CONF: 0.41975308641975306
# 	 LIFT: 11.400637683787417
#
# KEY:  ('ALARM CLOCK BAKELIKE PINK', 'ALARM CLOCK BAKELIKE RED ')
# Ante:['ALARM CLOCK BAKELIKE PINK'], cons:['ALARM CLOCK BAKELIKE RED ']
# 	 CONF: 0.6406995230524642
# 	 LIFT: 15.674886898053122
# Ante:['ALARM CLOCK BAKELIKE RED '], cons:['ALARM CLOCK BAKELIKE PINK']
# 	 CONF: 0.44432194046306506
# 	 LIFT: 15.674886898053122
#
# KEY:  ('JUMBO BAG RED RETROSPOT', 'JUMBO SHOPPER VINTAGE RED PAISLEY')
# Ante:['JUMBO BAG RED RETROSPOT'], cons:['JUMBO SHOPPER VINTAGE RED PAISLEY']
# 	 CONF: 0.24284844796104688
# 	 LIFT: 6.727599326161836
# Ante:['JUMBO SHOPPER VINTAGE RED PAISLEY'], cons:['JUMBO BAG RED RETROSPOT']
# 	 CONF: 0.49812734082397003
# 	 LIFT: 6.727599326161835
#
# KEY:  ('GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER ')
# Ante:['GREEN REGENCY TEACUP AND SAUCER'], cons:['PINK REGENCY TEACUP AND SAUCER']
# 	 CONF: 0.6425648021828103
# 	 LIFT: 24.12607945928352
# Ante:['GREEN REGENCY TEACUP AND SAUCER'], cons:['ROSES REGENCY TEACUP AND SAUCER ']
# 	 CONF: 0.7598908594815825
# 	 LIFT: 20.16983034915827
# Ante:['PINK REGENCY TEACUP AND SAUCER'], cons:['GREEN REGENCY TEACUP AND SAUCER']
# 	 CONF: 0.7969543147208121
# 	 LIFT: 24.12607945928352
# Ante:['PINK REGENCY TEACUP AND SAUCER'], cons:['ROSES REGENCY TEACUP AND SAUCER ']
# 	 CONF: 0.7631133671742809
# 	 LIFT: 20.25536557128863
# Ante:['ROSES REGENCY TEACUP AND SAUCER '], cons:['GREEN REGENCY TEACUP AND SAUCER']
# 	 CONF: 0.666267942583732
# 	 LIFT: 20.16983034915827
# Ante:['ROSES REGENCY TEACUP AND SAUCER '], cons:['PINK REGENCY TEACUP AND SAUCER']
# 	 CONF: 0.5394736842105263
# 	 LIFT: 20.25536557128863
# Ante:['GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER'], cons:['ROSES REGENCY TEACUP AND SAUCER ']
# 	 CONF: 0.8428874734607219
# 	 LIFT: 22.37281463647538
# Ante:['GREEN REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER '], cons:['PINK REGENCY TEACUP AND SAUCER']
# 	 CONF: 0.7127468581687613
# 	 LIFT: 26.761172221260257
# Ante:['PINK REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER '], cons:['GREEN REGENCY TEACUP AND SAUCER']
# 	 CONF: 0.8802660753880266
# 	 LIFT: 26.648164001173683
#
# KEY:  ('LUNCH BAG CARS BLUE', 'LUNCH BAG SPACEBOY DESIGN ')
# Ante:['LUNCH BAG CARS BLUE'], cons:['LUNCH BAG SPACEBOY DESIGN ']
# 	 CONF: 0.3993933265925177
# 	 LIFT: 8.853684232855112
# Ante:['LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.3946053946053946
# 	 LIFT: 8.853684232855112
#
# KEY:  ('LUNCH BAG CARS BLUE', 'LUNCH BAG SUKI DESIGN ')
# Ante:['LUNCH BAG CARS BLUE'], cons:['LUNCH BAG SUKI DESIGN ']
# 	 CONF: 0.39838220424671383
# 	 LIFT: 9.650765406369628
# Ante:['LUNCH BAG SUKI DESIGN '], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.43013100436681223
# 	 LIFT: 9.65076540636963
#
# KEY:  ('PARTY BUNTING', 'SPOTTY BUNTING')
# Ante:['PARTY BUNTING'], cons:['SPOTTY BUNTING']
# 	 CONF: 0.2809149392423159
# 	 LIFT: 6.141381775159596
# Ante:['SPOTTY BUNTING'], cons:['PARTY BUNTING']
# 	 CONF: 0.387192118226601
# 	 LIFT: 6.141381775159596
#
# KEY:  ('LUNCH BAG APPLE DESIGN', 'LUNCH BAG RED RETROSPOT')
# Ante:['LUNCH BAG APPLE DESIGN'], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.44646924829157175
# 	 LIFT: 7.4545918883295545
# Ante:['LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG APPLE DESIGN']
# 	 CONF: 0.2949586155003762
# 	 LIFT: 7.4545918883295545
#
# KEY:  ('GREEN REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER')
# Ante:['GREEN REGENCY TEACUP AND SAUCER'], cons:['REGENCY CAKESTAND 3 TIER']
# 	 CONF: 0.5225102319236017
# 	 LIFT: 6.154194292136264
# Ante:['REGENCY CAKESTAND 3 TIER'], cons:['GREEN REGENCY TEACUP AND SAUCER']
# 	 CONF: 0.20329087048832273
# 	 LIFT: 6.154194292136264
#
# KEY:  ('LUNCH BAG SPACEBOY DESIGN ', 'LUNCH BAG SUKI DESIGN ')
# Ante:['LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG SUKI DESIGN ']
# 	 CONF: 0.38161838161838163
# 	 LIFT: 9.244663633309921
# Ante:['LUNCH BAG SUKI DESIGN '], cons:['LUNCH BAG SPACEBOY DESIGN ']
# 	 CONF: 0.4170305676855895
# 	 LIFT: 9.244663633309921
#
# KEY:  ('JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG RED RETROSPOT')
# Ante:['JUMBO  BAG BAROQUE BLACK WHITE'], cons:['JUMBO BAG RED RETROSPOT']
# 	 CONF: 0.5580693815987934
# 	 LIFT: 7.537163467849802
# Ante:['JUMBO BAG RED RETROSPOT'], cons:['JUMBO  BAG BAROQUE BLACK WHITE']
# 	 CONF: 0.22519780888618382
# 	 LIFT: 7.537163467849802
#
# KEY:  ('LUNCH BAG PINK POLKADOT', 'LUNCH BAG SPACEBOY DESIGN ')
# Ante:['LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG SPACEBOY DESIGN ']
# 	 CONF: 0.3890641430073607
# 	 LIFT: 8.624708624708624
# Ante:['LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.3696303696303696
# 	 LIFT: 8.624708624708624
#
# KEY:  ('LUNCH BAG CARS BLUE', 'LUNCH BAG WOODLAND')
# Ante:['LUNCH BAG CARS BLUE'], cons:['LUNCH BAG WOODLAND']
# 	 CONF: 0.3731041456016178
# 	 LIFT: 9.867915364600595
# Ante:['LUNCH BAG WOODLAND'], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.4398092967818832
# 	 LIFT: 9.867915364600595
#
# KEY:  ('LUNCH BAG APPLE DESIGN', 'LUNCH BAG SUKI DESIGN ')
# Ante:['LUNCH BAG APPLE DESIGN'], cons:['LUNCH BAG SUKI DESIGN ']
# 	 CONF: 0.4123006833712984
# 	 LIFT: 9.987939043678068
# Ante:['LUNCH BAG SUKI DESIGN '], cons:['LUNCH BAG APPLE DESIGN']
# 	 CONF: 0.3951965065502183
# 	 LIFT: 9.98793904367807
#
# KEY:  ('LUNCH BAG PINK POLKADOT', 'LUNCH BAG SUKI DESIGN ')
# Ante:['LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG SUKI DESIGN ']
# 	 CONF: 0.38065194532071506
# 	 LIFT: 9.221251819505094
# Ante:['LUNCH BAG SUKI DESIGN '], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.3951965065502183
# 	 LIFT: 9.221251819505094
#
# KEY:  ('JUMBO BAG APPLES', 'JUMBO BAG RED RETROSPOT')
# Ante:['JUMBO BAG APPLES'], cons:['JUMBO BAG RED RETROSPOT']
# 	 CONF: 0.4871447902571042
# 	 LIFT: 6.579271391238675
# Ante:['JUMBO BAG RED RETROSPOT'], cons:['JUMBO BAG APPLES']
# 	 CONF: 0.21911138161898966
# 	 LIFT: 6.579271391238675
#
# KEY:  ('LUNCH BAG DOLLY GIRL DESIGN', 'LUNCH BAG SPACEBOY DESIGN ')
# Ante:['LUNCH BAG DOLLY GIRL DESIGN'], cons:['LUNCH BAG SPACEBOY DESIGN ']
# 	 CONF: 0.5884297520661157
# 	 LIFT: 13.044211986360747
# Ante:['LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG DOLLY GIRL DESIGN']
# 	 CONF: 0.35564435564435565
# 	 LIFT: 13.044211986360747
#
# KEY:  ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG WOODLAND')
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['LUNCH BAG WOODLAND']
# 	 CONF: 0.32805219012115566
# 	 LIFT: 8.676374372811017
# Ante:['LUNCH BAG WOODLAND'], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.4195470798569726
# 	 LIFT: 8.676374372811019
#
# KEY:  ('JUMBO BAG RED RETROSPOT', 'JUMBO BAG VINTAGE LEAF')
# Ante:['JUMBO BAG RED RETROSPOT'], cons:['JUMBO BAG VINTAGE LEAF']
# 	 CONF: 0.21119902617163724
# 	 LIFT: 6.023787134638343
# Ante:['JUMBO BAG VINTAGE LEAF'], cons:['JUMBO BAG RED RETROSPOT']
# 	 CONF: 0.44601542416452444
# 	 LIFT: 6.023787134638343
#
# KEY:  ('ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE PINK')
# Ante:['ALARM CLOCK BAKELIKE GREEN'], cons:['ALARM CLOCK BAKELIKE PINK']
# 	 CONF: 0.4252163164400494
# 	 LIFT: 15.00087450207424
# Ante:['ALARM CLOCK BAKELIKE PINK'], cons:['ALARM CLOCK BAKELIKE GREEN']
# 	 CONF: 0.5468998410174881
# 	 LIFT: 15.000874502074241
#
# KEY:  ('PACK OF 60 PINK PAISLEY CAKE CASES', 'PACK OF 72 RETROSPOT CAKE CASES')
# Ante:['PACK OF 60 PINK PAISLEY CAKE CASES'], cons:['PACK OF 72 RETROSPOT CAKE CASES']
# 	 CONF: 0.5007407407407407
# 	 LIFT: 10.67381079446401
# Ante:['PACK OF 72 RETROSPOT CAKE CASES'], cons:['PACK OF 60 PINK PAISLEY CAKE CASES']
# 	 CONF: 0.32468780019212296
# 	 LIFT: 10.673810794464012
#
# KEY:  ('JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG RED RETROSPOT')
# Ante:['JUMBO BAG PINK VINTAGE PAISLEY'], cons:['JUMBO BAG RED RETROSPOT']
# 	 CONF: 0.5456026058631922
# 	 LIFT: 7.3687899112016035
# Ante:['JUMBO BAG RED RETROSPOT'], cons:['JUMBO BAG PINK VINTAGE PAISLEY']
# 	 CONF: 0.20389531345100426
# 	 LIFT: 7.3687899112016035
#
# KEY:  ('60 TEATIME FAIRY CAKE CASES', 'PACK OF 72 RETROSPOT CAKE CASES')
# Ante:['60 TEATIME FAIRY CAKE CASES'], cons:['PACK OF 72 RETROSPOT CAKE CASES']
# 	 CONF: 0.5030120481927711
# 	 LIFT: 10.722226080112959
# Ante:['PACK OF 72 RETROSPOT CAKE CASES'], cons:['60 TEATIME FAIRY CAKE CASES']
# 	 CONF: 0.3208453410182517
# 	 LIFT: 10.722226080112959
#
# KEY:  ('CHARLOTTE BAG PINK POLKADOT', 'RED RETROSPOT CHARLOTTE BAG')
# Ante:['CHARLOTTE BAG PINK POLKADOT'], cons:['RED RETROSPOT CHARLOTTE BAG']
# 	 CONF: 0.6468253968253969
# 	 LIFT: 19.01066961000736
# Ante:['RED RETROSPOT CHARLOTTE BAG'], cons:['CHARLOTTE BAG PINK POLKADOT']
# 	 CONF: 0.43178807947019865
# 	 LIFT: 19.01066961000736
#
# KEY:  ('LUNCH BAG PINK POLKADOT', 'LUNCH BAG WOODLAND')
# Ante:['LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG WOODLAND']
# 	 CONF: 0.33964248159831756
# 	 LIFT: 8.982916170043703
# Ante:['LUNCH BAG WOODLAND'], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.38498212157330153
# 	 LIFT: 8.982916170043703
#
# KEY:  ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG APPLE DESIGN')
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['LUNCH BAG APPLE DESIGN']
# 	 CONF: 0.2982292637465051
# 	 LIFT: 7.53725212133821
# Ante:['LUNCH BAG APPLE DESIGN'], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.36446469248291574
# 	 LIFT: 7.537252121338211
#
# KEY:  ('WOODEN HEART CHRISTMAS SCANDINAVIAN', 'WOODEN STAR CHRISTMAS SCANDINAVIAN')
# Ante:['WOODEN HEART CHRISTMAS SCANDINAVIAN'], cons:['WOODEN STAR CHRISTMAS SCANDINAVIAN']
# 	 CONF: 0.6881720430107527
# 	 LIFT: 35.024168886258266
# Ante:['WOODEN STAR CHRISTMAS SCANDINAVIAN'], cons:['WOODEN HEART CHRISTMAS SCANDINAVIAN']
# 	 CONF: 0.7339449541284404
# 	 LIFT: 35.02416888625826
#
# KEY:  ('PINK REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER')
# Ante:['PINK REGENCY TEACUP AND SAUCER'], cons:['REGENCY CAKESTAND 3 TIER']
# 	 CONF: 0.5397631133671743
# 	 LIFT: 6.357401000858598
# Ante:['REGENCY CAKESTAND 3 TIER'], cons:['PINK REGENCY TEACUP AND SAUCER']
# DID NOT REACH MINCONF
#
# KEY:  ('ALARM CLOCK BAKELIKE IVORY', 'ALARM CLOCK BAKELIKE RED ')
# Ante:['ALARM CLOCK BAKELIKE IVORY'], cons:['ALARM CLOCK BAKELIKE RED ']
# 	 CONF: 0.6625
# 	 LIFT: 16.2082414553473
# Ante:['ALARM CLOCK BAKELIKE RED '], cons:['ALARM CLOCK BAKELIKE IVORY']
# 	 CONF: 0.350606394707828
# 	 LIFT: 16.2082414553473
#
# KEY:  ('GREEN REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER', 'ROSES REGENCY TEACUP AND SAUCER ')
# Ante:['GREEN REGENCY TEACUP AND SAUCER'], cons:['REGENCY CAKESTAND 3 TIER']
# 	 CONF: 0.5225102319236017
# 	 LIFT: 6.154194292136264
# Ante:['GREEN REGENCY TEACUP AND SAUCER'], cons:['ROSES REGENCY TEACUP AND SAUCER ']
# 	 CONF: 0.7598908594815825
# 	 LIFT: 20.16983034915827
# Ante:['REGENCY CAKESTAND 3 TIER'], cons:['GREEN REGENCY TEACUP AND SAUCER']
# 	 CONF: 0.20329087048832273
# 	 LIFT: 6.154194292136264
# Ante:['REGENCY CAKESTAND 3 TIER'], cons:['ROSES REGENCY TEACUP AND SAUCER ']
# 	 CONF: 0.22929936305732485
# 	 LIFT: 6.086307256270381
# Ante:['ROSES REGENCY TEACUP AND SAUCER '], cons:['GREEN REGENCY TEACUP AND SAUCER']
# 	 CONF: 0.666267942583732
# 	 LIFT: 20.16983034915827
# Ante:['ROSES REGENCY TEACUP AND SAUCER '], cons:['REGENCY CAKESTAND 3 TIER']
# 	 CONF: 0.5167464114832536
# 	 LIFT: 6.0863072562703815
# Ante:['GREEN REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER'], cons:['ROSES REGENCY TEACUP AND SAUCER ']
# 	 CONF: 0.825065274151436
# 	 LIFT: 21.899758891651153
# Ante:['GREEN REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER '], cons:['REGENCY CAKESTAND 3 TIER']
# 	 CONF: 0.5673249551166966
# 	 LIFT: 6.682028001082536
# Ante:['REGENCY CAKESTAND 3 TIER', 'ROSES REGENCY TEACUP AND SAUCER '], cons:['GREEN REGENCY TEACUP AND SAUCER']
# 	 CONF: 0.7314814814814815
# 	 LIFT: 22.1440301146986
#
# KEY:  ('JUMBO BAG APPLES', 'JUMBO BAG PEARS')
# Ante:['JUMBO BAG APPLES'], cons:['JUMBO BAG PEARS']
# 	 CONF: 0.42760487144790255
# 	 LIFT: 19.93393297779193
# Ante:['JUMBO BAG PEARS'], cons:['JUMBO BAG APPLES']
# 	 CONF: 0.6638655462184874
# 	 LIFT: 19.933932977791926
#
# KEY:  ('BAKING SET 9 PIECE RETROSPOT ', 'BAKING SET SPACEBOY DESIGN')
# Ante:['BAKING SET 9 PIECE RETROSPOT '], cons:['BAKING SET SPACEBOY DESIGN']
# 	 CONF: 0.35414301929625425
# 	 LIFT: 17.900759904746884
# Ante:['BAKING SET SPACEBOY DESIGN'], cons:['BAKING SET 9 PIECE RETROSPOT ']
# 	 CONF: 0.7107061503416856
# 	 LIFT: 17.900759904746884
#
# KEY:  ('LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG APPLE DESIGN')
# Ante:['LUNCH BAG ALPHABET DESIGN'], cons:['LUNCH BAG APPLE DESIGN']
# 	 CONF: 0.4727272727272727
# 	 LIFT: 11.947401118243944
# Ante:['LUNCH BAG APPLE DESIGN'], cons:['LUNCH BAG ALPHABET DESIGN']
# 	 CONF: 0.3553530751708428
# 	 LIFT: 11.947401118243942
#
# KEY:  ('LUNCH BAG APPLE DESIGN', 'LUNCH BAG SPACEBOY DESIGN ')
# Ante:['LUNCH BAG APPLE DESIGN'], cons:['LUNCH BAG SPACEBOY DESIGN ']
# 	 CONF: 0.3553530751708428
# 	 LIFT: 7.877407330710291
# Ante:['LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG APPLE DESIGN']
# 	 CONF: 0.3116883116883117
# 	 LIFT: 7.877407330710292
#
# KEY:  ('JAM MAKING SET PRINTED', 'JAM MAKING SET WITH JARS')
# Ante:['JAM MAKING SET PRINTED'], cons:['JAM MAKING SET WITH JARS']
# 	 CONF: 0.3534090909090909
# 	 LIFT: 8.126577955723032
# Ante:['JAM MAKING SET WITH JARS'], cons:['JAM MAKING SET PRINTED']
# 	 CONF: 0.322279792746114
# 	 LIFT: 8.126577955723034
#
# KEY:  ('LUNCH BAG SUKI DESIGN ', 'LUNCH BAG WOODLAND')
# Ante:['LUNCH BAG SUKI DESIGN '], cons:['LUNCH BAG WOODLAND']
# 	 CONF: 0.3384279475982533
# 	 LIFT: 8.95079398951757
# Ante:['LUNCH BAG WOODLAND'], cons:['LUNCH BAG SUKI DESIGN ']
# 	 CONF: 0.3694874851013111
# 	 LIFT: 8.950793989517567
#
# KEY:  ('WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN PICTURE FRAME WHITE FINISH')
# Ante:['WHITE HANGING HEART T-LIGHT HOLDER'], cons:['WOODEN PICTURE FRAME WHITE FINISH']
# DID NOT REACH MINCONF
# Ante:['WOODEN PICTURE FRAME WHITE FINISH'], cons:['WHITE HANGING HEART T-LIGHT HOLDER']
# 	 CONF: 0.34675615212527966
# 	 LIFT: 3.822413818012894
#
# KEY:  ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG PINK POLKADOT', 'LUNCH BAG RED RETROSPOT')
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.43522833178005593
# 	 LIFT: 10.155327741534638
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.4874184529356943
# 	 LIFT: 8.138311114103129
# Ante:['LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.491062039957939
# 	 LIFT: 10.155327741534638
# Ante:['LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.5573080967402734
# 	 LIFT: 9.305242036619012
# Ante:['LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.3935289691497366
# 	 LIFT: 8.138311114103127
# Ante:['LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.39879608728367194
# 	 LIFT: 9.305242036619012
# Ante:['LUNCH BAG  BLACK SKULL.', 'LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.6616702355460385
# 	 LIFT: 11.047752089365385
# Ante:['LUNCH BAG  BLACK SKULL.', 'LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.5908221797323135
# 	 LIFT: 13.785850860420648
# Ante:['LUNCH BAG PINK POLKADOT', 'LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.5830188679245283
# 	 LIFT: 12.057025796127943
#
# KEY:  ('LUNCH BAG DOLLY GIRL DESIGN', 'LUNCH BAG RED RETROSPOT')
# Ante:['LUNCH BAG DOLLY GIRL DESIGN'], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.5107438016528926
# 	 LIFT: 8.527768968154769
# Ante:['LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG DOLLY GIRL DESIGN']
# 	 CONF: 0.2325056433408578
# 	 LIFT: 8.527768968154767
#
# KEY:  ('LUNCH BAG APPLE DESIGN', 'LUNCH BAG VINTAGE LEAF DESIGN')
# Ante:['LUNCH BAG APPLE DESIGN'], cons:['LUNCH BAG VINTAGE LEAF DESIGN']
# 	 CONF: 0.34851936218678814
# 	 LIFT: 12.867961142969765
# Ante:['LUNCH BAG VINTAGE LEAF DESIGN'], cons:['LUNCH BAG APPLE DESIGN']
# 	 CONF: 0.5091514143094842
# 	 LIFT: 12.867961142969765
#
# KEY:  ('JUMBO BAG ALPHABET', 'JUMBO BAG RED RETROSPOT')
# Ante:['JUMBO BAG ALPHABET'], cons:['JUMBO BAG RED RETROSPOT']
# 	 CONF: 0.39425587467362927
# 	 LIFT: 5.324733937314567
# Ante:['JUMBO BAG RED RETROSPOT'], cons:['JUMBO BAG ALPHABET']
# DID NOT REACH MINCONF
#
# KEY:  ('CHARLOTTE BAG SUKI DESIGN', 'RED RETROSPOT CHARLOTTE BAG')
# Ante:['CHARLOTTE BAG SUKI DESIGN'], cons:['RED RETROSPOT CHARLOTTE BAG']
# 	 CONF: 0.5041876046901173
# 	 LIFT: 14.818440990826094
# Ante:['RED RETROSPOT CHARLOTTE BAG'], cons:['CHARLOTTE BAG SUKI DESIGN']
# 	 CONF: 0.39867549668874175
# 	 LIFT: 14.818440990826097
#
# KEY:  ('LUNCH BAG APPLE DESIGN', 'LUNCH BAG WOODLAND')
# Ante:['LUNCH BAG APPLE DESIGN'], cons:['LUNCH BAG WOODLAND']
# 	 CONF: 0.3416856492027335
# 	 LIFT: 9.036954178556204
# Ante:['LUNCH BAG WOODLAND'], cons:['LUNCH BAG APPLE DESIGN']
# 	 CONF: 0.3575685339690107
# 	 LIFT: 9.036954178556206
#
# KEY:  ('SET OF 3 CAKE TINS PANTRY DESIGN ', 'SET OF 6 SPICE TINS PANTRY DESIGN')
# Ante:['SET OF 3 CAKE TINS PANTRY DESIGN '], cons:['SET OF 6 SPICE TINS PANTRY DESIGN']
# 	 CONF: 0.24630541871921183
# 	 LIFT: 8.218822919367383
# Ante:['SET OF 6 SPICE TINS PANTRY DESIGN'], cons:['SET OF 3 CAKE TINS PANTRY DESIGN ']
# 	 CONF: 0.45112781954887216
# 	 LIFT: 8.218822919367383
#
# KEY:  ('RED RETROSPOT CHARLOTTE BAG', 'STRAWBERRY CHARLOTTE BAG')
# Ante:['RED RETROSPOT CHARLOTTE BAG'], cons:['STRAWBERRY CHARLOTTE BAG']
# 	 CONF: 0.3973509933774834
# 	 LIFT: 17.49448123620309
# Ante:['STRAWBERRY CHARLOTTE BAG'], cons:['RED RETROSPOT CHARLOTTE BAG']
# 	 CONF: 0.5952380952380952
# 	 LIFT: 17.49448123620309
#
# KEY:  ('JUMBO BAG APPLES', 'LUNCH BAG APPLE DESIGN')
# Ante:['JUMBO BAG APPLES'], cons:['LUNCH BAG APPLE DESIGN']
# 	 CONF: 0.401894451962111
# 	 LIFT: 10.157218552436495
# Ante:['LUNCH BAG APPLE DESIGN'], cons:['JUMBO BAG APPLES']
# 	 CONF: 0.33826879271070615
# 	 LIFT: 10.157218552436493
#
# KEY:  ('JUMBO BAG RED RETROSPOT', 'JUMBO BAG VINTAGE DOILY ')
# Ante:['JUMBO BAG RED RETROSPOT'], cons:['JUMBO BAG VINTAGE DOILY ']
# DID NOT REACH MINCONF
# Ante:['JUMBO BAG VINTAGE DOILY '], cons:['JUMBO BAG RED RETROSPOT']
# 	 CONF: 0.46529968454258674
# 	 LIFT: 6.284236153377967
#
# KEY:  ('JUMBO BAG PINK POLKADOT', 'JUMBO BAG STRAWBERRY')
# Ante:['JUMBO BAG PINK POLKADOT'], cons:['JUMBO BAG STRAWBERRY']
# 	 CONF: 0.332579185520362
# 	 LIFT: 11.064366007041727
# Ante:['JUMBO BAG STRAWBERRY'], cons:['JUMBO BAG PINK POLKADOT']
# 	 CONF: 0.4407796101949025
# 	 LIFT: 11.064366007041727
#
# KEY:  ('PLASTERS IN TIN SPACEBOY', 'PLASTERS IN TIN WOODLAND ANIMALS')
# Ante:['PLASTERS IN TIN SPACEBOY'], cons:['PLASTERS IN TIN WOODLAND ANIMALS']
# 	 CONF: 0.5008517887563884
# 	 LIFT: 18.77348174409503
# Ante:['PLASTERS IN TIN WOODLAND ANIMALS'], cons:['PLASTERS IN TIN SPACEBOY']
# 	 CONF: 0.4966216216216216
# 	 LIFT: 18.773481744095033
#
# KEY:  ('LUNCH BAG APPLE DESIGN', 'LUNCH BAG PINK POLKADOT')
# Ante:['LUNCH BAG APPLE DESIGN'], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.3325740318906606
# 	 LIFT: 7.760060744115414
# Ante:['LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG APPLE DESIGN']
# 	 CONF: 0.3070452155625657
# 	 LIFT: 7.760060744115414
#
# KEY:  ('LUNCH BAG APPLE DESIGN', 'LUNCH BAG CARS BLUE')
# Ante:['LUNCH BAG APPLE DESIGN'], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.3314350797266515
# 	 LIFT: 7.436344205393728
# Ante:['LUNCH BAG CARS BLUE'], cons:['LUNCH BAG APPLE DESIGN']
# 	 CONF: 0.2942366026289181
# 	 LIFT: 7.436344205393728
#
# KEY:  ('HEART OF WICKER LARGE', 'WHITE HANGING HEART T-LIGHT HOLDER')
# Ante:['HEART OF WICKER LARGE'], cons:['WHITE HANGING HEART T-LIGHT HOLDER']
# 	 CONF: 0.35495716034271724
# 	 LIFT: 3.912816387483803
# Ante:['WHITE HANGING HEART T-LIGHT HOLDER'], cons:['HEART OF WICKER LARGE']
# DID NOT REACH MINCONF
#
# KEY:  ('CHOCOLATE HOT WATER BOTTLE', 'HOT WATER BOTTLE I AM SO POORLY')
# Ante:['CHOCOLATE HOT WATER BOTTLE'], cons:['HOT WATER BOTTLE I AM SO POORLY']
# 	 CONF: 0.4101838755304102
# 	 LIFT: 17.84701999611726
# Ante:['HOT WATER BOTTLE I AM SO POORLY'], cons:['CHOCOLATE HOT WATER BOTTLE']
# 	 CONF: 0.5686274509803921
# 	 LIFT: 17.84701999611726
#
# KEY:  ('RED RETROSPOT CHARLOTTE BAG', 'WOODLAND CHARLOTTE BAG')
# Ante:['RED RETROSPOT CHARLOTTE BAG'], cons:['WOODLAND CHARLOTTE BAG']
# 	 CONF: 0.3841059602649007
# 	 LIFT: 15.81319342908747
# Ante:['WOODLAND CHARLOTTE BAG'], cons:['RED RETROSPOT CHARLOTTE BAG']
# 	 CONF: 0.5380333951762524
# 	 LIFT: 15.81319342908747
#
# KEY:  ('JUMBO BAG APPLES', 'JUMBO BAG VINTAGE LEAF')
# Ante:['JUMBO BAG APPLES'], cons:['JUMBO BAG VINTAGE LEAF']
# 	 CONF: 0.3870094722598105
# 	 LIFT: 11.038226464582515
# Ante:['JUMBO BAG VINTAGE LEAF'], cons:['JUMBO BAG APPLES']
# 	 CONF: 0.3676092544987147
# 	 LIFT: 11.038226464582515
#
# KEY:  ('JUMBO BAG PINK POLKADOT', 'JUMBO STORAGE BAG SUKI')
# Ante:['JUMBO BAG PINK POLKADOT'], cons:['JUMBO STORAGE BAG SUKI']
# 	 CONF: 0.3212669683257919
# 	 LIFT: 9.012533536219118
# Ante:['JUMBO STORAGE BAG SUKI'], cons:['JUMBO BAG PINK POLKADOT']
# 	 CONF: 0.359039190897598
# 	 LIFT: 9.012533536219117
#
# KEY:  ('JUMBO BAG RED RETROSPOT', 'RED RETROSPOT CHARLOTTE BAG')
# Ante:['JUMBO BAG RED RETROSPOT'], cons:['RED RETROSPOT CHARLOTTE BAG']
# DID NOT REACH MINCONF
# Ante:['RED RETROSPOT CHARLOTTE BAG'], cons:['JUMBO BAG RED RETROSPOT']
# 	 CONF: 0.3748344370860927
# 	 LIFT: 5.062432233073888
#
# KEY:  ('LUNCH BAG CARS BLUE', 'LUNCH BAG PINK POLKADOT', 'LUNCH BAG RED RETROSPOT')
# Ante:['LUNCH BAG CARS BLUE'], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.4368048533872599
# 	 LIFT: 10.19211324570273
# Ante:['LUNCH BAG CARS BLUE'], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.47017189079878663
# 	 LIFT: 7.850349327934595
# Ante:['LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.45425867507886436
# 	 LIFT: 10.19211324570273
# Ante:['LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.5573080967402734
# 	 LIFT: 9.305242036619012
# Ante:['LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.34988713318284426
# 	 LIFT: 7.850349327934595
# Ante:['LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.39879608728367194
# 	 LIFT: 9.305242036619012
# Ante:['LUNCH BAG CARS BLUE', 'LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.6527777777777778
# 	 LIFT: 10.899276816319706
# Ante:['LUNCH BAG CARS BLUE', 'LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.6064516129032258
# 	 LIFT: 14.150537634408602
# Ante:['LUNCH BAG PINK POLKADOT', 'LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.5320754716981132
# 	 LIFT: 11.938073525764542
#
# KEY:  ('JUMBO BAG ALPHABET', 'JUMBO BAG APPLES')
# Ante:['JUMBO BAG ALPHABET'], cons:['JUMBO BAG APPLES']
# 	 CONF: 0.3681462140992167
# 	 LIFT: 11.054349784657129
# Ante:['JUMBO BAG APPLES'], cons:['JUMBO BAG ALPHABET']
# 	 CONF: 0.38159675236806495
# 	 LIFT: 11.054349784657129
#
# KEY:  ('LARGE WHITE HEART OF WICKER', 'SMALL WHITE HEART OF WICKER')
# Ante:['LARGE WHITE HEART OF WICKER'], cons:['SMALL WHITE HEART OF WICKER']
# 	 CONF: 0.5412667946257198
# 	 LIFT: 20.496092444956865
# Ante:['SMALL WHITE HEART OF WICKER'], cons:['LARGE WHITE HEART OF WICKER']
# 	 CONF: 0.4812286689419795
# 	 LIFT: 20.49609244495686
#
# KEY:  ('JUMBO BAG RED RETROSPOT', 'LUNCH BAG PINK POLKADOT')
# Ante:['JUMBO BAG RED RETROSPOT'], cons:['LUNCH BAG PINK POLKADOT']
# DID NOT REACH MINCONF
# Ante:['LUNCH BAG PINK POLKADOT'], cons:['JUMBO BAG RED RETROSPOT']
# 	 CONF: 0.29652996845425866
# 	 LIFT: 4.004869141813755
#
# KEY:  ('HAND WARMER OWL DESIGN', 'HAND WARMER SCOTTY DOG DESIGN')
# Ante:['HAND WARMER OWL DESIGN'], cons:['HAND WARMER SCOTTY DOG DESIGN']
# 	 CONF: 0.48198970840480276
# 	 LIFT: 22.516529746321204
# Ante:['HAND WARMER SCOTTY DOG DESIGN'], cons:['HAND WARMER OWL DESIGN']
# 	 CONF: 0.5915789473684211
# 	 LIFT: 22.516529746321208
#
# KEY:  ('60 TEATIME FAIRY CAKE CASES', 'PACK OF 60 PINK PAISLEY CAKE CASES')
# Ante:['60 TEATIME FAIRY CAKE CASES'], cons:['PACK OF 60 PINK PAISLEY CAKE CASES']
# 	 CONF: 0.42168674698795183
# 	 LIFT: 13.86256135653726
# Ante:['PACK OF 60 PINK PAISLEY CAKE CASES'], cons:['60 TEATIME FAIRY CAKE CASES']
# 	 CONF: 0.4148148148148148
# 	 LIFT: 13.86256135653726
#
# KEY:  ('JUMBO BAG RED RETROSPOT', 'LUNCH BAG  BLACK SKULL.')
# Ante:['JUMBO BAG RED RETROSPOT'], cons:['LUNCH BAG  BLACK SKULL.']
# DID NOT REACH MINCONF
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['JUMBO BAG RED RETROSPOT']
# 	 CONF: 0.26095060577819196
# 	 LIFT: 3.5243420220438706
#
# KEY:  ('PARTY BUNTING', 'WHITE HANGING HEART T-LIGHT HOLDER')
# Ante:['PARTY BUNTING'], cons:['WHITE HANGING HEART T-LIGHT HOLDER']
# 	 CONF: 0.20014295925661185
# 	 LIFT: 2.2062455369618563
# Ante:['WHITE HANGING HEART T-LIGHT HOLDER'], cons:['PARTY BUNTING']
# DID NOT REACH MINCONF
#
# KEY:  ('COOK WITH WINE METAL SIGN ', 'GIN + TONIC DIET METAL SIGN')
# Ante:['COOK WITH WINE METAL SIGN '], cons:['GIN + TONIC DIET METAL SIGN']
# 	 CONF: 0.4551386623164764
# 	 LIFT: 15.256082955895183
# Ante:['GIN + TONIC DIET METAL SIGN'], cons:['COOK WITH WINE METAL SIGN ']
# 	 CONF: 0.4214501510574018
# 	 LIFT: 15.256082955895181
#
# KEY:  ('ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE IVORY')
# Ante:['ALARM CLOCK BAKELIKE GREEN'], cons:['ALARM CLOCK BAKELIKE IVORY']
# 	 CONF: 0.3411619283065513
# 	 LIFT: 15.771631644004943
# Ante:['ALARM CLOCK BAKELIKE IVORY'], cons:['ALARM CLOCK BAKELIKE GREEN']
# 	 CONF: 0.575
# 	 LIFT: 15.771631644004943
#
# KEY:  ('HOME BUILDING BLOCK WORD', 'LOVE BUILDING BLOCK WORD')
# Ante:['HOME BUILDING BLOCK WORD'], cons:['LOVE BUILDING BLOCK WORD']
# 	 CONF: 0.39285714285714285
# 	 LIFT: 15.650807899461402
# Ante:['LOVE BUILDING BLOCK WORD'], cons:['HOME BUILDING BLOCK WORD']
# 	 CONF: 0.49371633752244165
# 	 LIFT: 15.650807899461402
#
# KEY:  ('GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER')
# Ante:['GREEN REGENCY TEACUP AND SAUCER'], cons:['PINK REGENCY TEACUP AND SAUCER']
# 	 CONF: 0.6425648021828103
# 	 LIFT: 24.12607945928352
# Ante:['GREEN REGENCY TEACUP AND SAUCER'], cons:['REGENCY CAKESTAND 3 TIER']
# 	 CONF: 0.5225102319236017
# 	 LIFT: 6.154194292136264
# Ante:['PINK REGENCY TEACUP AND SAUCER'], cons:['GREEN REGENCY TEACUP AND SAUCER']
# 	 CONF: 0.7969543147208121
# 	 LIFT: 24.12607945928352
# Ante:['PINK REGENCY TEACUP AND SAUCER'], cons:['REGENCY CAKESTAND 3 TIER']
# 	 CONF: 0.5397631133671743
# 	 LIFT: 6.357401000858598
# Ante:['REGENCY CAKESTAND 3 TIER'], cons:['GREEN REGENCY TEACUP AND SAUCER']
# 	 CONF: 0.20329087048832273
# 	 LIFT: 6.154194292136264
# Ante:['REGENCY CAKESTAND 3 TIER'], cons:['PINK REGENCY TEACUP AND SAUCER']
# DID NOT REACH MINCONF
# Ante:['GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER'], cons:['REGENCY CAKESTAND 3 TIER']
# 	 CONF: 0.5817409766454352
# 	 LIFT: 6.851821800298412
# Ante:['GREEN REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER'], cons:['PINK REGENCY TEACUP AND SAUCER']
# 	 CONF: 0.7154046997389034
# 	 LIFT: 26.860964952971685
# Ante:['PINK REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER'], cons:['GREEN REGENCY TEACUP AND SAUCER']
# 	 CONF: 0.8589341692789969
# 	 LIFT: 26.00238637967386
#
# KEY:  ('BLUE HARMONICA IN BOX ', 'RED  HARMONICA IN BOX ')
# Ante:['BLUE HARMONICA IN BOX '], cons:['RED  HARMONICA IN BOX ']
# 	 CONF: 0.5240847784200385
# 	 LIFT: 20.43838529550203
# Ante:['RED  HARMONICA IN BOX '], cons:['BLUE HARMONICA IN BOX ']
# 	 CONF: 0.4780316344463972
# 	 LIFT: 20.43838529550203
#
# KEY:  ('JUMBO BAG RED RETROSPOT', 'JUMBO BAG SCANDINAVIAN BLUE PAISLEY')
# Ante:['JUMBO BAG RED RETROSPOT'], cons:['JUMBO BAG SCANDINAVIAN BLUE PAISLEY']
# DID NOT REACH MINCONF
# Ante:['JUMBO BAG SCANDINAVIAN BLUE PAISLEY'], cons:['JUMBO BAG RED RETROSPOT']
# 	 CONF: 0.5925925925925926
# 	 LIFT: 8.003426433128197
#
# KEY:  ('PINK REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER', 'ROSES REGENCY TEACUP AND SAUCER ')
# Ante:['PINK REGENCY TEACUP AND SAUCER'], cons:['REGENCY CAKESTAND 3 TIER']
# 	 CONF: 0.5397631133671743
# 	 LIFT: 6.357401000858598
# Ante:['PINK REGENCY TEACUP AND SAUCER'], cons:['ROSES REGENCY TEACUP AND SAUCER ']
# 	 CONF: 0.7631133671742809
# 	 LIFT: 20.25536557128863
# Ante:['REGENCY CAKESTAND 3 TIER'], cons:['PINK REGENCY TEACUP AND SAUCER']
# DID NOT REACH MINCONF
# Ante:['REGENCY CAKESTAND 3 TIER'], cons:['ROSES REGENCY TEACUP AND SAUCER ']
# 	 CONF: 0.22929936305732485
# 	 LIFT: 6.086307256270381
# Ante:['ROSES REGENCY TEACUP AND SAUCER '], cons:['PINK REGENCY TEACUP AND SAUCER']
# 	 CONF: 0.5394736842105263
# 	 LIFT: 20.25536557128863
# Ante:['ROSES REGENCY TEACUP AND SAUCER '], cons:['REGENCY CAKESTAND 3 TIER']
# 	 CONF: 0.5167464114832536
# 	 LIFT: 6.0863072562703815
# Ante:['PINK REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER'], cons:['ROSES REGENCY TEACUP AND SAUCER ']
# 	 CONF: 0.8495297805642633
# 	 LIFT: 22.54912180708254
# Ante:['PINK REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER '], cons:['REGENCY CAKESTAND 3 TIER']
# 	 CONF: 0.6008869179600886
# 	 LIFT: 7.07732521737493
# Ante:['REGENCY CAKESTAND 3 TIER', 'ROSES REGENCY TEACUP AND SAUCER '], cons:['PINK REGENCY TEACUP AND SAUCER']
# 	 CONF: 0.6273148148148148
# 	 LIFT: 23.553495331202605
#
# KEY:  ('ASSORTED COLOUR BIRD ORNAMENT', 'WHITE HANGING HEART T-LIGHT HOLDER')
# Ante:['ASSORTED COLOUR BIRD ORNAMENT'], cons:['WHITE HANGING HEART T-LIGHT HOLDER']
# DID NOT REACH MINCONF
# Ante:['WHITE HANGING HEART T-LIGHT HOLDER'], cons:['ASSORTED COLOUR BIRD ORNAMENT']
# DID NOT REACH MINCONF
#
# KEY:  ('COOK WITH WINE METAL SIGN ', 'PLEASE ONE PERSON METAL SIGN')
# Ante:['COOK WITH WINE METAL SIGN '], cons:['PLEASE ONE PERSON METAL SIGN']
# 	 CONF: 0.44045676998368677
# 	 LIFT: 13.883147337980128
# Ante:['PLEASE ONE PERSON METAL SIGN'], cons:['COOK WITH WINE METAL SIGN ']
# 	 CONF: 0.3835227272727273
# 	 LIFT: 13.883147337980128
#
# KEY:  ('IVORY KITCHEN SCALES', 'RED KITCHEN SCALES')
# Ante:['IVORY KITCHEN SCALES'], cons:['RED KITCHEN SCALES']
# 	 CONF: 0.4292527821939587
# 	 LIFT: 20.396400935511654
# Ante:['RED KITCHEN SCALES'], cons:['IVORY KITCHEN SCALES']
# 	 CONF: 0.5781584582441114
# 	 LIFT: 20.396400935511657
#
# KEY:  ('JUMBO BAG RED RETROSPOT', 'JUMBO BAG SPACEBOY DESIGN')
# Ante:['JUMBO BAG RED RETROSPOT'], cons:['JUMBO BAG SPACEBOY DESIGN']
# DID NOT REACH MINCONF
# Ante:['JUMBO BAG SPACEBOY DESIGN'], cons:['JUMBO BAG RED RETROSPOT']
# 	 CONF: 0.558091286307054
# 	 LIFT: 7.537459308066663
#
# KEY:  ('RECIPE BOX PANTRY YELLOW DESIGN', 'SET OF 3 CAKE TINS PANTRY DESIGN ')
# Ante:['RECIPE BOX PANTRY YELLOW DESIGN'], cons:['SET OF 3 CAKE TINS PANTRY DESIGN ']
# 	 CONF: 0.30742857142857144
# 	 LIFT: 5.600853858784894
# Ante:['SET OF 3 CAKE TINS PANTRY DESIGN '], cons:['RECIPE BOX PANTRY YELLOW DESIGN']
# 	 CONF: 0.22085385878489328
# 	 LIFT: 5.600853858784894
#
# KEY:  ('ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE PINK', 'ALARM CLOCK BAKELIKE RED ')
# Ante:['ALARM CLOCK BAKELIKE GREEN'], cons:['ALARM CLOCK BAKELIKE PINK']
# 	 CONF: 0.4252163164400494
# 	 LIFT: 15.00087450207424
# Ante:['ALARM CLOCK BAKELIKE GREEN'], cons:['ALARM CLOCK BAKELIKE RED ']
# 	 CONF: 0.6625463535228677
# 	 LIFT: 16.20937550680533
# Ante:['ALARM CLOCK BAKELIKE PINK'], cons:['ALARM CLOCK BAKELIKE GREEN']
# 	 CONF: 0.5468998410174881
# 	 LIFT: 15.000874502074241
# Ante:['ALARM CLOCK BAKELIKE PINK'], cons:['ALARM CLOCK BAKELIKE RED ']
# 	 CONF: 0.6406995230524642
# 	 LIFT: 15.674886898053122
# Ante:['ALARM CLOCK BAKELIKE RED '], cons:['ALARM CLOCK BAKELIKE GREEN']
# 	 CONF: 0.5909592061742006
# 	 LIFT: 16.20937550680533
# Ante:['ALARM CLOCK BAKELIKE RED '], cons:['ALARM CLOCK BAKELIKE PINK']
# 	 CONF: 0.44432194046306506
# 	 LIFT: 15.674886898053122
# Ante:['ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE PINK'], cons:['ALARM CLOCK BAKELIKE RED ']
# 	 CONF: 0.7790697674418605
# 	 LIFT: 19.060152303787085
# Ante:['ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE RED '], cons:['ALARM CLOCK BAKELIKE PINK']
# 	 CONF: 0.5
# 	 LIFT: 17.63910969793323
# Ante:['ALARM CLOCK BAKELIKE PINK', 'ALARM CLOCK BAKELIKE RED '], cons:['ALARM CLOCK BAKELIKE GREEN']
# 	 CONF: 0.6650124069478908
# 	 LIFT: 18.240575167087385
#
# KEY:  ('HAND WARMER BIRD DESIGN', 'HAND WARMER OWL DESIGN')
# Ante:['HAND WARMER BIRD DESIGN'], cons:['HAND WARMER OWL DESIGN']
# 	 CONF: 0.5583333333333333
# 	 LIFT: 21.251143510577474
# Ante:['HAND WARMER OWL DESIGN'], cons:['HAND WARMER BIRD DESIGN']
# 	 CONF: 0.45969125214408235
# 	 LIFT: 21.25114351057747
#
# KEY:  ('HEART OF WICKER SMALL', 'WHITE HANGING HEART T-LIGHT HOLDER')
# Ante:['HEART OF WICKER SMALL'], cons:['WHITE HANGING HEART T-LIGHT HOLDER']
# 	 CONF: 0.2757201646090535
# 	 LIFT: 3.0393593903004956
# Ante:['WHITE HANGING HEART T-LIGHT HOLDER'], cons:['HEART OF WICKER SMALL']
# DID NOT REACH MINCONF
#
# KEY:  ('PACK OF 60 DINOSAUR CAKE CASES', 'PACK OF 72 RETROSPOT CAKE CASES')
# Ante:['PACK OF 60 DINOSAUR CAKE CASES'], cons:['PACK OF 72 RETROSPOT CAKE CASES']
# 	 CONF: 0.5037593984962406
# 	 LIFT: 10.738156630770009
# Ante:['PACK OF 72 RETROSPOT CAKE CASES'], cons:['PACK OF 60 DINOSAUR CAKE CASES']
# 	 CONF: 0.2574447646493756
# 	 LIFT: 10.738156630770009
#
# KEY:  ('ROUND SNACK BOXES SET OF 4 FRUITS ', 'ROUND SNACK BOXES SET OF4 WOODLAND ')
# Ante:['ROUND SNACK BOXES SET OF 4 FRUITS '], cons:['ROUND SNACK BOXES SET OF4 WOODLAND ']
# 	 CONF: 0.5644820295983086
# 	 LIFT: 20.467085354226256
# Ante:['ROUND SNACK BOXES SET OF4 WOODLAND '], cons:['ROUND SNACK BOXES SET OF 4 FRUITS ']
# 	 CONF: 0.4362745098039216
# 	 LIFT: 20.46708535422626
#
# KEY:  ('NATURAL SLATE HEART CHALKBOARD ', 'WHITE HANGING HEART T-LIGHT HOLDER')
# Ante:['NATURAL SLATE HEART CHALKBOARD '], cons:['WHITE HANGING HEART T-LIGHT HOLDER']
# 	 CONF: 0.2703252032520325
# 	 LIFT: 2.979888852539792
# Ante:['WHITE HANGING HEART T-LIGHT HOLDER'], cons:['NATURAL SLATE HEART CHALKBOARD ']
# DID NOT REACH MINCONF
#
# KEY:  ('JUMBO BAG RED RETROSPOT', 'JUMBO BAG WOODLAND ANIMALS')
# Ante:['JUMBO BAG RED RETROSPOT'], cons:['JUMBO BAG WOODLAND ANIMALS']
# DID NOT REACH MINCONF
# Ante:['JUMBO BAG WOODLAND ANIMALS'], cons:['JUMBO BAG RED RETROSPOT']
# 	 CONF: 0.5289421157684631
# 	 LIFT: 7.1437769622046225
#
# KEY:  ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG VINTAGE LEAF DESIGN')
# Ante:['LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG VINTAGE LEAF DESIGN']
# DID NOT REACH MINCONF
# Ante:['LUNCH BAG VINTAGE LEAF DESIGN'], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.44093178036605657
# 	 LIFT: 7.3621340905363395
#
# KEY:  ('COOK WITH WINE METAL SIGN ', 'HAND OVER THE CHOCOLATE   SIGN ')
# Ante:['COOK WITH WINE METAL SIGN '], cons:['HAND OVER THE CHOCOLATE   SIGN ']
# 	 CONF: 0.43066884176182707
# 	 LIFT: 16.115584483465334
# Ante:['HAND OVER THE CHOCOLATE   SIGN '], cons:['COOK WITH WINE METAL SIGN ']
# 	 CONF: 0.4451939291736931
# 	 LIFT: 16.115584483465334
#
# KEY:  ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG DOLLY GIRL DESIGN')
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['LUNCH BAG DOLLY GIRL DESIGN']
# 	 CONF: 0.24603914259086673
# 	 LIFT: 9.024146403456749
# Ante:['LUNCH BAG DOLLY GIRL DESIGN'], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.43636363636363634
# 	 LIFT: 9.024146403456749
#
# KEY:  ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG CARS BLUE', 'LUNCH BAG RED RETROSPOT')
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.3960857409133271
# 	 LIFT: 8.886898474081626
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.4874184529356943
# 	 LIFT: 8.138311114103129
# Ante:['LUNCH BAG CARS BLUE'], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.42972699696663297
# 	 LIFT: 8.886898474081628
# Ante:['LUNCH BAG CARS BLUE'], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.47017189079878663
# 	 LIFT: 7.850349327934595
# Ante:['LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.3935289691497366
# 	 LIFT: 8.138311114103127
# Ante:['LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.34988713318284426
# 	 LIFT: 7.850349327934595
# Ante:['LUNCH BAG  BLACK SKULL.', 'LUNCH BAG CARS BLUE'], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.6188235294117647
# 	 LIFT: 10.332350728101623
# Ante:['LUNCH BAG  BLACK SKULL.', 'LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.502868068833652
# 	 LIFT: 11.282752727420363
# Ante:['LUNCH BAG CARS BLUE', 'LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.5655913978494623
# 	 LIFT: 11.696619867921314
#
# KEY:  ('JUMBO BAG ALPHABET', 'JUMBO BAG VINTAGE LEAF')
# Ante:['JUMBO BAG ALPHABET'], cons:['JUMBO BAG VINTAGE LEAF']
# 	 CONF: 0.3433420365535248
# 	 LIFT: 9.792750374193723
# Ante:['JUMBO BAG VINTAGE LEAF'], cons:['JUMBO BAG ALPHABET']
# 	 CONF: 0.3380462724935733
# 	 LIFT: 9.792750374193721
#
# KEY:  ('LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG RED RETROSPOT')
# Ante:['LUNCH BAG ALPHABET DESIGN'], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.396969696969697
# 	 LIFT: 6.628109537816084
# Ante:['LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG ALPHABET DESIGN']
# DID NOT REACH MINCONF
#
# KEY:  ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG CARS BLUE', 'LUNCH BAG PINK POLKADOT')
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.3960857409133271
# 	 LIFT: 8.886898474081626
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.43522833178005593
# 	 LIFT: 10.155327741534638
# Ante:['LUNCH BAG CARS BLUE'], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.42972699696663297
# 	 LIFT: 8.886898474081628
# Ante:['LUNCH BAG CARS BLUE'], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.4368048533872599
# 	 LIFT: 10.19211324570273
# Ante:['LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.491062039957939
# 	 LIFT: 10.155327741534638
# Ante:['LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.45425867507886436
# 	 LIFT: 10.19211324570273
# Ante:['LUNCH BAG  BLACK SKULL.', 'LUNCH BAG CARS BLUE'], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.6141176470588235
# 	 LIFT: 14.329411764705883
# Ante:['LUNCH BAG  BLACK SKULL.', 'LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.5588865096359743
# 	 LIFT: 12.539627551893094
# Ante:['LUNCH BAG CARS BLUE', 'LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.6041666666666666
# 	 LIFT: 12.49436936936937
#
# KEY:  ('CHOCOLATE HOT WATER BOTTLE', 'HOT WATER BOTTLE TEA AND SYMPATHY')
# Ante:['CHOCOLATE HOT WATER BOTTLE'], cons:['HOT WATER BOTTLE TEA AND SYMPATHY']
# 	 CONF: 0.36916548797736914
# 	 LIFT: 15.814251309300813
# Ante:['HOT WATER BOTTLE TEA AND SYMPATHY'], cons:['CHOCOLATE HOT WATER BOTTLE']
# 	 CONF: 0.5038610038610039
# 	 LIFT: 15.814251309300815
#
# KEY:  ('LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG SUKI DESIGN ')
# Ante:['LUNCH BAG ALPHABET DESIGN'], cons:['LUNCH BAG SUKI DESIGN ']
# 	 CONF: 0.39545454545454545
# 	 LIFT: 9.579843191742754
# Ante:['LUNCH BAG SUKI DESIGN '], cons:['LUNCH BAG ALPHABET DESIGN']
# 	 CONF: 0.2849344978165939
# 	 LIFT: 9.579843191742755
#
# KEY:  ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG SPACEBOY DESIGN ', 'LUNCH BAG WOODLAND')
# Ante:['LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG SPACEBOY DESIGN ']
# 	 CONF: 0.35364936042136946
# 	 LIFT: 7.839639668082106
# Ante:['LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG WOODLAND']
# 	 CONF: 0.3303235515425132
# 	 LIFT: 8.736447686207827
# Ante:['LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.4695304695304695
# 	 LIFT: 7.839639668082106
# Ante:['LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG WOODLAND']
# 	 CONF: 0.4085914085914086
# 	 LIFT: 10.806487910182783
# Ante:['LUNCH BAG WOODLAND'], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.5232419547079857
# 	 LIFT: 8.736447686207828
# Ante:['LUNCH BAG WOODLAND'], cons:['LUNCH BAG SPACEBOY DESIGN ']
# 	 CONF: 0.48748510131108463
# 	 LIFT: 10.806487910182785
# Ante:['LUNCH BAG RED RETROSPOT', 'LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG WOODLAND']
# 	 CONF: 0.5531914893617021
# 	 LIFT: 14.630892906956102
# Ante:['LUNCH BAG RED RETROSPOT', 'LUNCH BAG WOODLAND'], cons:['LUNCH BAG SPACEBOY DESIGN ']
# 	 CONF: 0.592255125284738
# 	 LIFT: 13.129012217850486
# Ante:['LUNCH BAG SPACEBOY DESIGN ', 'LUNCH BAG WOODLAND'], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.6356968215158925
# 	 LIFT: 10.614080112443682
#
# KEY:  ('JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO SHOPPER VINTAGE RED PAISLEY')
# Ante:['JUMBO BAG PINK VINTAGE PAISLEY'], cons:['JUMBO SHOPPER VINTAGE RED PAISLEY']
# 	 CONF: 0.4234527687296417
# 	 LIFT: 11.730857600637641
# Ante:['JUMBO SHOPPER VINTAGE RED PAISLEY'], cons:['JUMBO BAG PINK VINTAGE PAISLEY']
# 	 CONF: 0.32459425717852686
# 	 LIFT: 11.730857600637641
#
# KEY:  ('JUMBO BAG RED RETROSPOT', 'LUNCH BAG CARS BLUE')
# Ante:['JUMBO BAG RED RETROSPOT'], cons:['LUNCH BAG CARS BLUE']
# DID NOT REACH MINCONF
# Ante:['LUNCH BAG CARS BLUE'], cons:['JUMBO BAG RED RETROSPOT']
# 	 CONF: 0.2608695652173913
# 	 LIFT: 3.523247505887957
#
# KEY:  ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG RED RETROSPOT', 'LUNCH BAG SPACEBOY DESIGN ')
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.4874184529356943
# 	 LIFT: 8.138311114103129
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['LUNCH BAG SPACEBOY DESIGN ']
# 	 CONF: 0.39049394221808015
# 	 LIFT: 8.656404173645553
# Ante:['LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG  BLACK SKULL.']
# ...
# Ante:['LUNCH BAG SUKI DESIGN '], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.49890829694323147
# 	 LIFT: 8.33015433346148
# Ante:['LUNCH BAG SUKI DESIGN '], cons:['LUNCH BAG SPACEBOY DESIGN ']
# 	 CONF: 0.4170305676855895
# 	 LIFT: 9.244663633309921
# Ante:['LUNCH BAG RED RETROSPOT', 'LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG SUKI DESIGN ']
# 	 CONF: 0.49148936170212765
# 	 LIFT: 11.906276131190188
# Ante:['LUNCH BAG RED RETROSPOT', 'LUNCH BAG SUKI DESIGN '], cons:['LUNCH BAG SPACEBOY DESIGN ']
# 	 CONF: 0.5054704595185996
# 	 LIFT: 11.205184312405319
# Ante:['LUNCH BAG SPACEBOY DESIGN ', 'LUNCH BAG SUKI DESIGN '], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.6047120418848168
# 	 LIFT: 10.09673454433716
#
# KEY:  ('ASSORTED COLOUR BIRD ORNAMENT', 'REGENCY CAKESTAND 3 TIER')
# Ante:['ASSORTED COLOUR BIRD ORNAMENT'], cons:['REGENCY CAKESTAND 3 TIER']
# DID NOT REACH MINCONF
# Ante:['REGENCY CAKESTAND 3 TIER'], cons:['ASSORTED COLOUR BIRD ORNAMENT']
# DID NOT REACH MINCONF
#
# KEY:  ('ALARM CLOCK BAKELIKE CHOCOLATE', 'ALARM CLOCK BAKELIKE RED ')
# Ante:['ALARM CLOCK BAKELIKE CHOCOLATE'], cons:['ALARM CLOCK BAKELIKE RED ']
# 	 CONF: 0.6865671641791045
# 	 LIFT: 16.79705112804226
# Ante:['ALARM CLOCK BAKELIKE RED '], cons:['ALARM CLOCK BAKELIKE CHOCOLATE']
# 	 CONF: 0.2535832414553473
# 	 LIFT: 16.797051128042256
#
# KEY:  ('HOT WATER BOTTLE KEEP CALM', 'HOT WATER BOTTLE TEA AND SYMPATHY')
# Ante:['HOT WATER BOTTLE KEEP CALM'], cons:['HOT WATER BOTTLE TEA AND SYMPATHY']
# 	 CONF: 0.3154269972451791
# 	 LIFT: 13.512210557665105
# Ante:['HOT WATER BOTTLE TEA AND SYMPATHY'], cons:['HOT WATER BOTTLE KEEP CALM']
# 	 CONF: 0.4420849420849421
# 	 LIFT: 13.512210557665103
#
# KEY:  ('SET/20 RED RETROSPOT PAPER NAPKINS ', 'SET/6 RED SPOTTY PAPER PLATES')
# Ante:['SET/20 RED RETROSPOT PAPER NAPKINS '], cons:['SET/6 RED SPOTTY PAPER PLATES']
# 	 CONF: 0.3119891008174387
# 	 LIFT: 21.30165583735066
# Ante:['SET/6 RED SPOTTY PAPER PLATES'], cons:['SET/20 RED RETROSPOT PAPER NAPKINS ']
# 	 CONF: 0.7046153846153846
# 	 LIFT: 21.301655837350662
#
# KEY:  ('72 SWEETHEART FAIRY CAKE CASES', 'PACK OF 72 RETROSPOT CAKE CASES')
# Ante:['72 SWEETHEART FAIRY CAKE CASES'], cons:['PACK OF 72 RETROSPOT CAKE CASES']
# 	 CONF: 0.4514851485148515
# 	 LIFT: 9.623876508688333
# Ante:['PACK OF 72 RETROSPOT CAKE CASES'], cons:['72 SWEETHEART FAIRY CAKE CASES']
# 	 CONF: 0.21902017291066284
# 	 LIFT: 9.623876508688333
#
# KEY:  ('JUMBO BAG VINTAGE DOILY ', 'JUMBO BAG VINTAGE LEAF')
# Ante:['JUMBO BAG VINTAGE DOILY '], cons:['JUMBO BAG VINTAGE LEAF']
# 	 CONF: 0.35962145110410093
# 	 LIFT: 10.25706940874036
# Ante:['JUMBO BAG VINTAGE LEAF'], cons:['JUMBO BAG VINTAGE DOILY ']
# 	 CONF: 0.2930591259640103
# 	 LIFT: 10.25706940874036
#
# KEY:  ('LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG PINK POLKADOT')
# Ante:['LUNCH BAG ALPHABET DESIGN'], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.34545454545454546
# 	 LIFT: 8.06060606060606
# Ante:['LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG ALPHABET DESIGN']
# 	 CONF: 0.23974763406940064
# 	 LIFT: 8.06060606060606
#
# KEY:  ('LUNCH BAG SPACEBOY DESIGN ', 'LUNCH BAG VINTAGE LEAF DESIGN')
# Ante:['LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG VINTAGE LEAF DESIGN']
# 	 CONF: 0.22777222777222778
# 	 LIFT: 8.409759957180922
# Ante:['LUNCH BAG VINTAGE LEAF DESIGN'], cons:['LUNCH BAG SPACEBOY DESIGN ']
# 	 CONF: 0.3793677204658902
# 	 LIFT: 8.409759957180922
#
# KEY:  ('JUMBO BAG APPLES', 'JUMBO BAG PINK POLKADOT')
# Ante:['JUMBO BAG APPLES'], cons:['JUMBO BAG PINK POLKADOT']
# 	 CONF: 0.3071718538565629
# 	 LIFT: 7.710569498956031
# Ante:['JUMBO BAG PINK POLKADOT'], cons:['JUMBO BAG APPLES']
# 	 CONF: 0.25678733031674206
# 	 LIFT: 7.71056949895603
#
# KEY:  ('LUNCH BAG RED RETROSPOT', 'WHITE HANGING HEART T-LIGHT HOLDER')
# Ante:['LUNCH BAG RED RETROSPOT'], cons:['WHITE HANGING HEART T-LIGHT HOLDER']
# DID NOT REACH MINCONF
# Ante:['WHITE HANGING HEART T-LIGHT HOLDER'], cons:['LUNCH BAG RED RETROSPOT']
# DID NOT REACH MINCONF
#
# KEY:  ('JUMBO BAG VINTAGE DOILY ', 'LUNCH BAG VINTAGE DOILY ')
# Ante:['JUMBO BAG VINTAGE DOILY '], cons:['LUNCH BAG VINTAGE DOILY ']
# 	 CONF: 0.3580441640378549
# 	 LIFT: 14.577981651376147
# Ante:['LUNCH BAG VINTAGE DOILY '], cons:['JUMBO BAG VINTAGE DOILY ']
# 	 CONF: 0.41651376146788993
# 	 LIFT: 14.577981651376149
#
# KEY:  ('BATHROOM METAL SIGN', 'TOILET METAL SIGN')
# Ante:['BATHROOM METAL SIGN'], cons:['TOILET METAL SIGN']
# 	 CONF: 0.5850515463917526
# 	 LIFT: 42.28760200141039
# Ante:['TOILET METAL SIGN'], cons:['BATHROOM METAL SIGN']
# 	 CONF: 0.739413680781759
# 	 LIFT: 42.28760200141039
#
# KEY:  ('WOODEN STAR CHRISTMAS SCANDINAVIAN', 'WOODEN TREE CHRISTMAS SCANDINAVIAN')
# Ante:['WOODEN STAR CHRISTMAS SCANDINAVIAN'], cons:['WOODEN TREE CHRISTMAS SCANDINAVIAN']
# 	 CONF: 0.5206422018348624
# 	 LIFT: 41.70776338886497
# Ante:['WOODEN TREE CHRISTMAS SCANDINAVIAN'], cons:['WOODEN STAR CHRISTMAS SCANDINAVIAN']
# 	 CONF: 0.8194945848375451
# 	 LIFT: 41.70776338886497
#
# KEY:  ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG PINK POLKADOT', 'LUNCH BAG SPACEBOY DESIGN ')
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.43522833178005593
# 	 LIFT: 10.155327741534638
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['LUNCH BAG SPACEBOY DESIGN ']
# 	 CONF: 0.39049394221808015
# 	 LIFT: 8.656404173645553
# Ante:['LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.491062039957939
# 	 LIFT: 10.155327741534638
# Ante:['LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG SPACEBOY DESIGN ']
# 	 CONF: 0.3890641430073607
# 	 LIFT: 8.624708624708624
# Ante:['LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.41858141858141856
# 	 LIFT: 8.656404173645553
# Ante:['LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.3696303696303696
# 	 LIFT: 8.624708624708624
# Ante:['LUNCH BAG  BLACK SKULL.', 'LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG SPACEBOY DESIGN ']
# 	 CONF: 0.48394004282655245
# 	 LIFT: 10.727901648672526
# Ante:['LUNCH BAG  BLACK SKULL.', 'LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.5393794749403341
# 	 LIFT: 12.58552108194113
# Ante:['LUNCH BAG PINK POLKADOT', 'LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.6108108108108108
# 	 LIFT: 12.631772499433264
#
# KEY:  ('REGENCY CAKESTAND 3 TIER', 'SET OF 3 CAKE TINS PANTRY DESIGN ')
# Ante:['REGENCY CAKESTAND 3 TIER'], cons:['SET OF 3 CAKE TINS PANTRY DESIGN ']
# DID NOT REACH MINCONF
# Ante:['SET OF 3 CAKE TINS PANTRY DESIGN '], cons:['REGENCY CAKESTAND 3 TIER']
# DID NOT REACH MINCONF
#
# KEY:  ('SMALL DOLLY MIX DESIGN ORANGE BOWL', 'SMALL MARSHMALLOWS PINK BOWL')
# Ante:['SMALL DOLLY MIX DESIGN ORANGE BOWL'], cons:['SMALL MARSHMALLOWS PINK BOWL']
# 	 CONF: 0.6243093922651933
# 	 LIFT: 47.935728077386294
# Ante:['SMALL MARSHMALLOWS PINK BOWL'], cons:['SMALL DOLLY MIX DESIGN ORANGE BOWL']
# 	 CONF: 0.7820069204152249
# 	 LIFT: 47.9357280773863
#
# KEY:  ('LUNCH BAG CARS BLUE', 'LUNCH BAG PINK POLKADOT', 'LUNCH BAG SPACEBOY DESIGN ')
# Ante:['LUNCH BAG CARS BLUE'], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.4368048533872599
# 	 LIFT: 10.19211324570273
# Ante:['LUNCH BAG CARS BLUE'], cons:['LUNCH BAG SPACEBOY DESIGN ']
# 	 CONF: 0.3993933265925177
# 	 LIFT: 8.853684232855112
# Ante:['LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.45425867507886436
# 	 LIFT: 10.19211324570273
# Ante:['LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG SPACEBOY DESIGN ']
# 	 CONF: 0.3890641430073607
# 	 LIFT: 8.624708624708624
# Ante:['LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.3946053946053946
# 	 LIFT: 8.853684232855112
# Ante:['LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.3696303696303696
# 	 LIFT: 8.624708624708624
# Ante:['LUNCH BAG CARS BLUE', 'LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG SPACEBOY DESIGN ']
# 	 CONF: 0.5208333333333334
# 	 LIFT: 11.54574592074592
# Ante:['LUNCH BAG CARS BLUE', 'LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.569620253164557
# 	 LIFT: 13.29113924050633
# Ante:['LUNCH BAG PINK POLKADOT', 'LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.6081081081081081
# 	 LIFT: 13.644002951384145
#
# KEY:  ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG SUKI DESIGN ', 'LUNCH BAG WOODLAND')
# Ante:['LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG SUKI DESIGN ']
# 	 CONF: 0.3438675696012039
# 	 LIFT: 8.330154333461477
# Ante:['LUNCH BAG RED RETROSPOT'], cons:['LUNCH BAG WOODLAND']
# 	 CONF: 0.3303235515425132
# 	 LIFT: 8.736447686207827
# Ante:['LUNCH BAG SUKI DESIGN '], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.49890829694323147
# 	 LIFT: 8.33015433346148
# Ante:['LUNCH BAG SUKI DESIGN '], cons:['LUNCH BAG WOODLAND']
# 	 CONF: 0.3384279475982533
# 	 LIFT: 8.95079398951757
# Ante:['LUNCH BAG WOODLAND'], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.5232419547079857
# 	 LIFT: 8.736447686207828
# Ante:['LUNCH BAG WOODLAND'], cons:['LUNCH BAG SUKI DESIGN ']
# 	 CONF: 0.3694874851013111
# 	 LIFT: 8.950793989517567
# Ante:['LUNCH BAG RED RETROSPOT', 'LUNCH BAG SUKI DESIGN '], cons:['LUNCH BAG WOODLAND']
# 	 CONF: 0.4923413566739606
# 	 LIFT: 13.021519314177814
# Ante:['LUNCH BAG RED RETROSPOT', 'LUNCH BAG WOODLAND'], cons:['LUNCH BAG SUKI DESIGN ']
# 	 CONF: 0.5125284738041003
# 	 LIFT: 12.415946325014175
# Ante:['LUNCH BAG SUKI DESIGN ', 'LUNCH BAG WOODLAND'], cons:['LUNCH BAG RED RETROSPOT']
# 	 CONF: 0.7258064516129032
# 	 LIFT: 12.118619383965632
#
# KEY:  ('JUMBO BAG RED RETROSPOT', 'LUNCH BAG APPLE DESIGN')
# Ante:['JUMBO BAG RED RETROSPOT'], cons:['LUNCH BAG APPLE DESIGN']
# DID NOT REACH MINCONF
# Ante:['LUNCH BAG APPLE DESIGN'], cons:['JUMBO BAG RED RETROSPOT']
# 	 CONF: 0.25626423690205014
# 	 LIFT: 3.46104894513481
#
# KEY:  ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG CARS BLUE', 'LUNCH BAG SPACEBOY DESIGN ')
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.3960857409133271
# 	 LIFT: 8.886898474081626
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['LUNCH BAG SPACEBOY DESIGN ']
# 	 CONF: 0.39049394221808015
# 	 LIFT: 8.656404173645553
# Ante:['LUNCH BAG CARS BLUE'], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.42972699696663297
# 	 LIFT: 8.886898474081628
# Ante:['LUNCH BAG CARS BLUE'], cons:['LUNCH BAG SPACEBOY DESIGN ']
# 	 CONF: 0.3993933265925177
# 	 LIFT: 8.853684232855112
# Ante:['LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.41858141858141856
# 	 LIFT: 8.656404173645553
# Ante:['LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.3946053946053946
# 	 LIFT: 8.853684232855112
# Ante:['LUNCH BAG  BLACK SKULL.', 'LUNCH BAG CARS BLUE'], cons:['LUNCH BAG SPACEBOY DESIGN ']
# 	 CONF: 0.5270588235294118
# 	 LIFT: 11.683751542575072
# Ante:['LUNCH BAG  BLACK SKULL.', 'LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.5346062052505967
# 	 LIFT: 11.994855100617533
# Ante:['LUNCH BAG CARS BLUE', 'LUNCH BAG SPACEBOY DESIGN '], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.5670886075949367
# 	 LIFT: 11.727582667783455
#
# KEY:  ('ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE ORANGE')
# Ante:['ALARM CLOCK BAKELIKE GREEN'], cons:['ALARM CLOCK BAKELIKE ORANGE']
# 	 CONF: 0.276885043263288
# 	 LIFT: 16.340635930883938
# Ante:['ALARM CLOCK BAKELIKE ORANGE'], cons:['ALARM CLOCK BAKELIKE GREEN']
# 	 CONF: 0.5957446808510638
# 	 LIFT: 16.340635930883938
#
# KEY:  ('JUMBO BAG PINK POLKADOT', 'JUMBO BAG RED RETROSPOT', 'JUMBO STORAGE BAG SUKI')
# Ante:['JUMBO BAG PINK POLKADOT'], cons:['JUMBO BAG RED RETROSPOT']
# 	 CONF: 0.6266968325791855
# 	 LIFT: 8.464030867274575
# Ante:['JUMBO BAG PINK POLKADOT'], cons:['JUMBO STORAGE BAG SUKI']
# 	 CONF: 0.3212669683257919
# 	 LIFT: 9.012533536219118
# Ante:['JUMBO BAG RED RETROSPOT'], cons:['JUMBO BAG PINK POLKADOT']
# 	 CONF: 0.3371880706025563
# 	 LIFT: 8.464030867274575
# Ante:['JUMBO BAG RED RETROSPOT'], cons:['JUMBO STORAGE BAG SUKI']
# 	 CONF: 0.2696287279367012
# 	 LIFT: 7.563920951852591
# Ante:['JUMBO STORAGE BAG SUKI'], cons:['JUMBO BAG PINK POLKADOT']
# 	 CONF: 0.359039190897598
# 	 LIFT: 9.012533536219117
# Ante:['JUMBO STORAGE BAG SUKI'], cons:['JUMBO BAG RED RETROSPOT']
# 	 CONF: 0.5600505689001264
# 	 LIFT: 7.563920951852589
# Ante:['JUMBO BAG PINK POLKADOT', 'JUMBO BAG RED RETROSPOT'], cons:['JUMBO STORAGE BAG SUKI']
# 	 CONF: 0.40252707581227437
# 	 LIFT: 11.292131241813362
# Ante:['JUMBO BAG PINK POLKADOT', 'JUMBO STORAGE BAG SUKI'], cons:['JUMBO BAG RED RETROSPOT']
# 	 CONF: 0.7852112676056338
# 	 LIFT: 10.604892287382235
# Ante:['JUMBO BAG RED RETROSPOT', 'JUMBO STORAGE BAG SUKI'], cons:['JUMBO BAG PINK POLKADOT']
# 	 CONF: 0.5033860045146726
# 	 LIFT: 12.635899819208808
#
# KEY:  ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG CARS BLUE', 'LUNCH BAG SUKI DESIGN ')
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.3960857409133271
# 	 LIFT: 8.886898474081626
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['LUNCH BAG SUKI DESIGN ']
# 	 CONF: 0.3830382106244175
# 	 LIFT: 9.279058835977974
# Ante:['LUNCH BAG CARS BLUE'], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.42972699696663297
# 	 LIFT: 8.886898474081628
# Ante:['LUNCH BAG CARS BLUE'], cons:['LUNCH BAG SUKI DESIGN ']
# 	 CONF: 0.39838220424671383
# 	 LIFT: 9.650765406369628
# Ante:['LUNCH BAG SUKI DESIGN '], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.44868995633187775
# 	 LIFT: 9.279058835977976
# Ante:['LUNCH BAG SUKI DESIGN '], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.43013100436681223
# 	 LIFT: 9.65076540636963
# Ante:['LUNCH BAG  BLACK SKULL.', 'LUNCH BAG CARS BLUE'], cons:['LUNCH BAG SUKI DESIGN ']
# 	 CONF: 0.5247058823529411
# 	 LIFT: 12.710942717698432
# Ante:['LUNCH BAG  BLACK SKULL.', 'LUNCH BAG SUKI DESIGN '], cons:['LUNCH BAG CARS BLUE']
# 	 CONF: 0.5425790754257908
# 	 LIFT: 12.173740832859755
# Ante:['LUNCH BAG CARS BLUE', 'LUNCH BAG SUKI DESIGN '], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.565989847715736
# 	 LIFT: 11.70485994483894
#
# KEY:  ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG PINK POLKADOT', 'LUNCH BAG SUKI DESIGN ')
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.43522833178005593
# 	 LIFT: 10.155327741534638
# Ante:['LUNCH BAG  BLACK SKULL.'], cons:['LUNCH BAG SUKI DESIGN ']
# 	 CONF: 0.3830382106244175
# 	 LIFT: 9.279058835977974
# Ante:['LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.491062039957939
# 	 LIFT: 10.155327741534638
# Ante:['LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG SUKI DESIGN ']
# 	 CONF: 0.38065194532071506
# 	 LIFT: 9.221251819505094
# Ante:['LUNCH BAG SUKI DESIGN '], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.44868995633187775
# 	 LIFT: 9.279058835977976
# Ante:['LUNCH BAG SUKI DESIGN '], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.3951965065502183
# 	 LIFT: 9.221251819505094
# Ante:['LUNCH BAG  BLACK SKULL.', 'LUNCH BAG PINK POLKADOT'], cons:['LUNCH BAG SUKI DESIGN ']
# 	 CONF: 0.47751605995717344
# 	 LIFT: 11.567774421888295
# Ante:['LUNCH BAG  BLACK SKULL.', 'LUNCH BAG SUKI DESIGN '], cons:['LUNCH BAG PINK POLKADOT']
# 	 CONF: 0.5425790754257908
# 	 LIFT: 12.660178426601783
# Ante:['LUNCH BAG PINK POLKADOT', 'LUNCH BAG SUKI DESIGN '], cons:['LUNCH BAG  BLACK SKULL.']
# 	 CONF: 0.6160220994475138
# 	 LIFT: 12.739543696868903
#
# KEY:  ('60 TEATIME FAIRY CAKE CASES', '72 SWEETHEART FAIRY CAKE CASES')
# Ante:['60 TEATIME FAIRY CAKE CASES'], cons:['72 SWEETHEART FAIRY CAKE CASES']
# 	 CONF: 0.3358433734939759
# 	 LIFT: 14.75715734224025
# Ante:['72 SWEETHEART FAIRY CAKE CASES'], cons:['60 TEATIME FAIRY CAKE CASES']
# 	 CONF: 0.4415841584158416
# 	 LIFT: 14.757157342240248
#
# KEY:  ('JUMBO STORAGE BAG SUKI', 'LUNCH BAG SUKI DESIGN ')
# Ante:['JUMBO STORAGE BAG SUKI'], cons:['LUNCH BAG SUKI DESIGN ']
# 	 CONF: 0.28192161820480405
# 	 LIFT: 6.829520423542141
# Ante:['LUNCH BAG SUKI DESIGN '], cons:['JUMBO STORAGE BAG SUKI']
# 	 CONF: 0.24344978165938866
# 	 LIFT: 6.829520423542142
#
# KEY:  ('60 TEATIME FAIRY CAKE CASES', 'PACK OF 60 DINOSAUR CAKE CASES')
# Ante:['60 TEATIME FAIRY CAKE CASES'], cons:['PACK OF 60 DINOSAUR CAKE CASES']
# 	 CONF: 0.3358433734939759
# 	 LIFT: 14.008203868103994
# Ante:['PACK OF 60 DINOSAUR CAKE CASES'], cons:['60 TEATIME FAIRY CAKE CASES']
# 	 CONF: 0.4191729323308271
# 	 LIFT: 14.008203868103996
#
# KEY:  ('RETROSPOT HEART HOT WATER BOTTLE', 'SCOTTIE DOG HOT WATER BOTTLE')
# Ante:['RETROSPOT HEART HOT WATER BOTTLE'], cons:['SCOTTIE DOG HOT WATER BOTTLE']
# 	 CONF: 0.41035120147874304
# 	 LIFT: 13.734077165630932
# Ante:['SCOTTIE DOG HOT WATER BOTTLE'], cons:['RETROSPOT HEART HOT WATER BOTTLE']
# 	 CONF: 0.334841628959276
# 	 LIFT: 13.734077165630932

# %%
assoc_ex11
# Out:
# [{'antecedent': ('SET/6 RED SPOTTY PAPER PLATES',),
#   'consequent': 'SET/6 RED SPOTTY PAPER CUPS',
#   'support': 236,
#   'confidence': 0.7261538461538461,
#   'lift': 56.53808367071525},
#  {'antecedent': ('SET/6 RED SPOTTY PAPER CUPS',),
#   'consequent': 'SET/6 RED SPOTTY PAPER PLATES',
#   'support': 236,
#   'confidence': 0.8280701754385965,
#   'lift': 56.53808367071525},
#  {'antecedent': ('REGENCY TEA PLATE ROSES ',),
#   'consequent': 'REGENCY TEA PLATE GREEN ',
#   'support': 232,
#   'confidence': 0.6823529411764706,
#   'lift': 55.05967914438503},
#  {'antecedent': ('REGENCY TEA PLATE GREEN ',),
#   'consequent': 'REGENCY TEA PLATE ROSES ',
#   'support': 232,
#   'confidence': 0.8436363636363636,
#   'lift': 55.05967914438502},
#  {'antecedent': ("POPPY'S PLAYHOUSE KITCHEN",),
#   'consequent': "POPPY'S PLAYHOUSE BEDROOM ",
#   'support': 255,
#   'confidence': 0.7306590257879656,
#   'lift': 50.82546640199046},
#  {'antecedent': ("POPPY'S PLAYHOUSE BEDROOM ",),
#   'consequent': "POPPY'S PLAYHOUSE KITCHEN",
#   'support': 255,
#   'confidence': 0.799373040752351,
#   'lift': 50.825466401990454},
#  {'antecedent': ('SMALL MARSHMALLOWS PINK BOWL',),
#   'consequent': 'SMALL DOLLY MIX DESIGN ORANGE BOWL',
#   'support': 226,
#   'confidence': 0.7820069204152249,
#   'lift': 47.9357280773863},
#  {'antecedent': ('SMALL DOLLY MIX DESIGN ORANGE BOWL',),
#   'consequent': 'SMALL MARSHMALLOWS PINK BOWL',
#   'support': 226,
#   'confidence': 0.6243093922651933,
#   'lift': 47.935728077386294},
#  {'antecedent': ('PINK HAPPY BIRTHDAY BUNTING',),
#   'consequent': 'BLUE HAPPY BIRTHDAY BUNTING',
#   'support': 256,
#   'confidence': 0.7052341597796143,
#   'lift': 43.71269833941241},
#  {'antecedent': ('BLUE HAPPY BIRTHDAY BUNTING',),
#   'consequent': 'PINK HAPPY BIRTHDAY BUNTING',
#   'support': 256,
#   'confidence': 0.7150837988826816,
#   'lift': 43.712698339412405},
#  {'antecedent': ('TOILET METAL SIGN',),
#   'consequent': 'BATHROOM METAL SIGN',
#   'support': 227,
#   'confidence': 0.739413680781759,
#   'lift': 42.28760200141039},
#  {'antecedent': ('BATHROOM METAL SIGN',),
#   'consequent': 'TOILET METAL SIGN',
#   'support': 227,
#   'confidence': 0.5850515463917526,
#   'lift': 42.28760200141039},
#  {'antecedent': ('WOODEN TREE CHRISTMAS SCANDINAVIAN',),
#   'consequent': 'WOODEN STAR CHRISTMAS SCANDINAVIAN',
#   'support': 227,
#   'confidence': 0.8194945848375451,
#   'lift': 41.70776338886497},
#  {'antecedent': ('WOODEN STAR CHRISTMAS SCANDINAVIAN',),
#   'consequent': 'WOODEN TREE CHRISTMAS SCANDINAVIAN',
#   'support': 227,
#   'confidence': 0.5206422018348624,
#   'lift': 41.70776338886497},
#  {'antecedent': ('WOODEN HEART CHRISTMAS SCANDINAVIAN',),
#   'consequent': 'WOODEN STAR CHRISTMAS SCANDINAVIAN',
#   'support': 320,
#   'confidence': 0.6881720430107527,
#   'lift': 35.024168886258266},
#  {'antecedent': ('WOODEN STAR CHRISTMAS SCANDINAVIAN',),
#   'consequent': 'WOODEN HEART CHRISTMAS SCANDINAVIAN',
#   'support': 320,
#   'confidence': 0.7339449541284404,
#   'lift': 35.02416888625826},
#  {'antecedent': ('FELTCRAFT PRINCESS CHARLOTTE DOLL',),
#   'consequent': 'FELTCRAFT PRINCESS LOLA DOLL',
#   'support': 238,
#   'confidence': 0.5935162094763092,
#   'lift': 34.6582228638929},
#  {'antecedent': ('FELTCRAFT PRINCESS LOLA DOLL',),
#   'consequent': 'FELTCRAFT PRINCESS CHARLOTTE DOLL',
#   'support': 238,
#   'confidence': 0.6263157894736842,
#   'lift': 34.658222863892895},
#  {'antecedent': ('SET OF 12 MINI LOAF BAKING CASES',),
#   'consequent': 'SET OF 12 FAIRY CAKE BAKING CASES',
#   'support': 247,
#   'confidence': 0.6785714285714286,
#   'lift': 32.037234042553195},
#  {'antecedent': ('SET OF 12 FAIRY CAKE BAKING CASES',),
#   'consequent': 'SET OF 12 MINI LOAF BAKING CASES',
#   'support': 247,
#   'confidence': 0.5255319148936171,
#   'lift': 32.037234042553195},
#  {'antecedent': ('GREEN REGENCY TEACUP AND SAUCER',
#    'REGENCY CAKESTAND 3 TIER',
#    'ROSES REGENCY TEACUP AND SAUCER '),
#   'consequent': 'PINK REGENCY TEACUP AND SAUCER',
#   'support': 241,
#   'confidence': 0.7626582278481012,
#   'lift': 28.635171025295033},
#  {'antecedent': ('PINK REGENCY TEACUP AND SAUCER',
#    'REGENCY CAKESTAND 3 TIER',
#    'ROSES REGENCY TEACUP AND SAUCER '),
#   'consequent': 'GREEN REGENCY TEACUP AND SAUCER',
#   'support': 241,
#   'confidence': 0.8892988929889298,
#   'lift': 26.921613145190115},
#  {'antecedent': ('GREEN REGENCY TEACUP AND SAUCER',
#    'REGENCY CAKESTAND 3 TIER'),
#   'consequent': 'PINK REGENCY TEACUP AND SAUCER',
#   'support': 241,
#   'confidence': 0.7154046997389034,
#   'lift': 26.860964952971685},
#  {'antecedent': ('GREEN REGENCY TEACUP AND SAUCER',
#    'ROSES REGENCY TEACUP AND SAUCER '),
#   'consequent': 'PINK REGENCY TEACUP AND SAUCER',
#   'support': 241,
#   'confidence': 0.7127468581687613,
#   'lift': 26.761172221260257},
#  {'antecedent': ('PINK REGENCY TEACUP AND SAUCER',
#    'ROSES REGENCY TEACUP AND SAUCER '),
#   'consequent': 'GREEN REGENCY TEACUP AND SAUCER',
#   'support': 241,
#   'confidence': 0.8802660753880266,
#   'lift': 26.648164001173683},
#  {'antecedent': ('PINK REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER'),
#   'consequent': 'GREEN REGENCY TEACUP AND SAUCER',
#   'support': 241,
#   'confidence': 0.8589341692789969,
#   'lift': 26.00238637967386},
#  {'antecedent': ('PINK REGENCY TEACUP AND SAUCER',),
#   'consequent': 'GREEN REGENCY TEACUP AND SAUCER',
#   'support': 241,
#   'confidence': 0.7969543147208121,
#   'lift': 24.12607945928352},
#  {'antecedent': ('GREEN REGENCY TEACUP AND SAUCER',),
#   'consequent': 'PINK REGENCY TEACUP AND SAUCER',
#   'support': 241,
#   'confidence': 0.6425648021828103,
#   'lift': 24.12607945928352},
#  {'antecedent': ("JUMBO BAG 50'S CHRISTMAS ",),
#   'consequent': 'JUMBO BAG VINTAGE CHRISTMAS ',
#   'support': 247,
#   'confidence': 0.41652613827993257,
#   'lift': 23.578354613346185},
#  {'antecedent': ('JUMBO BAG VINTAGE CHRISTMAS ',),
#   'consequent': "JUMBO BAG 50'S CHRISTMAS ",
#   'support': 247,
#   'confidence': 0.6301020408163265,
#   'lift': 23.57835461334618},
#  {'antecedent': ('REGENCY CAKESTAND 3 TIER',
#    'ROSES REGENCY TEACUP AND SAUCER '),
#   'consequent': 'PINK REGENCY TEACUP AND SAUCER',
#   'support': 241,
#   'confidence': 0.6273148148148148,
#   'lift': 23.553495331202605},
#  {'antecedent': ('HAND WARMER SCOTTY DOG DESIGN',),
#   'consequent': 'HAND WARMER BIRD DESIGN',
#   'support': 241,
#   'confidence': 0.5073684210526316,
#   'lift': 23.455219298245613},
#  {'antecedent': ('HAND WARMER BIRD DESIGN',),
#   'consequent': 'HAND WARMER SCOTTY DOG DESIGN',
#   'support': 241,
#   'confidence': 0.5020833333333333,
#   'lift': 23.455219298245613},
#  {'antecedent': ('GREEN REGENCY TEACUP AND SAUCER',
#    'PINK REGENCY TEACUP AND SAUCER',
#    'REGENCY CAKESTAND 3 TIER'),
#   'consequent': 'ROSES REGENCY TEACUP AND SAUCER ',
#   'support': 241,
#   'confidence': 0.8795620437956204,
#   'lift': 23.346270038067964},
#  {'antecedent': ('PINK REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER'),
#   'consequent': 'ROSES REGENCY TEACUP AND SAUCER ',
#   'support': 241,
#   'confidence': 0.8495297805642633,
#   'lift': 22.54912180708254},
#  {'antecedent': ('HAND WARMER SCOTTY DOG DESIGN',),
#   'consequent': 'HAND WARMER OWL DESIGN',
#   'support': 281,
#   'confidence': 0.5915789473684211,
#   'lift': 22.516529746321208},
#  {'antecedent': ('HAND WARMER OWL DESIGN',),
#   'consequent': 'HAND WARMER SCOTTY DOG DESIGN',
#   'support': 281,
#   'confidence': 0.48198970840480276,
#   'lift': 22.516529746321204},
#  {'antecedent': ('GREEN REGENCY TEACUP AND SAUCER',
#    'PINK REGENCY TEACUP AND SAUCER'),
#   'consequent': 'ROSES REGENCY TEACUP AND SAUCER ',
#   'support': 241,
#   'confidence': 0.8428874734607219,
#   'lift': 22.37281463647538},
#  {'antecedent': ('REGENCY CAKESTAND 3 TIER',
#    'ROSES REGENCY TEACUP AND SAUCER '),
#   'consequent': 'GREEN REGENCY TEACUP AND SAUCER',
#   'support': 241,
#   'confidence': 0.7314814814814815,
#   'lift': 22.1440301146986},
#  {'antecedent': ('GREEN REGENCY TEACUP AND SAUCER',
#    'REGENCY CAKESTAND 3 TIER'),
#   'consequent': 'ROSES REGENCY TEACUP AND SAUCER ',
#   'support': 241,
#   'confidence': 0.825065274151436,
#   'lift': 21.899758891651153},
#  {'antecedent': ('SET/6 RED SPOTTY PAPER PLATES',),
#   'consequent': 'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   'support': 229,
#   'confidence': 0.7046153846153846,
#   'lift': 21.301655837350662},
#  {'antecedent': ('SET/20 RED RETROSPOT PAPER NAPKINS ',),
#   'consequent': 'SET/6 RED SPOTTY PAPER PLATES',
#   'support': 229,
#   'confidence': 0.3119891008174387,
#   'lift': 21.30165583735066},
#  {'antecedent': ('HAND WARMER BIRD DESIGN',),
#   'consequent': 'HAND WARMER OWL DESIGN',
#   'support': 268,
#   'confidence': 0.5583333333333333,
#   'lift': 21.251143510577474},
#  {'antecedent': ('HAND WARMER OWL DESIGN',),
#   'consequent': 'HAND WARMER BIRD DESIGN',
#   'support': 268,
#   'confidence': 0.45969125214408235,
#   'lift': 21.25114351057747},
#  {'antecedent': ('PINK CREAM FELT CRAFT TRINKET BOX ',),
#   'consequent': 'PINK BLUE FELT CRAFT TRINKET BOX',
#   'support': 236,
#   'confidence': 0.43947858472998136,
#   'lift': 21.15407764676418},
#  {'antecedent': ('PINK BLUE FELT CRAFT TRINKET BOX',),
#   'consequent': 'PINK CREAM FELT CRAFT TRINKET BOX ',
#   'support': 236,
#   'confidence': 0.5119305856832972,
#   'lift': 21.15407764676418},
#  {'antecedent': ('SPACEBOY LUNCH BOX ',),
#   'consequent': 'DOLLY GIRL LUNCH BOX',
#   'support': 424,
#   'confidence': 0.5955056179775281,
#   'lift': 21.142831460674156},
#  {'antecedent': ('DOLLY GIRL LUNCH BOX',),
#   'consequent': 'SPACEBOY LUNCH BOX ',
#   'support': 424,
#   'confidence': 0.6784,
#   'lift': 21.142831460674156},
#  {'antecedent': ('GARDENERS KNEELING PAD KEEP CALM ',),
#   'consequent': 'GARDENERS KNEELING PAD CUP OF TEA ',
#   'support': 466,
#   'confidence': 0.6075619295958279,
#   'lift': 20.999687255033365},
#  {'antecedent': ('GARDENERS KNEELING PAD CUP OF TEA ',),
#   'consequent': 'GARDENERS KNEELING PAD KEEP CALM ',
#   'support': 466,
#   'confidence': 0.7258566978193146,
#   'lift': 20.999687255033365},
#  {'antecedent': ('SET OF 3 HEART COOKIE CUTTERS',),
#   'consequent': 'SET OF 3 BUTTERFLY COOKIE CUTTERS',
#   'support': 245,
#   'confidence': 0.4666666666666667,
#   'lift': 20.50561056105611},
#  {'antecedent': ('SET OF 3 BUTTERFLY COOKIE CUTTERS',),
#   'consequent': 'SET OF 3 HEART COOKIE CUTTERS',
#   'support': 245,
#   'confidence': 0.48514851485148514,
#   'lift': 20.505610561056105},
#  {'antecedent': ('LARGE WHITE HEART OF WICKER',),
#   'consequent': 'SMALL WHITE HEART OF WICKER',
#   'support': 282,
#   'confidence': 0.5412667946257198,
#   'lift': 20.496092444956865},
#  {'antecedent': ('SMALL WHITE HEART OF WICKER',),
#   'consequent': 'LARGE WHITE HEART OF WICKER',
#   'support': 282,
#   'confidence': 0.4812286689419795,
#   'lift': 20.49609244495686},
#  {'antecedent': ('ROUND SNACK BOXES SET OF4 WOODLAND ',),
#   'consequent': 'ROUND SNACK BOXES SET OF 4 FRUITS ',
#   'support': 267,
#   'confidence': 0.4362745098039216,
#   'lift': 20.46708535422626},
#  {'antecedent': ('ROUND SNACK BOXES SET OF 4 FRUITS ',),
#   'consequent': 'ROUND SNACK BOXES SET OF4 WOODLAND ',
#   'support': 267,
#   'confidence': 0.5644820295983086,
#   'lift': 20.467085354226256},
#  {'antecedent': ('RED  HARMONICA IN BOX ',),
#   'consequent': 'BLUE HARMONICA IN BOX ',
#   'support': 272,
#   'confidence': 0.4780316344463972,
#   'lift': 20.43838529550203},
#  {'antecedent': ('BLUE HARMONICA IN BOX ',),
#   'consequent': 'RED  HARMONICA IN BOX ',
#   'support': 272,
#   'confidence': 0.5240847784200385,
#   'lift': 20.43838529550203},
#  {'antecedent': ('RED KITCHEN SCALES',),
#   'consequent': 'IVORY KITCHEN SCALES',
#   'support': 270,
#   'confidence': 0.5781584582441114,
#   'lift': 20.396400935511657},
#  {'antecedent': ('IVORY KITCHEN SCALES',),
#   'consequent': 'RED KITCHEN SCALES',
#   'support': 270,
#   'confidence': 0.4292527821939587,
#   'lift': 20.396400935511654},
#  {'antecedent': ('ROSES REGENCY TEACUP AND SAUCER ',),
#   'consequent': 'PINK REGENCY TEACUP AND SAUCER',
#   'support': 241,
#   'confidence': 0.5394736842105263,
#   'lift': 20.25536557128863},
#  {'antecedent': ('PINK REGENCY TEACUP AND SAUCER',),
#   'consequent': 'ROSES REGENCY TEACUP AND SAUCER ',
#   'support': 241,
#   'confidence': 0.7631133671742809,
#   'lift': 20.25536557128863},
#  {'antecedent': ('ROSES REGENCY TEACUP AND SAUCER ',),
#   'consequent': 'GREEN REGENCY TEACUP AND SAUCER',
#   'support': 241,
#   'confidence': 0.666267942583732,
#   'lift': 20.16983034915827},
#  {'antecedent': ('GREEN REGENCY TEACUP AND SAUCER',),
#   'consequent': 'ROSES REGENCY TEACUP AND SAUCER ',
#   'support': 241,
#   'confidence': 0.7598908594815825,
#   'lift': 20.16983034915827},
#  {'antecedent': ('JUMBO BAG APPLES',),
#   'consequent': 'JUMBO BAG PEARS',
#   'support': 316,
#   'confidence': 0.42760487144790255,
#   'lift': 19.93393297779193},
#  {'antecedent': ('JUMBO BAG PEARS',),
#   'consequent': 'JUMBO BAG APPLES',
#   'support': 316,
#   'confidence': 0.6638655462184874,
#   'lift': 19.933932977791926},
#  {'antecedent': ('JUMBO BAG SCANDINAVIAN BLUE PAISLEY',),
#   'consequent': 'JUMBO BAG PINK VINTAGE PAISLEY',
#   'support': 243,
#   'confidence': 0.5294117647058824,
#   'lift': 19.13297566583637},
#  {'antecedent': ('JUMBO BAG PINK VINTAGE PAISLEY',),
#   'consequent': 'JUMBO BAG SCANDINAVIAN BLUE PAISLEY',
#   'support': 243,
#   'confidence': 0.3957654723127036,
#   'lift': 19.13297566583637},
#  {'antecedent': ('ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE PINK'),
#   'consequent': 'ALARM CLOCK BAKELIKE RED ',
#   'support': 268,
#   'confidence': 0.7790697674418605,
#   'lift': 19.060152303787085},
#  {'antecedent': ('RED RETROSPOT CHARLOTTE BAG',),
#   'consequent': 'CHARLOTTE BAG PINK POLKADOT',
#   'support': 326,
#   'confidence': 0.43178807947019865,
#   'lift': 19.01066961000736},
#  {'antecedent': ('CHARLOTTE BAG PINK POLKADOT',),
#   'consequent': 'RED RETROSPOT CHARLOTTE BAG',
#   'support': 326,
#   'confidence': 0.6468253968253969,
#   'lift': 19.01066961000736},
#  {'antecedent': ('PLASTERS IN TIN WOODLAND ANIMALS',),
#   'consequent': 'PLASTERS IN TIN SPACEBOY',
#   'support': 294,
#   'confidence': 0.4966216216216216,
#   'lift': 18.773481744095033},
#  {'antecedent': ('PLASTERS IN TIN SPACEBOY',),
#   'consequent': 'PLASTERS IN TIN WOODLAND ANIMALS',
#   'support': 294,
#   'confidence': 0.5008517887563884,
#   'lift': 18.77348174409503},
#  {'antecedent': ('ALARM CLOCK BAKELIKE PINK', 'ALARM CLOCK BAKELIKE RED '),
#   'consequent': 'ALARM CLOCK BAKELIKE GREEN',
#   'support': 268,
#   'confidence': 0.6650124069478908,
#   'lift': 18.240575167087385},
#  {'antecedent': ('PLASTERS IN TIN WOODLAND ANIMALS',),
#   'consequent': 'PLASTERS IN TIN CIRCUS PARADE ',
#   'support': 256,
#   'confidence': 0.43243243243243246,
#   'lift': 18.070952308240443},
#  {'antecedent': ('PLASTERS IN TIN CIRCUS PARADE ',),
#   'consequent': 'PLASTERS IN TIN WOODLAND ANIMALS',
#   'support': 256,
#   'confidence': 0.4821092278719397,
#   'lift': 18.070952308240443},
#  {'antecedent': ('BAKING SET SPACEBOY DESIGN',),
#   'consequent': 'BAKING SET 9 PIECE RETROSPOT ',
#   'support': 312,
#   'confidence': 0.7107061503416856,
#   'lift': 17.900759904746884},
#  {'antecedent': ('BAKING SET 9 PIECE RETROSPOT ',),
#   'consequent': 'BAKING SET SPACEBOY DESIGN',
#   'support': 312,
#   'confidence': 0.35414301929625425,
#   'lift': 17.900759904746884},
#  {'antecedent': ('HOT WATER BOTTLE I AM SO POORLY',),
#   'consequent': 'CHOCOLATE HOT WATER BOTTLE',
#   'support': 290,
#   'confidence': 0.5686274509803921,
#   'lift': 17.84701999611726},
#  {'antecedent': ('CHOCOLATE HOT WATER BOTTLE',),
#   'consequent': 'HOT WATER BOTTLE I AM SO POORLY',
#   'support': 290,
#   'confidence': 0.4101838755304102,
#   'lift': 17.84701999611726},
#  {'antecedent': ('ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE RED '),
#   'consequent': 'ALARM CLOCK BAKELIKE PINK',
#   'support': 268,
#   'confidence': 0.5,
#   'lift': 17.63910969793323},
#  {'antecedent': ('PLASTERS IN TIN SPACEBOY',),
#   'consequent': 'PLASTERS IN TIN CIRCUS PARADE ',
#   'support': 246,
#   'confidence': 0.4190800681431005,
#   'lift': 17.512969325980038},
#  {'antecedent': ('PLASTERS IN TIN CIRCUS PARADE ',),
#   'consequent': 'PLASTERS IN TIN SPACEBOY',
#   'support': 246,
#   'confidence': 0.4632768361581921,
#   'lift': 17.512969325980038},
#  {'antecedent': ('STRAWBERRY CHARLOTTE BAG',),
#   'consequent': 'RED RETROSPOT CHARLOTTE BAG',
#   'support': 300,
#   'confidence': 0.5952380952380952,
#   'lift': 17.49448123620309},
#  {'antecedent': ('RED RETROSPOT CHARLOTTE BAG',),
#   'consequent': 'STRAWBERRY CHARLOTTE BAG',
#   'support': 300,
#   'confidence': 0.3973509933774834,
#   'lift': 17.49448123620309},
#  {'antecedent': ('STRAWBERRY CHARLOTTE BAG',),
#   'consequent': 'CHARLOTTE BAG SUKI DESIGN',
#   'support': 237,
#   'confidence': 0.47023809523809523,
#   'lift': 17.478364042434393},
#  {'antecedent': ('CHARLOTTE BAG SUKI DESIGN',),
#   'consequent': 'STRAWBERRY CHARLOTTE BAG',
#   'support': 237,
#   'confidence': 0.3969849246231156,
#   'lift': 17.478364042434393},
#  {'antecedent': ('ALARM CLOCK BAKELIKE PINK',),
#   'consequent': 'ALARM CLOCK BAKELIKE IVORY',
#   'support': 237,
#   'confidence': 0.3767885532591415,
#   'lift': 17.418620826709063},
#  {'antecedent': ('ALARM CLOCK BAKELIKE IVORY',),
#   'consequent': 'ALARM CLOCK BAKELIKE PINK',
#   'support': 237,
#   'confidence': 0.49375,
#   'lift': 17.418620826709063},
#  {'antecedent': ('CHARLOTTE BAG SUKI DESIGN',),
#   'consequent': 'CHARLOTTE BAG PINK POLKADOT',
#   'support': 232,
#   'confidence': 0.38860971524288107,
#   'lift': 17.10962218499907},
#  {'antecedent': ('CHARLOTTE BAG PINK POLKADOT',),
#   'consequent': 'CHARLOTTE BAG SUKI DESIGN',
#   'support': 232,
#   'confidence': 0.4603174603174603,
#   'lift': 17.10962218499907},
#  {'antecedent': ('WOODLAND CHARLOTTE BAG',),
#   'consequent': 'CHARLOTTE BAG SUKI DESIGN',
#   'support': 245,
#   'confidence': 0.45454545454545453,
#   'lift': 16.89508146794579},
#  {'antecedent': ('CHARLOTTE BAG SUKI DESIGN',),
#   'consequent': 'WOODLAND CHARLOTTE BAG',
#   'support': 245,
#   'confidence': 0.4103852596314908,
#   'lift': 16.89508146794579},
#  {'antecedent': ('ALARM CLOCK BAKELIKE CHOCOLATE',),
#   'consequent': 'ALARM CLOCK BAKELIKE RED ',
#   'support': 230,
#   'confidence': 0.6865671641791045,
#   'lift': 16.79705112804226},
#  {'antecedent': ('ALARM CLOCK BAKELIKE RED ',),
#   'consequent': 'ALARM CLOCK BAKELIKE CHOCOLATE',
#   'support': 230,
#   'confidence': 0.2535832414553473,
#   'lift': 16.797051128042256},
#  {'antecedent': ('ALARM CLOCK BAKELIKE RED ',),
#   'consequent': 'ALARM CLOCK BAKELIKE ORANGE',
#   'support': 254,
#   'confidence': 0.28004410143329656,
#   'lift': 16.527070773417154},
#  {'antecedent': ('ALARM CLOCK BAKELIKE ORANGE',),
#   'consequent': 'ALARM CLOCK BAKELIKE RED ',
#   'support': 254,
#   'confidence': 0.675531914893617,
#   'lift': 16.527070773417154},
#  {'antecedent': ('ALARM CLOCK BAKELIKE ORANGE',),
#   'consequent': 'ALARM CLOCK BAKELIKE GREEN',
#   'support': 224,
#   'confidence': 0.5957446808510638,
#   'lift': 16.340635930883938},
#  {'antecedent': ('ALARM CLOCK BAKELIKE GREEN',),
#   'consequent': 'ALARM CLOCK BAKELIKE ORANGE',
#   'support': 224,
#   'confidence': 0.276885043263288,
#   'lift': 16.340635930883938},
#  {'antecedent': ('ALARM CLOCK BAKELIKE RED ',),
#   'consequent': 'ALARM CLOCK BAKELIKE GREEN',
#   'support': 268,
#   'confidence': 0.5909592061742006,
#   'lift': 16.20937550680533},
#  {'antecedent': ('ALARM CLOCK BAKELIKE GREEN',),
#   'consequent': 'ALARM CLOCK BAKELIKE RED ',
#   'support': 268,
#   'confidence': 0.6625463535228677,
#   'lift': 16.20937550680533},
#  {'antecedent': ('ALARM CLOCK BAKELIKE RED ',),
#   'consequent': 'ALARM CLOCK BAKELIKE IVORY',
#   'support': 318,
#   'confidence': 0.350606394707828,
#   'lift': 16.2082414553473},
#  {'antecedent': ('ALARM CLOCK BAKELIKE IVORY',),
#   'consequent': 'ALARM CLOCK BAKELIKE RED ',
#   'support': 318,
#   'confidence': 0.6625,
#   'lift': 16.2082414553473},
#  {'antecedent': ('HAND OVER THE CHOCOLATE   SIGN ',),
#   'consequent': 'COOK WITH WINE METAL SIGN ',
#   'support': 264,
#   'confidence': 0.4451939291736931,
#   'lift': 16.115584483465334},
#  {'antecedent': ('COOK WITH WINE METAL SIGN ',),
#   'consequent': 'HAND OVER THE CHOCOLATE   SIGN ',
#   'support': 264,
#   'confidence': 0.43066884176182707,
#   'lift': 16.115584483465334},
#  {'antecedent': ('HOT WATER BOTTLE TEA AND SYMPATHY',),
#   'consequent': 'CHOCOLATE HOT WATER BOTTLE',
#   'support': 261,
#   'confidence': 0.5038610038610039,
#   'lift': 15.814251309300815},
#  {'antecedent': ('CHOCOLATE HOT WATER BOTTLE',),
#   'consequent': 'HOT WATER BOTTLE TEA AND SYMPATHY',
#   'support': 261,
#   'confidence': 0.36916548797736914,
#   'lift': 15.814251309300813},
#  {'antecedent': ('WOODLAND CHARLOTTE BAG',),
#   'consequent': 'RED RETROSPOT CHARLOTTE BAG',
#   'support': 290,
#   'confidence': 0.5380333951762524,
#   'lift': 15.81319342908747},
#  {'antecedent': ('RED RETROSPOT CHARLOTTE BAG',),
#   'consequent': 'WOODLAND CHARLOTTE BAG',
#   'support': 290,
#   'confidence': 0.3841059602649007,
#   'lift': 15.81319342908747},
#  {'antecedent': ('ALARM CLOCK BAKELIKE IVORY',),
#   'consequent': 'ALARM CLOCK BAKELIKE GREEN',
#   'support': 276,
#   'confidence': 0.575,
#   'lift': 15.771631644004943},
#  {'antecedent': ('ALARM CLOCK BAKELIKE GREEN',),
#   'consequent': 'ALARM CLOCK BAKELIKE IVORY',
#   'support': 276,
#   'confidence': 0.3411619283065513,
#   'lift': 15.771631644004943},
#  {'antecedent': ('VINTAGE SNAP CARDS',),
#   'consequent': 'VINTAGE HEADS AND TAILS CARD GAME ',
#   'support': 250,
#   'confidence': 0.3448275862068966,
#   'lift': 15.679762577727532},
#  {'antecedent': ('VINTAGE HEADS AND TAILS CARD GAME ',),
#   'consequent': 'VINTAGE SNAP CARDS',
#   'support': 250,
#   'confidence': 0.5122950819672131,
#   'lift': 15.679762577727528},
#  {'antecedent': ('ALARM CLOCK BAKELIKE RED ',),
#   'consequent': 'ALARM CLOCK BAKELIKE PINK',
#   'support': 268,
#   'confidence': 0.44432194046306506,
#   'lift': 15.674886898053122},
#  {'antecedent': ('ALARM CLOCK BAKELIKE PINK',),
#   'consequent': 'ALARM CLOCK BAKELIKE RED ',
#   'support': 268,
#   'confidence': 0.6406995230524642,
#   'lift': 15.674886898053122},
#  {'antecedent': ('LOVE BUILDING BLOCK WORD',),
#   'consequent': 'HOME BUILDING BLOCK WORD',
#   'support': 275,
#   'confidence': 0.49371633752244165,
#   'lift': 15.650807899461402},
#  {'antecedent': ('HOME BUILDING BLOCK WORD',),
#   'consequent': 'LOVE BUILDING BLOCK WORD',
#   'support': 275,
#   'confidence': 0.39285714285714285,
#   'lift': 15.650807899461402},
#  {'antecedent': ('COOK WITH WINE METAL SIGN ',),
#   'consequent': 'GIN + TONIC DIET METAL SIGN',
#   'support': 279,
#   'confidence': 0.4551386623164764,
#   'lift': 15.256082955895183},
#  {'antecedent': ('GIN + TONIC DIET METAL SIGN',),
#   'consequent': 'COOK WITH WINE METAL SIGN ',
#   'support': 279,
#   'confidence': 0.4214501510574018,
#   'lift': 15.256082955895181},
#  {'antecedent': ('ALARM CLOCK BAKELIKE PINK',),
#   'consequent': 'ALARM CLOCK BAKELIKE GREEN',
#   'support': 268,
#   'confidence': 0.5468998410174881,
#   'lift': 15.000874502074241},
#  {'antecedent': ('ALARM CLOCK BAKELIKE GREEN',),
#   'consequent': 'ALARM CLOCK BAKELIKE PINK',
#   'support': 268,
#   'confidence': 0.4252163164400494,
#   'lift': 15.00087450207424},
#  {'antecedent': ('RED RETROSPOT CHARLOTTE BAG',),
#   'consequent': 'CHARLOTTE BAG SUKI DESIGN',
#   'support': 301,
#   'confidence': 0.39867549668874175,
#   'lift': 14.818440990826097},
#  {'antecedent': ('CHARLOTTE BAG SUKI DESIGN',),
#   'consequent': 'RED RETROSPOT CHARLOTTE BAG',
#   'support': 301,
#   'confidence': 0.5041876046901173,
#   'lift': 14.818440990826094},
#  {'antecedent': ('60 TEATIME FAIRY CAKE CASES',),
#   'consequent': '72 SWEETHEART FAIRY CAKE CASES',
#   'support': 223,
#   'confidence': 0.3358433734939759,
#   'lift': 14.75715734224025},
#  {'antecedent': ('72 SWEETHEART FAIRY CAKE CASES',),
#   'consequent': '60 TEATIME FAIRY CAKE CASES',
#   'support': 223,
#   'confidence': 0.4415841584158416,
#   'lift': 14.757157342240248},
#  {'antecedent': ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG SPACEBOY DESIGN '),
#   'consequent': 'LUNCH BAG WOODLAND',
#   'support': 260,
#   'confidence': 0.5531914893617021,
#   'lift': 14.630892906956102},
#  {'antecedent': ('LUNCH BAG VINTAGE DOILY ',),
#   'consequent': 'JUMBO BAG VINTAGE DOILY ',
#   'support': 227,
#   'confidence': 0.41651376146788993,
#   'lift': 14.577981651376149},
#  {'antecedent': ('JUMBO BAG VINTAGE DOILY ',),
#   'consequent': 'LUNCH BAG VINTAGE DOILY ',
#   'support': 227,
#   'confidence': 0.3580441640378549,
#   'lift': 14.577981651376147},
#  {'antecedent': ('JUMBO BAG VINTAGE LEAF',),
#   'consequent': 'JUMBO BAG PEARS',
#   'support': 241,
#   'confidence': 0.3097686375321337,
#   'lift': 14.440685014365645},
#  {'antecedent': ('JUMBO BAG PEARS',),
#   'consequent': 'JUMBO BAG VINTAGE LEAF',
#   'support': 241,
#   'confidence': 0.5063025210084033,
#   'lift': 14.440685014365645},
#  {'antecedent': ("PAPER CHAIN KIT 50'S CHRISTMAS ",),
#   'consequent': 'PAPER CHAIN KIT VINTAGE CHRISTMAS',
#   'support': 454,
#   'confidence': 0.4585858585858586,
#   'lift': 14.352637802567282},
#  {'antecedent': ('PAPER CHAIN KIT VINTAGE CHRISTMAS',),
#   'consequent': "PAPER CHAIN KIT 50'S CHRISTMAS ",
#   'support': 454,
#   'confidence': 0.6403385049365303,
#   'lift': 14.35263780256728},
#  {'antecedent': ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG CARS BLUE'),
#   'consequent': 'LUNCH BAG PINK POLKADOT',
#   'support': 261,
#   'confidence': 0.6141176470588235,
#   'lift': 14.329411764705883},
#  {'antecedent': ('WOODEN FRAME ANTIQUE WHITE ',),
#   'consequent': 'WOODEN PICTURE FRAME WHITE FINISH',
#   'support': 474,
#   'confidence': 0.5738498789346247,
#   'lift': 14.243544534182687},
#  {'antecedent': ('WOODEN PICTURE FRAME WHITE FINISH',),
#   'consequent': 'WOODEN FRAME ANTIQUE WHITE ',
#   'support': 474,
#   'confidence': 0.5302013422818792,
#   'lift': 14.243544534182686},
#  {'antecedent': ('LUNCH BAG CARS BLUE', 'LUNCH BAG RED RETROSPOT'),
#   'consequent': 'LUNCH BAG PINK POLKADOT',
#   'support': 282,
#   'confidence': 0.6064516129032258,
#   'lift': 14.150537634408602},
#  {'antecedent': ('GIN + TONIC DIET METAL SIGN',),
#   'consequent': 'HAND OVER THE CHOCOLATE   SIGN ',
#   'support': 250,
#   'confidence': 0.3776435045317221,
#   'lift': 14.131381729441674},
#  {'antecedent': ('HAND OVER THE CHOCOLATE   SIGN ',),
#   'consequent': 'GIN + TONIC DIET METAL SIGN',
#   'support': 250,
#   'confidence': 0.42158516020236086,
#   'lift': 14.131381729441673},
#  {'antecedent': ('PACK OF 60 DINOSAUR CAKE CASES',),
#   'consequent': '60 TEATIME FAIRY CAKE CASES',
#   'support': 223,
#   'confidence': 0.4191729323308271,
#   'lift': 14.008203868103996},
#  {'antecedent': ('60 TEATIME FAIRY CAKE CASES',),
#   'consequent': 'PACK OF 60 DINOSAUR CAKE CASES',
#   'support': 223,
#   'confidence': 0.3358433734939759,
#   'lift': 14.008203868103994},
#  {'antecedent': ('JUMBO BAG PINK POLKADOT', 'JUMBO BAG RED RETROSPOT'),
#   'consequent': 'JUMBO BAG STRAWBERRY',
#   'support': 233,
#   'confidence': 0.42057761732851984,
#   'lift': 13.9919300277659},
#  {'antecedent': ('PLEASE ONE PERSON METAL SIGN',),
#   'consequent': 'COOK WITH WINE METAL SIGN ',
#   'support': 270,
#   'confidence': 0.3835227272727273,
#   'lift': 13.883147337980128},
#  {'antecedent': ('COOK WITH WINE METAL SIGN ',),
#   'consequent': 'PLEASE ONE PERSON METAL SIGN',
#   'support': 270,
#   'confidence': 0.44045676998368677,
#   'lift': 13.883147337980128},
#  {'antecedent': ('PACK OF 60 PINK PAISLEY CAKE CASES',),
#   'consequent': '60 TEATIME FAIRY CAKE CASES',
#   'support': 280,
#   'confidence': 0.4148148148148148,
#   'lift': 13.86256135653726},
#  {'antecedent': ('60 TEATIME FAIRY CAKE CASES',),
#   'consequent': 'PACK OF 60 PINK PAISLEY CAKE CASES',
#   'support': 280,
#   'confidence': 0.42168674698795183,
#   'lift': 13.86256135653726},
#  {'antecedent': ('JUMBO BAG RED RETROSPOT', 'JUMBO BAG STRAWBERRY'),
#   'consequent': 'JUMBO BAG PINK POLKADOT',
#   'support': 233,
#   'confidence': 0.5521327014218009,
#   'lift': 13.859530140893396},
#  {'antecedent': ('LUNCH BAG VINTAGE LEAF DESIGN',),
#   'consequent': 'LUNCH BAG ALPHABET DESIGN',
#   'support': 247,
#   'confidence': 0.41098169717138106,
#   'lift': 13.817702818534766},
#  {'antecedent': ('LUNCH BAG ALPHABET DESIGN',),
#   'consequent': 'LUNCH BAG VINTAGE LEAF DESIGN',
#   'support': 247,
#   'confidence': 0.37424242424242427,
#   'lift': 13.817702818534766},
#  {'antecedent': ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG RED RETROSPOT'),
#   'consequent': 'LUNCH BAG PINK POLKADOT',
#   'support': 309,
#   'confidence': 0.5908221797323135,
#   'lift': 13.785850860420648},
#  {'antecedent': ('SCOTTIE DOG HOT WATER BOTTLE',),
#   'consequent': 'RETROSPOT HEART HOT WATER BOTTLE',
#   'support': 222,
#   'confidence': 0.334841628959276,
#   'lift': 13.734077165630932},
#  {'antecedent': ('RETROSPOT HEART HOT WATER BOTTLE',),
#   'consequent': 'SCOTTIE DOG HOT WATER BOTTLE',
#   'support': 222,
#   'confidence': 0.41035120147874304,
#   'lift': 13.734077165630932},
#  {'antecedent': ('LUNCH BAG PINK POLKADOT', 'LUNCH BAG SPACEBOY DESIGN '),
#   'consequent': 'LUNCH BAG CARS BLUE',
#   'support': 225,
#   'confidence': 0.6081081081081081,
#   'lift': 13.644002951384145},
#  {'antecedent': ('HOT WATER BOTTLE KEEP CALM',),
#   'consequent': 'HOT WATER BOTTLE TEA AND SYMPATHY',
#   'support': 229,
#   'confidence': 0.3154269972451791,
#   'lift': 13.512210557665105},
#  {'antecedent': ('HOT WATER BOTTLE TEA AND SYMPATHY',),
#   'consequent': 'HOT WATER BOTTLE KEEP CALM',
#   'support': 229,
#   'confidence': 0.4420849420849421,
#   'lift': 13.512210557665103},
#  {'antecedent': ('LUNCH BAG CARS BLUE', 'LUNCH BAG RED RETROSPOT'),
#   'consequent': 'LUNCH BAG WOODLAND',
#   'support': 235,
#   'confidence': 0.5053763440860215,
#   'lift': 13.366270649903237},
#  {'antecedent': ('LUNCH BAG CARS BLUE', 'LUNCH BAG SPACEBOY DESIGN '),
#   'consequent': 'LUNCH BAG PINK POLKADOT',
#   'support': 225,
#   'confidence': 0.569620253164557,
#   'lift': 13.29113924050633},
#  {'antecedent': ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG WOODLAND'),
#   'consequent': 'LUNCH BAG SPACEBOY DESIGN ',
#   'support': 260,
#   'confidence': 0.592255125284738,
#   'lift': 13.129012217850486},
#  {'antecedent': ('LUNCH BAG SPACEBOY DESIGN ',),
#   'consequent': 'LUNCH BAG DOLLY GIRL DESIGN',
#   'support': 356,
#   'confidence': 0.35564435564435565,
#   'lift': 13.044211986360747},
#  {'antecedent': ('LUNCH BAG DOLLY GIRL DESIGN',),
#   'consequent': 'LUNCH BAG SPACEBOY DESIGN ',
#   'support': 356,
#   'confidence': 0.5884297520661157,
#   'lift': 13.044211986360747},
#  {'antecedent': ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG SUKI DESIGN '),
#   'consequent': 'LUNCH BAG WOODLAND',
#   'support': 225,
#   'confidence': 0.4923413566739606,
#   'lift': 13.021519314177814},
#  {'antecedent': ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG SUKI DESIGN '),
#   'consequent': 'LUNCH BAG PINK POLKADOT',
#   'support': 255,
#   'confidence': 0.5579868708971554,
#   'lift': 13.019693654266959},
#  {'antecedent': ('LUNCH BAG VINTAGE LEAF DESIGN',),
#   'consequent': 'LUNCH BAG APPLE DESIGN',
#   'support': 306,
#   'confidence': 0.5091514143094842,
#   'lift': 12.867961142969765},
#  {'antecedent': ('LUNCH BAG APPLE DESIGN',),
#   'consequent': 'LUNCH BAG VINTAGE LEAF DESIGN',
#   'support': 306,
#   'confidence': 0.34851936218678814,
#   'lift': 12.867961142969765},
#  {'antecedent': ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG WOODLAND'),
#   'consequent': 'LUNCH BAG PINK POLKADOT',
#   'support': 240,
#   'confidence': 0.5466970387243736,
#   'lift': 12.75626423690205},
#  {'antecedent': ('LUNCH BAG PINK POLKADOT', 'LUNCH BAG SUKI DESIGN '),
#   'consequent': 'LUNCH BAG  BLACK SKULL.',
#   'support': 223,
#   'confidence': 0.6160220994475138,
#   'lift': 12.739543696868903},
#  {'antecedent': ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG CARS BLUE'),
#   'consequent': 'LUNCH BAG SUKI DESIGN ',
#   'support': 223,
#   'confidence': 0.5247058823529411,
#   'lift': 12.710942717698432},
#  {'antecedent': ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG SUKI DESIGN '),
#   'consequent': 'LUNCH BAG PINK POLKADOT',
#   'support': 223,
#   'confidence': 0.5425790754257908,
#   'lift': 12.660178426601783},
#  {'antecedent': ('JUMBO BAG RED RETROSPOT', 'JUMBO STORAGE BAG SUKI'),
#   'consequent': 'JUMBO BAG PINK POLKADOT',
#   'support': 223,
#   'confidence': 0.5033860045146726,
#   'lift': 12.635899819208808},
#  {'antecedent': ('LUNCH BAG PINK POLKADOT', 'LUNCH BAG SPACEBOY DESIGN '),
#   'consequent': 'LUNCH BAG  BLACK SKULL.',
#   'support': 226,
#   'confidence': 0.6108108108108108,
#   'lift': 12.631772499433264},
#  {'antecedent': ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG SPACEBOY DESIGN '),
#   'consequent': 'LUNCH BAG PINK POLKADOT',
#   'support': 226,
#   'confidence': 0.5393794749403341,
#   'lift': 12.58552108194113},
#  {'antecedent': ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG SPACEBOY DESIGN '),
#   'consequent': 'LUNCH BAG PINK POLKADOT',
#   'support': 253,
#   'confidence': 0.5382978723404256,
#   'lift': 12.560283687943263},
#  {'antecedent': ('HAND OVER THE CHOCOLATE   SIGN ',),
#   'consequent': 'PLEASE ONE PERSON METAL SIGN',
#   'support': 236,
#   'confidence': 0.3979763912310287,
#   'lift': 12.544170627012113},
#  {'antecedent': ('PLEASE ONE PERSON METAL SIGN',),
#   'consequent': 'HAND OVER THE CHOCOLATE   SIGN ',
#   'support': 236,
#   'confidence': 0.3352272727272727,
#   'lift': 12.54417062701211},
#  {'antecedent': ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG PINK POLKADOT'),
#   'consequent': 'LUNCH BAG CARS BLUE',
#   'support': 261,
#   'confidence': 0.5588865096359743,
#   'lift': 12.539627551893094},
#  {'antecedent': ('LUNCH BAG CARS BLUE', 'LUNCH BAG PINK POLKADOT'),
#   'consequent': 'LUNCH BAG  BLACK SKULL.',
#   'support': 261,
#   'confidence': 0.6041666666666666,
#   'lift': 12.49436936936937},
#  {'antecedent': ('LUNCH BAG CARS BLUE', 'LUNCH BAG RED RETROSPOT'),
#   'consequent': 'LUNCH BAG SUKI DESIGN ',
#   'support': 239,
#   'confidence': 0.513978494623656,
#   'lift': 12.451072921068695},
#  {'antecedent': ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG WOODLAND'),
#   'consequent': 'LUNCH BAG SUKI DESIGN ',
#   'support': 225,
#   'confidence': 0.5125284738041003,
#   'lift': 12.415946325014175},
#  {'antecedent': ('LUNCH BAG PINK POLKADOT', 'LUNCH BAG WOODLAND'),
#   'consequent': 'LUNCH BAG RED RETROSPOT',
#   'support': 240,
#   'confidence': 0.7430340557275542,
#   'lift': 12.40626463250145},
#  {'antecedent': ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG SUKI DESIGN '),
#   'consequent': 'LUNCH BAG CARS BLUE',
#   'support': 223,
#   'confidence': 0.5425790754257908,
#   'lift': 12.173740832859755},
#  {'antecedent': ('LUNCH BAG SUKI DESIGN ', 'LUNCH BAG WOODLAND'),
#   'consequent': 'LUNCH BAG RED RETROSPOT',
#   'support': 225,
#   'confidence': 0.7258064516129032,
#   'lift': 12.118619383965632},
#  {'antecedent': ('LUNCH BAG PINK POLKADOT', 'LUNCH BAG RED RETROSPOT'),
#   'consequent': 'LUNCH BAG  BLACK SKULL.',
#   'support': 309,
#   'confidence': 0.5830188679245283,
#   'lift': 12.057025796127943},
#  {'antecedent': ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG WOODLAND'),
#   'consequent': 'LUNCH BAG CARS BLUE',
#   'support': 235,
#   'confidence': 0.5353075170842825,
#   'lift': 12.010590297371314},
#  {'antecedent': ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG SPACEBOY DESIGN '),
#   'consequent': 'LUNCH BAG CARS BLUE',
#   'support': 224,
#   'confidence': 0.5346062052505967,
#   'lift': 11.994855100617533},
#  {'antecedent': ('LUNCH BAG PINK POLKADOT', 'LUNCH BAG RED RETROSPOT'),
#   'consequent': 'LUNCH BAG WOODLAND',
#   'support': 240,
#   'confidence': 0.4528301886792453,
#   'lift': 11.976521915128071},
#  {'antecedent': ('LUNCH BAG ALPHABET DESIGN',),
#   'consequent': 'LUNCH BAG APPLE DESIGN',
#   'support': 312,
#   'confidence': 0.4727272727272727,
#   'lift': 11.947401118243944},
#  {'antecedent': ('LUNCH BAG APPLE DESIGN',),
#   'consequent': 'LUNCH BAG ALPHABET DESIGN',
#   'support': 312,
#   'confidence': 0.3553530751708428,
#   'lift': 11.947401118243942},
#  {'antecedent': ('LUNCH BAG PINK POLKADOT', 'LUNCH BAG RED RETROSPOT'),
#   'consequent': 'LUNCH BAG CARS BLUE',
#   'support': 282,
#   'confidence': 0.5320754716981132,
#   'lift': 11.938073525764542},
#  {'antecedent': ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG SPACEBOY DESIGN '),
#   'consequent': 'LUNCH BAG SUKI DESIGN ',
#   'support': 231,
#   'confidence': 0.49148936170212765,
#   'lift': 11.906276131190188},
#  {'antecedent': ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG RED RETROSPOT'),
#   'consequent': 'LUNCH BAG SUKI DESIGN ',
#   'support': 254,
#   'confidence': 0.48565965583174,
#   'lift': 11.765052142910818},
#  {'antecedent': ('LUNCH BAG PINK POLKADOT', 'LUNCH BAG SUKI DESIGN '),
#   'consequent': 'LUNCH BAG RED RETROSPOT',
#   'support': 255,
#   'confidence': 0.7044198895027625,
#   'lift': 11.761532993277878},
#  {'antecedent': ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG SUKI DESIGN '),
#   'consequent': 'LUNCH BAG CARS BLUE',
#   'support': 239,
#   'confidence': 0.5229759299781181,
#   'lift': 11.733908883937758},
#  {'antecedent': ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG RED RETROSPOT'),
#   'consequent': 'LUNCH BAG WOODLAND',
#   'support': 232,
#   'confidence': 0.4435946462715105,
#   'lift': 11.732258880530177},
#  {'antecedent': ('JUMBO SHOPPER VINTAGE RED PAISLEY',),
#   'consequent': 'JUMBO BAG PINK VINTAGE PAISLEY',
#   'support': 260,
#   'confidence': 0.32459425717852686,
#   'lift': 11.730857600637641},
#  {'antecedent': ('JUMBO BAG PINK VINTAGE PAISLEY',),
#   'consequent': 'JUMBO SHOPPER VINTAGE RED PAISLEY',
#   'support': 260,
#   'confidence': 0.4234527687296417,
#   'lift': 11.730857600637641},
#  {'antecedent': ('LUNCH BAG CARS BLUE', 'LUNCH BAG SPACEBOY DESIGN '),
#   'consequent': 'LUNCH BAG  BLACK SKULL.',
#   'support': 224,
#   'confidence': 0.5670886075949367,
#   'lift': 11.727582667783455},
#  {'antecedent': ('LUNCH BAG CARS BLUE', 'LUNCH BAG SUKI DESIGN '),
#   'consequent': 'LUNCH BAG  BLACK SKULL.',
#   'support': 223,
#   'confidence': 0.565989847715736,
#   'lift': 11.70485994483894},
#  {'antecedent': ('LUNCH BAG CARS BLUE', 'LUNCH BAG RED RETROSPOT'),
#   'consequent': 'LUNCH BAG  BLACK SKULL.',
#   'support': 263,
#   'confidence': 0.5655913978494623,
#   'lift': 11.696619867921314},
#  {'antecedent': ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG CARS BLUE'),
#   'consequent': 'LUNCH BAG SPACEBOY DESIGN ',
#   'support': 224,
#   'confidence': 0.5270588235294118,
#   'lift': 11.683751542575072},
#  {'antecedent': ('LUNCH BAG PINK POLKADOT', 'LUNCH BAG RED RETROSPOT'),
#   'consequent': 'LUNCH BAG SUKI DESIGN ',
#   'support': 255,
#   'confidence': 0.4811320754716981,
#   'lift': 11.655372002966136},
#  {'antecedent': ('PAINTED METAL PEARS ASSORTED',),
#   'consequent': 'ASSORTED COLOUR BIRD ORNAMENT',
#   'support': 256,
#   'confidence': 0.7231638418079096,
#   'lift': 11.586285667666075},
#  {'antecedent': ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG PINK POLKADOT'),
#   'consequent': 'LUNCH BAG SUKI DESIGN ',
#   'support': 223,
#   'confidence': 0.47751605995717344,
#   'lift': 11.567774421888295},
#  {'antecedent': ('LUNCH BAG CARS BLUE', 'LUNCH BAG PINK POLKADOT'),
#   'consequent': 'LUNCH BAG SPACEBOY DESIGN ',
#   'support': 225,
#   'confidence': 0.5208333333333334,
#   'lift': 11.54574592074592},
#  {'antecedent': ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG SUKI DESIGN '),
#   'consequent': 'LUNCH BAG  BLACK SKULL.',
#   'support': 254,
#   'confidence': 0.5557986870897156,
#   'lift': 11.494103323877717},
#  {'antecedent': ('GIN + TONIC DIET METAL SIGN',),
#   'consequent': 'PLEASE ONE PERSON METAL SIGN',
#   'support': 241,
#   'confidence': 0.3640483383685801,
#   'lift': 11.474762256248285},
#  {'antecedent': ('PLEASE ONE PERSON METAL SIGN',),
#   'consequent': 'GIN + TONIC DIET METAL SIGN',
#   'support': 241,
#   'confidence': 0.34232954545454547,
#   'lift': 11.474762256248283},
#  {'antecedent': ('LUNCH BAG PINK POLKADOT', 'LUNCH BAG SPACEBOY DESIGN '),
#   'consequent': 'LUNCH BAG RED RETROSPOT',
#   'support': 253,
#   'confidence': 0.6837837837837838,
#   'lift': 11.416976796209303},
#  {'antecedent': ('SCOTTIE DOG HOT WATER BOTTLE',),
#   'consequent': 'CHOCOLATE HOT WATER BOTTLE',
#   'support': 241,
#   'confidence': 0.363499245852187,
#   'lift': 11.40883771635082},
#  {'antecedent': ('CHOCOLATE HOT WATER BOTTLE',),
#   'consequent': 'SCOTTIE DOG HOT WATER BOTTLE',
#   'support': 241,
#   'confidence': 0.3408769448373409,
#   'lift': 11.40883771635082},
#  {'antecedent': ('HEART OF WICKER LARGE',),
#   'consequent': 'HEART OF WICKER SMALL',
#   'support': 408,
#   'confidence': 0.49938800489596086,
#   'lift': 11.40063768378742},
#  {'antecedent': ('HEART OF WICKER SMALL',),
#   'consequent': 'HEART OF WICKER LARGE',
#   'support': 408,
#   'confidence': 0.41975308641975306,
#   'lift': 11.400637683787417},
#  {'antecedent': ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG SPACEBOY DESIGN '),
#   'consequent': 'LUNCH BAG CARS BLUE',
#   'support': 237,
#   'confidence': 0.5042553191489362,
#   'lift': 11.313878192027193},
#  {'antecedent': ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG SPACEBOY DESIGN '),
#   'consequent': 'LUNCH BAG  BLACK SKULL.',
#   'support': 257,
#   'confidence': 0.5468085106382978,
#   'lift': 11.30818345858698},
#  {'antecedent': ('LUNCH BAG CARS BLUE', 'LUNCH BAG RED RETROSPOT'),
#   'consequent': 'LUNCH BAG SPACEBOY DESIGN ',
#   'support': 237,
#   'confidence': 0.5096774193548387,
#   'lift': 11.298443491991877},
#  {'antecedent': ('JUMBO BAG PINK POLKADOT', 'JUMBO BAG RED RETROSPOT'),
#   'consequent': 'JUMBO STORAGE BAG SUKI',
#   'support': 223,
#   'confidence': 0.40252707581227437,
#   'lift': 11.292131241813362},
#  {'antecedent': ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG RED RETROSPOT'),
#   'consequent': 'LUNCH BAG CARS BLUE',
#   'support': 263,
#   'confidence': 0.502868068833652,
#   'lift': 11.282752727420363},
#  {'antecedent': ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG SUKI DESIGN '),
#   'consequent': 'LUNCH BAG SPACEBOY DESIGN ',
#   'support': 231,
#   'confidence': 0.5054704595185996,
#   'lift': 11.205184312405319},
#  {'antecedent': ('JUMBO BAG STRAWBERRY',),
#   'consequent': 'JUMBO BAG PINK POLKADOT',
#   'support': 233,
#   'confidence': 0.4407796101949025,
#   'lift': 11.064366007041727},
#  {'antecedent': ('JUMBO BAG PINK POLKADOT',),
#   'consequent': 'JUMBO BAG STRAWBERRY',
#   'support': 233,
#   'confidence': 0.332579185520362,
#   'lift': 11.064366007041727},
#  {'antecedent': ('LUNCH BAG WOODLAND',),
#   'consequent': 'LUNCH BAG DOLLY GIRL DESIGN',
#   'support': 253,
#   'confidence': 0.30154946364719903,
#   'lift': 11.060136526167515},
#  {'antecedent': ('LUNCH BAG DOLLY GIRL DESIGN',),
#   'consequent': 'LUNCH BAG WOODLAND',
#   'support': 253,
#   'confidence': 0.41818181818181815,
#   'lift': 11.060136526167513},
#  {'antecedent': ('JUMBO BAG APPLES',),
#   'consequent': 'JUMBO BAG ALPHABET',
#   'support': 282,
#   'confidence': 0.38159675236806495,
#   'lift': 11.054349784657129},
#  {'antecedent': ('JUMBO BAG ALPHABET',),
#   'consequent': 'JUMBO BAG APPLES',
#   'support': 282,
#   'confidence': 0.3681462140992167,
#   'lift': 11.054349784657129},
#  {'antecedent': ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG PINK POLKADOT'),
#   'consequent': 'LUNCH BAG RED RETROSPOT',
#   'support': 309,
#   'confidence': 0.6616702355460385,
#   'lift': 11.047752089365385},
#  {'antecedent': ('JUMBO BAG VINTAGE LEAF',),
#   'consequent': 'JUMBO BAG APPLES',
#   'support': 286,
#   'confidence': 0.3676092544987147,
#   'lift': 11.038226464582515},
#  {'antecedent': ('JUMBO BAG APPLES',),
#   'consequent': 'JUMBO BAG VINTAGE LEAF',
#   'support': 286,
#   'confidence': 0.3870094722598105,
#   'lift': 11.038226464582515},
#  {'antecedent': ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG WOODLAND'),
#   'consequent': 'LUNCH BAG RED RETROSPOT',
#   'support': 232,
#   'confidence': 0.6590909090909091,
#   'lift': 11.004685683015254},
#  {'antecedent': ('LUNCH BAG RED RETROSPOT', 'LUNCH BAG WOODLAND'),
#   'consequent': 'LUNCH BAG  BLACK SKULL.',
#   'support': 232,
#   'confidence': 0.5284738041002278,
#   'lift': 10.929015575940406},
#  {'antecedent': ('LUNCH BAG CARS BLUE', 'LUNCH BAG PINK POLKADOT'),
#   'consequent': 'LUNCH BAG RED RETROSPOT',
#   'support': 282,
#   'confidence': 0.6527777777777778,
#   'lift': 10.899276816319706},
#  {'antecedent': ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG RED RETROSPOT'),
#   'consequent': 'LUNCH BAG SPACEBOY DESIGN ',
#   'support': 257,
#   'confidence': 0.491395793499044,
#   'lift': 10.893179478265521},
#  {'antecedent': ('LUNCH BAG WOODLAND',),
#   'consequent': 'LUNCH BAG SPACEBOY DESIGN ',
#   'support': 260,
#   'confidence': 0.48748510131108463,
#   'lift': 10.806487910182785},
#  {'antecedent': ('LUNCH BAG SPACEBOY DESIGN ',),
#   'consequent': 'LUNCH BAG WOODLAND',
#   'support': 260,
#   'confidence': 0.4085914085914086,
#   'lift': 10.806487910182783},
#  {'antecedent': ('PACK OF 72 RETROSPOT CAKE CASES',),
#   'consequent': 'PACK OF 60 DINOSAUR CAKE CASES',
#   'support': 268,
#   'confidence': 0.2574447646493756,
#   'lift': 10.738156630770009},
#  {'antecedent': ('PACK OF 60 DINOSAUR CAKE CASES',),
#   'consequent': 'PACK OF 72 RETROSPOT CAKE CASES',
#   'support': 268,
#   'confidence': 0.5037593984962406,
#   'lift': 10.738156630770009},
#  {'antecedent': ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG PINK POLKADOT'),
#   'consequent': 'LUNCH BAG SPACEBOY DESIGN ',
#   'support': 226,
#   'confidence': 0.48394004282655245,
#   'lift': 10.727901648672526},
#  {'antecedent': ('PACK OF 72 RETROSPOT CAKE CASES',),
#   'consequent': '60 TEATIME FAIRY CAKE CASES',
#   'support': 334,
#   'confidence': 0.3208453410182517,
#   'lift': 10.722226080112959},
#  {'antecedent': ('60 TEATIME FAIRY CAKE CASES',),
#   'consequent': 'PACK OF 72 RETROSPOT CAKE CASES',
#   'support': 334,
#   'confidence': 0.5030120481927711,
#   'lift': 10.722226080112959},
#  {'antecedent': ('JUMBO BAG PINK POLKADOT', 'JUMBO BAG STRAWBERRY'),
#   'consequent': 'JUMBO BAG RED RETROSPOT',
#   'support': 233,
#   'confidence': 0.7925170068027211,
#   'lift': 10.703562009100658},
#  {'antecedent': ('HOT WATER BOTTLE KEEP CALM',),
#   'consequent': 'CHOCOLATE HOT WATER BOTTLE',
#   'support': 247,
#   'confidence': 0.3402203856749311,
#   'lift': 10.67820418405477},
#  {'antecedent': ('CHOCOLATE HOT WATER BOTTLE',),
#   'consequent': 'HOT WATER BOTTLE KEEP CALM',
#   'support': 247,
#   'confidence': 0.3493635077793494,
#   'lift': 10.678204184054769},
#  {'antecedent': ('PACK OF 72 RETROSPOT CAKE CASES',),
#   'consequent': 'PACK OF 60 PINK PAISLEY CAKE CASES',
#   'support': 338,
#   'confidence': 0.32468780019212296,
#   'lift': 10.673810794464012},
#  {'antecedent': ('PACK OF 60 PINK PAISLEY CAKE CASES',),
#   'consequent': 'PACK OF 72 RETROSPOT CAKE CASES',
#   'support': 338,
#   'confidence': 0.5007407407407407,
#   'lift': 10.67381079446401},
#  {'antecedent': ('LUNCH BAG CARS BLUE', 'LUNCH BAG WOODLAND'),
#   'consequent': 'LUNCH BAG RED RETROSPOT',
#   'support': 235,
#   'confidence': 0.6368563685636857,
#   'lift': 10.63344079640947},
#  {'antecedent': ('LUNCH BAG SPACEBOY DESIGN ', 'LUNCH BAG WOODLAND'),
#   'consequent': 'LUNCH BAG RED RETROSPOT',
#   'support': 260,
#   'confidence': 0.6356968215158925,
#   'lift': 10.614080112443682},
#  {'antecedent': ('JUMBO BAG PINK POLKADOT', 'JUMBO STORAGE BAG SUKI'),
#   'consequent': 'JUMBO BAG RED RETROSPOT',
#   'support': 223,
#   'confidence': 0.7852112676056338,
#   'lift': 10.604892287382235},
#  {'antecedent': ('LUNCH BAG PINK POLKADOT', 'LUNCH BAG RED RETROSPOT'),
#   'consequent': 'LUNCH BAG SPACEBOY DESIGN ',
#   'support': 253,
#   'confidence': 0.47735849056603774,
#   'lift': 10.582002902757619},
#  {'antecedent': ('PACK OF 72 SKULL CAKE CASES',),
#   'consequent': 'PACK OF 72 RETROSPOT CAKE CASES',
#   'support': 248,
#   'confidence': 0.496,
#   'lift': 10.572756964457252},
#  {'antecedent': ('PACK OF 72 RETROSPOT CAKE CASES',),
#   'consequent': 'PACK OF 72 SKULL CAKE CASES',
#   'support': 248,
#   'confidence': 0.23823246878001922,
#   'lift': 10.572756964457252},
#  {'antecedent': ('JUMBO BAG PINK POLKADOT',),
#   'consequent': 'JUMBO BAG PINK VINTAGE PAISLEY',
#   'support': 257,
#   'confidence': 0.2907239819004525,
#   'lift': 10.506783645555442},
#  {'antecedent': ('JUMBO BAG PINK VINTAGE PAISLEY',),
#   'consequent': 'JUMBO BAG PINK POLKADOT',
#   'support': 257,
#   'confidence': 0.4185667752442997,
#   'lift': 10.50678364555544},
#  {'antecedent': ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG CARS BLUE'),
#   'consequent': 'LUNCH BAG RED RETROSPOT',
#   'support': 263,
#   'confidence': 0.6188235294117647,
#   'lift': 10.332350728101623},
#  {'antecedent': ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG SUKI DESIGN '),
#   'consequent': 'LUNCH BAG RED RETROSPOT',
#   'support': 254,
#   'confidence': 0.6180048661800487,
#   'lift': 10.318681700929481},
#  {'antecedent': ('LUNCH BAG ALPHABET DESIGN',),
#   'consequent': 'JUMBO BAG ALPHABET',
#   'support': 234,
#   'confidence': 0.35454545454545455,
#   'lift': 10.270709708046523},
#  {'antecedent': ('JUMBO BAG ALPHABET',),
#   'consequent': 'LUNCH BAG ALPHABET DESIGN',
#   'support': 234,
#   'confidence': 0.30548302872062666,
#   'lift': 10.270709708046523},
#  {'antecedent': ('JUMBO BAG VINTAGE LEAF',),
#   'consequent': 'JUMBO BAG VINTAGE DOILY ',
#   'support': 228,
#   'confidence': 0.2930591259640103,
#   'lift': 10.25706940874036},
#  {'antecedent': ('JUMBO BAG VINTAGE DOILY ',),
#   'consequent': 'JUMBO BAG VINTAGE LEAF',
#   'support': 228,
#   'confidence': 0.35962145110410093,
#   'lift': 10.25706940874036},
#  {'antecedent': ('LUNCH BAG SUKI DESIGN ',),
#   'consequent': 'LUNCH BAG DOLLY GIRL DESIGN',
# ...
#   'confidence': 0.322279792746114,
#   'lift': 8.126577955723034},
#  {'antecedent': ('JAM MAKING SET PRINTED',),
#   'consequent': 'JAM MAKING SET WITH JARS',
#   'support': 311,
#   'confidence': 0.3534090909090909,
#   'lift': 8.126577955723032},
#  {'antecedent': ('LUNCH BAG CARS BLUE',),
#   'consequent': 'LUNCH BAG ALPHABET DESIGN',
#   'support': 238,
#   'confidence': 0.24064711830131447,
#   'lift': 8.09084781076692},
#  {'antecedent': ('LUNCH BAG ALPHABET DESIGN',),
#   'consequent': 'LUNCH BAG CARS BLUE',
#   'support': 238,
#   'confidence': 0.3606060606060606,
#   'lift': 8.09084781076692},
#  {'antecedent': ('CANDLEHOLDER PINK HANGING HEART',),
#   'consequent': 'WHITE HANGING HEART T-LIGHT HOLDER',
#   'support': 255,
#   'confidence': 0.7327586206896551,
#   'lift': 8.077453449132364},
#  {'antecedent': ('LUNCH BAG PINK POLKADOT',),
#   'consequent': 'LUNCH BAG ALPHABET DESIGN',
#   'support': 228,
#   'confidence': 0.23974763406940064,
#   'lift': 8.06060606060606},
#  {'antecedent': ('LUNCH BAG ALPHABET DESIGN',),
#   'consequent': 'LUNCH BAG PINK POLKADOT',
#   'support': 228,
#   'confidence': 0.34545454545454546,
#   'lift': 8.06060606060606},
#  {'antecedent': ('JUMBO BAG SCANDINAVIAN BLUE PAISLEY',),
#   'consequent': 'JUMBO BAG RED RETROSPOT',
#   'support': 272,
#   'confidence': 0.5925925925925926,
#   'lift': 8.003426433128197},
#  {'antecedent': ('LUNCH BAG SPACEBOY DESIGN ',),
#   'consequent': 'LUNCH BAG APPLE DESIGN',
#   'support': 312,
#   'confidence': 0.3116883116883117,
#   'lift': 7.877407330710292},
#  {'antecedent': ('LUNCH BAG APPLE DESIGN',),
#   'consequent': 'LUNCH BAG SPACEBOY DESIGN ',
#   'support': 312,
#   'confidence': 0.3553530751708428,
#   'lift': 7.877407330710291},
#  {'antecedent': ('LUNCH BAG RED RETROSPOT',),
#   'consequent': 'LUNCH BAG CARS BLUE',
#   'support': 235,
#   'confidence': 0.34988713318284426,
#   'lift': 7.850349327934595},
#  {'antecedent': ('LUNCH BAG CARS BLUE',),
#   'consequent': 'LUNCH BAG RED RETROSPOT',
#   'support': 235,
#   'confidence': 0.47017189079878663,
#   'lift': 7.850349327934595},
#  {'antecedent': ('LUNCH BAG SPACEBOY DESIGN ',),
#   'consequent': 'LUNCH BAG RED RETROSPOT',
#   'support': 231,
#   'confidence': 0.4695304695304695,
#   'lift': 7.839639668082106},
#  {'antecedent': ('LUNCH BAG RED RETROSPOT',),
#   'consequent': 'LUNCH BAG SPACEBOY DESIGN ',
#   'support': 231,
#   'confidence': 0.35364936042136946,
#   'lift': 7.839639668082106},
#  {'antecedent': ('JUMBO BAG PINK POLKADOT',),
#   'consequent': 'JUMBO SHOPPER VINTAGE RED PAISLEY',
#   'support': 248,
#   'confidence': 0.28054298642533937,
#   'lift': 7.771846278125195},
#  {'antecedent': ('JUMBO SHOPPER VINTAGE RED PAISLEY',),
#   'consequent': 'JUMBO BAG PINK POLKADOT',
#   'support': 248,
#   'confidence': 0.3096129837702871,
#   'lift': 7.771846278125194},
#  {'antecedent': ('LUNCH BAG PINK POLKADOT',),
#   'consequent': 'LUNCH BAG APPLE DESIGN',
#   'support': 292,
#   'confidence': 0.3070452155625657,
#   'lift': 7.760060744115414},
#  {'antecedent': ('LUNCH BAG APPLE DESIGN',),
#   'consequent': 'LUNCH BAG PINK POLKADOT',
#   'support': 292,
#   'confidence': 0.3325740318906606,
#   'lift': 7.760060744115414},
#  {'antecedent': ('JUMBO BAG APPLES',),
#   'consequent': 'JUMBO BAG PINK POLKADOT',
#   'support': 227,
#   'confidence': 0.3071718538565629,
#   'lift': 7.710569498956031},
#  {'antecedent': ('JUMBO BAG PINK POLKADOT',),
#   'consequent': 'JUMBO BAG APPLES',
#   'support': 227,
#   'confidence': 0.25678733031674206,
#   'lift': 7.71056949895603},
#  {'antecedent': ('LUNCH BAG ALPHABET DESIGN',),
#   'consequent': 'LUNCH BAG  BLACK SKULL.',
#   'support': 246,
#   'confidence': 0.37272727272727274,
#   'lift': 7.7081250529526395},
#  {'antecedent': ('LUNCH BAG  BLACK SKULL.',),
#   'consequent': 'LUNCH BAG ALPHABET DESIGN',
#   'support': 246,
#   'confidence': 0.22926374650512582,
#   'lift': 7.7081250529526395},
#  {'antecedent': ('JUMBO BAG RED RETROSPOT',),
#   'consequent': 'JUMBO STORAGE BAG SUKI',
#   'support': 223,
#   'confidence': 0.2696287279367012,
#   'lift': 7.563920951852591},
#  {'antecedent': ('JUMBO STORAGE BAG SUKI',),
#   'consequent': 'JUMBO BAG RED RETROSPOT',
#   'support': 223,
#   'confidence': 0.5600505689001264,
#   'lift': 7.563920951852589},
#  {'antecedent': ('JUMBO BAG SPACEBOY DESIGN',),
#   'consequent': 'JUMBO BAG RED RETROSPOT',
#   'support': 269,
#   'confidence': 0.558091286307054,
#   'lift': 7.537459308066663},
#  {'antecedent': ('LUNCH BAG APPLE DESIGN',),
#   'consequent': 'LUNCH BAG  BLACK SKULL.',
#   'support': 320,
#   'confidence': 0.36446469248291574,
#   'lift': 7.537252121338211},
#  {'antecedent': ('LUNCH BAG  BLACK SKULL.',),
#   'consequent': 'LUNCH BAG APPLE DESIGN',
#   'support': 320,
#   'confidence': 0.2982292637465051,
#   'lift': 7.53725212133821},
#  {'antecedent': ('JUMBO BAG RED RETROSPOT',),
#   'consequent': 'JUMBO  BAG BAROQUE BLACK WHITE',
#   'support': 370,
#   'confidence': 0.22519780888618382,
#   'lift': 7.537163467849802},
#  {'antecedent': ('JUMBO  BAG BAROQUE BLACK WHITE',),
#   'consequent': 'JUMBO BAG RED RETROSPOT',
#   'support': 370,
#   'confidence': 0.5580693815987934,
#   'lift': 7.537163467849802},
#  {'antecedent': ('LUNCH BAG VINTAGE DOILY ',),
#   'consequent': 'LUNCH BAG RED RETROSPOT',
#   'support': 245,
#   'confidence': 0.44954128440366975,
#   'lift': 7.505884951781364},
#  {'antecedent': ('LUNCH BAG RED RETROSPOT',),
#   'consequent': 'LUNCH BAG APPLE DESIGN',
#   'support': 392,
#   'confidence': 0.2949586155003762,
#   'lift': 7.4545918883295545},
#  {'antecedent': ('LUNCH BAG APPLE DESIGN',),
#   'consequent': 'LUNCH BAG RED RETROSPOT',
#   'support': 392,
#   'confidence': 0.44646924829157175,
#   'lift': 7.4545918883295545},
#  {'antecedent': ('LUNCH BAG CARS BLUE',),
#   'consequent': 'LUNCH BAG APPLE DESIGN',
#   'support': 291,
#   'confidence': 0.2942366026289181,
#   'lift': 7.436344205393728},
#  {'antecedent': ('LUNCH BAG APPLE DESIGN',),
#   'consequent': 'LUNCH BAG CARS BLUE',
#   'support': 291,
#   'confidence': 0.3314350797266515,
#   'lift': 7.436344205393728},
#  {'antecedent': ('JUMBO BAG RED RETROSPOT',),
#   'consequent': 'JUMBO BAG PINK VINTAGE PAISLEY',
#   'support': 335,
#   'confidence': 0.20389531345100426,
#   'lift': 7.3687899112016035},
#  {'antecedent': ('JUMBO BAG PINK VINTAGE PAISLEY',),
#   'consequent': 'JUMBO BAG RED RETROSPOT',
#   'support': 335,
#   'confidence': 0.5456026058631922,
#   'lift': 7.3687899112016035},
#  {'antecedent': ('LUNCH BAG VINTAGE LEAF DESIGN',),
#   'consequent': 'LUNCH BAG RED RETROSPOT',
#   'support': 265,
#   'confidence': 0.44093178036605657,
#   'lift': 7.3621340905363395},
#  {'antecedent': ('WHITE HANGING HEART T-LIGHT HOLDER',),
#   'consequent': 'RED HANGING HEART T-LIGHT HOLDER',
#   'support': 460,
#   'confidence': 0.22851465474416294,
#   'lift': 7.327659232330889},
#  {'antecedent': ('RED HANGING HEART T-LIGHT HOLDER',),
#   'consequent': 'WHITE HANGING HEART T-LIGHT HOLDER',
#   'support': 460,
#   'confidence': 0.6647398843930635,
#   'lift': 7.327659232330889},
#  {'antecedent': ('ROUND SNACK BOXES SET OF4 WOODLAND ',),
#   'consequent': 'POSTAGE',
#   'support': 238,
#   'confidence': 0.3888888888888889,
#   'lift': 7.227340405732366},
#  {'antecedent': ('GREEN REGENCY TEACUP AND SAUCER',
#    'PINK REGENCY TEACUP AND SAUCER',
#    'ROSES REGENCY TEACUP AND SAUCER '),
#   'consequent': 'REGENCY CAKESTAND 3 TIER',
#   'support': 241,
#   'confidence': 0.6070528967254408,
#   'lift': 7.14994892693075},
#  {'antecedent': ('JUMBO BAG WOODLAND ANIMALS',),
#   'consequent': 'JUMBO BAG RED RETROSPOT',
#   'support': 265,
#   'confidence': 0.5289421157684631,
#   'lift': 7.1437769622046225},
#  {'antecedent': ('JUMBO STORAGE BAG SKULLS',),
#   'consequent': 'JUMBO BAG RED RETROSPOT',
#   'support': 249,
#   'confidence': 0.5253164556962026,
#   'lift': 7.094809587278597},
#  {'antecedent': ('PINK REGENCY TEACUP AND SAUCER',
#    'ROSES REGENCY TEACUP AND SAUCER '),
#   'consequent': 'REGENCY CAKESTAND 3 TIER',
#   'support': 241,
#   'confidence': 0.6008869179600886,
#   'lift': 7.07732521737493},
#  {'antecedent': ('RETROSPOT TEA SET CERAMIC 11 PC ',),
#   'consequent': 'BAKING SET 9 PIECE RETROSPOT ',
#   'support': 233,
#   'confidence': 0.27771156138259834,
#   'lift': 6.994800847990757},
#  {'antecedent': ('BAKING SET 9 PIECE RETROSPOT ',),
#   'consequent': 'RETROSPOT TEA SET CERAMIC 11 PC ',
#   'support': 233,
#   'confidence': 0.264472190692395,
#   'lift': 6.994800847990757},
#  {'antecedent': ('GREEN REGENCY TEACUP AND SAUCER',
#    'PINK REGENCY TEACUP AND SAUCER'),
#   'consequent': 'REGENCY CAKESTAND 3 TIER',
#   'support': 241,
#   'confidence': 0.5817409766454352,
#   'lift': 6.851821800298412},
#  {'antecedent': ('LUNCH BAG SUKI DESIGN ',),
#   'consequent': 'JUMBO STORAGE BAG SUKI',
#   'support': 223,
#   'confidence': 0.24344978165938866,
#   'lift': 6.829520423542142},
#  {'antecedent': ('JUMBO STORAGE BAG SUKI',),
#   'consequent': 'LUNCH BAG SUKI DESIGN ',
#   'support': 223,
#   'confidence': 0.28192161820480405,
#   'lift': 6.829520423542141},
#  {'antecedent': ('JUMBO BAG RED RETROSPOT',),
#   'consequent': 'JUMBO SHOPPER VINTAGE RED PAISLEY',
#   'support': 399,
#   'confidence': 0.24284844796104688,
#   'lift': 6.727599326161836},
#  {'antecedent': ('JUMBO SHOPPER VINTAGE RED PAISLEY',),
#   'consequent': 'JUMBO BAG RED RETROSPOT',
#   'support': 399,
#   'confidence': 0.49812734082397003,
#   'lift': 6.727599326161835},
#  {'antecedent': ('GREEN REGENCY TEACUP AND SAUCER',
#    'ROSES REGENCY TEACUP AND SAUCER '),
#   'consequent': 'REGENCY CAKESTAND 3 TIER',
#   'support': 241,
#   'confidence': 0.5673249551166966,
#   'lift': 6.682028001082536},
#  {'antecedent': ('LUNCH BAG ALPHABET DESIGN',),
#   'consequent': 'LUNCH BAG RED RETROSPOT',
#   'support': 262,
#   'confidence': 0.396969696969697,
#   'lift': 6.628109537816084},
#  {'antecedent': ('JUMBO BAG RED RETROSPOT',),
#   'consequent': 'JUMBO BAG APPLES',
#   'support': 360,
#   'confidence': 0.21911138161898966,
#   'lift': 6.579271391238675},
#  {'antecedent': ('JUMBO BAG APPLES',),
#   'consequent': 'JUMBO BAG RED RETROSPOT',
#   'support': 360,
#   'confidence': 0.4871447902571042,
#   'lift': 6.579271391238675},
#  {'antecedent': ('LUNCH BAG PINK POLKADOT',),
#   'consequent': 'JUMBO BAG PINK POLKADOT',
#   'support': 246,
#   'confidence': 0.2586750788643533,
#   'lift': 6.493212669683258},
#  {'antecedent': ('JUMBO BAG PINK POLKADOT',),
#   'consequent': 'LUNCH BAG PINK POLKADOT',
#   'support': 246,
#   'confidence': 0.27828054298642535,
#   'lift': 6.493212669683258},
#  {'antecedent': ('PINK REGENCY TEACUP AND SAUCER',),
#   'consequent': 'REGENCY CAKESTAND 3 TIER',
#   'support': 241,
#   'confidence': 0.5397631133671743,
#   'lift': 6.357401000858598},
#  {'antecedent': ('JUMBO BAG VINTAGE DOILY ',),
#   'consequent': 'JUMBO BAG RED RETROSPOT',
#   'support': 295,
#   'confidence': 0.46529968454258674,
#   'lift': 6.284236153377967},
#  {'antecedent': ('REGENCY CAKESTAND 3 TIER',),
#   'consequent': 'GREEN REGENCY TEACUP AND SAUCER',
#   'support': 241,
#   'confidence': 0.20329087048832273,
#   'lift': 6.154194292136264},
#  {'antecedent': ('GREEN REGENCY TEACUP AND SAUCER',),
#   'consequent': 'REGENCY CAKESTAND 3 TIER',
#   'support': 241,
#   'confidence': 0.5225102319236017,
#   'lift': 6.154194292136264},
#  {'antecedent': ('SPOTTY BUNTING',),
#   'consequent': 'PARTY BUNTING',
#   'support': 393,
#   'confidence': 0.387192118226601,
#   'lift': 6.141381775159596},
#  {'antecedent': ('PARTY BUNTING',),
#   'consequent': 'SPOTTY BUNTING',
#   'support': 393,
#   'confidence': 0.2809149392423159,
#   'lift': 6.141381775159596},
#  {'antecedent': ('ROSES REGENCY TEACUP AND SAUCER ',),
#   'consequent': 'REGENCY CAKESTAND 3 TIER',
#   'support': 241,
#   'confidence': 0.5167464114832536,
#   'lift': 6.0863072562703815},
#  {'antecedent': ('REGENCY CAKESTAND 3 TIER',),
#   'consequent': 'ROSES REGENCY TEACUP AND SAUCER ',
#   'support': 241,
#   'confidence': 0.22929936305732485,
#   'lift': 6.086307256270381},
#  {'antecedent': ('JUMBO BAG VINTAGE LEAF',),
#   'consequent': 'JUMBO BAG RED RETROSPOT',
#   'support': 347,
#   'confidence': 0.44601542416452444,
#   'lift': 6.023787134638343},
#  {'antecedent': ('JUMBO BAG RED RETROSPOT',),
#   'consequent': 'JUMBO BAG VINTAGE LEAF',
#   'support': 347,
#   'confidence': 0.21119902617163724,
#   'lift': 6.023787134638343},
#  {'antecedent': ('SET OF 3 CAKE TINS PANTRY DESIGN ',),
#   'consequent': 'RECIPE BOX PANTRY YELLOW DESIGN',
#   'support': 269,
#   'confidence': 0.22085385878489328,
#   'lift': 5.600853858784894},
#  {'antecedent': ('RECIPE BOX PANTRY YELLOW DESIGN',),
#   'consequent': 'SET OF 3 CAKE TINS PANTRY DESIGN ',
#   'support': 269,
#   'confidence': 0.30742857142857144,
#   'lift': 5.600853858784894},
#  {'antecedent': ('RED RETROSPOT CHARLOTTE BAG',),
#   'consequent': 'LUNCH BAG RED RETROSPOT',
#   'support': 243,
#   'confidence': 0.3218543046357616,
#   'lift': 5.373925522849925},
#  {'antecedent': ('JUMBO BAG ALPHABET',),
#   'consequent': 'JUMBO BAG RED RETROSPOT',
#   'support': 302,
#   'confidence': 0.39425587467362927,
#   'lift': 5.324733937314567},
#  {'antecedent': ('JUMBO STORAGE BAG SUKI',),
#   'consequent': 'LUNCH BAG RED RETROSPOT',
#   'support': 240,
#   'confidence': 0.3034134007585335,
#   'lift': 5.066022093929164},
#  {'antecedent': ('RED RETROSPOT CHARLOTTE BAG',),
#   'consequent': 'JUMBO BAG RED RETROSPOT',
#   'support': 283,
#   'confidence': 0.3748344370860927,
#   'lift': 5.062432233073888},
#  {'antecedent': ('JAM MAKING SET WITH JARS',),
#   'consequent': 'SET OF 3 CAKE TINS PANTRY DESIGN ',
#   'support': 247,
#   'confidence': 0.2559585492227979,
#   'lift': 4.66315287951879},
#  {'antecedent': ('SET OF 3 CAKE TINS PANTRY DESIGN ',),
#   'consequent': 'JAM MAKING SET WITH JARS',
#   'support': 247,
#   'confidence': 0.20279146141215107,
#   'lift': 4.6631528795187895},
#  {'antecedent': ('JUMBO BAG PINK POLKADOT',),
#   'consequent': 'LUNCH BAG RED RETROSPOT',
#   'support': 239,
#   'confidence': 0.2703619909502262,
#   'lift': 4.514170488476689},
#  {'antecedent': ('LUNCH BAG RED RETROSPOT',),
#   'consequent': 'JUMBO BAG RED RETROSPOT',
#   'support': 434,
#   'confidence': 0.326561324303988,
#   'lift': 4.41046609026506},
#  {'antecedent': ('JUMBO BAG RED RETROSPOT',),
#   'consequent': 'LUNCH BAG RED RETROSPOT',
#   'support': 434,
#   'confidence': 0.2641509433962264,
#   'lift': 4.41046609026506},
#  {'antecedent': ('LUNCH BAG PINK POLKADOT',),
#   'consequent': 'JUMBO BAG RED RETROSPOT',
#   'support': 282,
#   'confidence': 0.29652996845425866,
#   'lift': 4.004869141813755},
#  {'antecedent': ('SET OF 3 REGENCY CAKE TINS',),
#   'consequent': 'REGENCY CAKESTAND 3 TIER',
#   'support': 255,
#   'confidence': 0.33774834437086093,
#   'lift': 3.978044459442359},
#  {'antecedent': ('HEART OF WICKER LARGE',),
#   'consequent': 'WHITE HANGING HEART T-LIGHT HOLDER',
#   'support': 290,
#   'confidence': 0.35495716034271724,
#   'lift': 3.912816387483803},
#  {'antecedent': ('WOODEN PICTURE FRAME WHITE FINISH',),
#   'consequent': 'WHITE HANGING HEART T-LIGHT HOLDER',
#   'support': 310,
#   'confidence': 0.34675615212527966,
#   'lift': 3.822413818012894},
#  {'antecedent': ('LUNCH BAG  BLACK SKULL.',),
#   'consequent': 'JUMBO BAG RED RETROSPOT',
#   'support': 280,
#   'confidence': 0.26095060577819196,
#   'lift': 3.5243420220438706},
#  {'antecedent': ('LUNCH BAG CARS BLUE',),
#   'consequent': 'JUMBO BAG RED RETROSPOT',
#   'support': 258,
#   'confidence': 0.2608695652173913,
#   'lift': 3.523247505887957},
#  {'antecedent': ('LUNCH BAG SUKI DESIGN ',),
#   'consequent': 'JUMBO BAG RED RETROSPOT',
#   'support': 235,
#   'confidence': 0.25655021834061137,
#   'lift': 3.4649113481303506},
#  {'antecedent': ('LUNCH BAG APPLE DESIGN',),
#   'consequent': 'JUMBO BAG RED RETROSPOT',
#   'support': 225,
#   'confidence': 0.25626423690205014,
#   'lift': 3.46104894513481},
#  {'antecedent': ('WOODEN FRAME ANTIQUE WHITE ',),
#   'consequent': 'WHITE HANGING HEART T-LIGHT HOLDER',
#   'support': 257,
#   'confidence': 0.31113801452784506,
#   'lift': 3.429782683742117},
#  {'antecedent': ('HEART OF WICKER SMALL',),
#   'consequent': 'WHITE HANGING HEART T-LIGHT HOLDER',
#   'support': 268,
#   'confidence': 0.2757201646090535,
#   'lift': 3.0393593903004956},
#  {'antecedent': ('NATURAL SLATE HEART CHALKBOARD ',),
#   'consequent': 'WHITE HANGING HEART T-LIGHT HOLDER',
#   'support': 266,
#   'confidence': 0.2703252032520325,
#   'lift': 2.979888852539792},
#  {'antecedent': ('PARTY BUNTING',),
#   'consequent': 'WHITE HANGING HEART T-LIGHT HOLDER',
#   'support': 280,
#   'confidence': 0.20014295925661185,
#   'lift': 2.2062455369618563}]

# %% [markdown]
# Recommendations:
#
# 1.) When purchasing from suppliers, negotiate for discounts for frequent items.
# For example items such as:
#  - `SET/6 RED SPOTTY PAPER PLATES` and `SET/6 RED SPOTTY PAPER CUPS`
#  - `REGENCY TEA PLATE ROSES ` and `REGENCY TEA PLATE GREEN`
#
# 2.) Place frequent items in close proximity of each other. As much as possible these items should be in the same shelf or same aisle. This will increase the likelihood of the consumer to add to their cart the other items frequently bought along with the item that they intended to buy.
#
# 3.) Create bundles for consumers. The store can bundle up frequent itemsets together to increase sales. People who only inteded to buy item A could also be influenced to buy item B if they are bundled. Using the previous example, the store can create a "Red Spotty Bundle" that consists of `SET/6 RED SPOTTY PAPER PLATES` and `SET/6 RED SPOTTY PAPER CUPS`.

# %% [markdown]
# # References

# %% [markdown]
# * C. Aggarwal, "Data Mining: The Textbook", Springer, 2015.
# * P. Fournier‐Viger, J.C.W. Lin, B. Vo, T.T. Chi, J. Zhang, & H.B. Le, "A survey of itemset mining", Wiley Interdisciplinary Reviews: Data Mining and Knowledge Discovery, 7(4), e1207, 2017.
# * U. Malik, "Association Rule Mining via Apriori Algorithm in Python", 2018 [retrieved from https://stackabuse.com/association-rule-mining-via-apriori-algorithm-in-python]
