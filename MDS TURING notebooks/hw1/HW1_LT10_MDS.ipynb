# %% [markdown]
# # Homework 1
#
# This homework should be submitted <b>by LT</b>.
#
# LT Number: 10
#
# Names: Janica Lae Batang, Mary Honeylie Buitre, Paolo Jose de Guzman, John Francis Gacal, Vincent John Rivera

# %% [markdown]
# Do <b>NOT</b> import any other libraries aside from those below.

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [15, 5]

# %% [markdown]
# ## Combinations of Functions
#
# For a more detailed discussion on combinations of functions, see [`Paul's Online Notes`](http://tutorial.math.lamar.edu/Classes/Alg/CombineFunctions.aspx).
#
# Let the following:
#
# - $f(x) = \sin(2\pi x)$
#
#
# - $g(x) = \cos\left(\frac{x}{\pi}\right)$

# %% [markdown]
# #### Q. Create a numpy array (called `x`) of 1000 equally spaced numbers from -25 to 25.

# %%
x = np.linspace(-25, 25, 1000)

# %% [markdown]
# #### Q. Create two functions called `f(x)` and `g(x)` as defined above.

# %%
def f(x):
    return np.sin(2*np.pi*x)

def g(x):
    return np.cos(x/np.pi)

# %% [markdown]
# #### Q. Plot both graphs of `f(x)` and `g(x)` simulteneously (i.e. on the same plot) as a <b><u>solid blue line</u></b> and <b><u>solid red line</u></b>, respectively.

# %%
plt.plot(x, f(x), 'b-')
plt.plot(x, g(x), 'r-')
plt.show()

# %% [markdown]
# #### Q. Based on the resulting plot above, describe the differences between the two functions. Answer in 1 to 2 sentences.

# %% [markdown]
# Answer: The two graphs have the same amplitudes, but different frequencies. f(x), graphed with a solid blue line, has a greater frequency than g(x), graphed with a solid red line, meaning, it takes a shorter period to complete one cycle.

# %% [markdown]
# #### Q. Plot a graph of $f(x) + g(x)$ as a <b><u>solid blue line</u></b>.

# %%
plt.plot(x, f(x) + g(x), 'b-')
plt.show()

# %% [markdown]
# #### Q. Describe how the two sinusoids interact when you add them. Answer in 1 to 2 sentences.

# %% [markdown]
# Answer: Adding the two graphs resulted to a sinusoid, with amplitude of the sine function, seemingly within a sinusoid, with a combined amplitude of the functions. It also seems to have the frequency of f(x) while behaving according to the oscillation of g(x).

# %% [markdown]
# #### Q. Plot a graph of $f(x)g(x)$ as a <b><u>solid red line</u></b>. (1 pt.)

# %%
plt.plot(x, f(x) * g(x), 'r-')
plt.show()

# %% [markdown]
# #### Q. Describe how the two sinusoids interact when you multiply them. Answer in 1 to 2 sentences.

# %% [markdown]
# Answer: Multiplying two sinusoids result to a graph with the function having the smaller period oscillating inside the function having the bigger period. The amplitude is increasing and decreasing on a set interval, with period consistent with g(x) and frequency consistent with f(x).

# %% [markdown]
# #### Q. Plot a graph of $f(g(x))$ as a <b><u>solid green line</u></b>.

# %%
plt.plot(x, f(g(x)), 'g-')
plt.show()

# %% [markdown]
# #### Q. Describe how the two sinusoids interact they are composited in 1 to 2 sentences.

# %% [markdown]
# Answer: There is constructive and destructive interference, hence the resulting graph is no longer sinusoidal. It is still, however, periodic following the period of the g(x), the inner/nested function.

# %% [markdown]
# #### Q. Plot all three graphs simulteneously as <b><u>dashed lines</u></b> (keep the colors specified above).

# %%
plt.plot(x, f(x) + g(x), 'b--')
plt.plot(x, f(x) * g(x), 'r--')
plt.plot(x, f(g(x)), 'g--')
plt.show()

# %% [markdown]
# #### Q. Let's try adding a positive linear trend. Plot a graph of $f(x) + g(x) + \frac{1}{8}x$ as a <b><u>solid green line</u></b>.

# %%
plt.plot(x, f(x) + g(x) + x/8, 'g-')
plt.show()

# %% [markdown]
# #### Q. What kinds of data could reasonably follow the function described above? Answer in 2 to 3 sentences.

# %% [markdown]
# Answer: The type of data that could reasonably follow the given function is one with a positive linear trend, yet still has seasonality, say those that continuously increase over long periods of time, but changes periodically in a shorter time frame. An example would be atmospheric carbon dioxide levels which increases annually, yet varies according to the season. Another example is commodity pricing subject to inflation and seasonality.
