# %% [markdown]
# # Homework 2
#
# This homework should be submitted <b>by LT</b>.
#
# LT Number:
#
# Names:

# %% [markdown]
# Do <b><u>NOT</u></b> import any other libraries aside from those below.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

plt.rcParams['figure.figsize'] = [15, 5]

# %% [markdown]
# ## Curve Fitting
#
# For this homework, we will be using the following datasets: `fit_data1.csv`, `fit_data2.csv`, `fit_data3.csv`, `fit_data4.csv`.

# %% [markdown]
# #### Q. Load the `fit_data1.csv` dataset using pandas and print the dataframe.

# %%
# Insert code here
df_data1 = pd.read_csv('fit_data1.csv')
df_data1
# Out:
#             x           y
# 0    0.000000  292.073549
# 1    0.707071  214.164335
# 2    1.414141  230.606929
# 3    2.121212  303.335048
# 4    2.828283  251.714122
# ..        ...         ...
# 95  67.171717  428.026119
# 96  67.878788  397.565071
# 97  68.585859  337.196256
# 98  69.292929  403.412667
# 99  70.000000  432.073549
#
# [100 rows x 2 columns]

# %% [markdown]
# #### Q. Create two variables `x` and `y` and assign the corresponding dataframe columns to them. Convert `x` and `y` into numpy arrays.

# %%
# Insert code here
x_1 = df_data1['x'] 
y_1 = df_data1['y']
x_1 = x_1.to_numpy()
y_1 = y_1.to_numpy()

# %% [markdown]
# #### Q. Plot a graph of the data as a <b><u>dashed blue line</u></b>.

# %%
# Insert code here
plt.plot(x_1, y_1, 'b--')
plt.title("Data Set 1")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# #### Q. Based on the plot above, choose an "appropriate" function to fit the data. Print the optimal parameters and SSR.

# %%
# Insert code here
def sine_linear(x_1, A, F, C, D, E):
    return A * np.sin((2 * np.pi * F * x_1) + C) + D*x_1 + E

popt, pcov = curve_fit(sine_linear, x_1, y_1)

ssr = sum((y_1 - sine_linear(x_1, *popt))**2)

print('A:',popt[0])
print('f:',popt[1])
print('C:',popt[2])
print('D:',popt[3])
print('E:',popt[4])

print('SSR:', ssr)
# Out:
# A: 50.00000000000012
# f: 1.0
# C: 0.9999999999999886
# D: 2.000000000000001
# E: 250.00000000000009
# SSR: 7.649643520268224e-23

# %% [markdown]
# #### Q. Plot the data as <u><b>blue dots</u></b> and plot you fitted function as a <b><u>smooth solid red line</u></b>.

# %%
# Insert code here
x_range = np.linspace(min(x_1), max(x_1), 100)

plt.plot(x_range, sine_linear(x_range, *popt), 'r-')
plt.scatter(x_1, y_1)
plt.title("Data Set 1")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# #### Q. Load the `fit_data2.csv` dataset using pandas and print the dataframe.

# %%
# Insert code here
df_data2 = pd.read_csv('fit_data2.csv')
df_data2
# Out:
#             x         y
# 0    0.000000  0.000000
# 1    0.008008  0.007944
# 2    0.016016  0.015762
# 3    0.024024  0.023454
# 4    0.032032  0.031022
# ..        ...       ...
# 995  7.967968  0.002760
# 996  7.975976  0.002741
# 997  7.983984  0.002722
# 998  7.991992  0.002703
# 999  8.000000  0.002684
#
# [1000 rows x 2 columns]

# %% [markdown]
# #### Q. Create two variables `x` and `y` and assign the corresponding dataframe columns to them. Convert `x` and `y` into numpy arrays.

# %%
# Insert code here
x_2 = df_data2['x'] 
y_2 = df_data2['y']
x_2 = x_2.to_numpy()
y_2 = y_2.to_numpy()

# %% [markdown]
# #### Q. Plot a graph of the data as a <b><u>dashed blue line</u></b>.

# %%
# Insert code here
plt.plot(x_2, y_2, 'b--')
plt.title("Data Set 2")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# #### Q. Based on the plot above, choose an "appropriate" function to fit the data. Print the optimal parameters and SSR.

# %%
# Insert code here
def sigmoid_cubic(x_2, a, b, c, d, A, k, x0):
    return ((a * (A/(1 + np.exp(-k * (x_2 - x0))))**3) + (b * (A/(1 + np.exp(-k * (x_2 - x0))))**2) + (c * (A/(1 + np.exp(-k * (x_2 - x0))))) + d)

popt, pcov = curve_fit(sigmoid_cubic, x_2, y_2)

ssr = sum((y_2 - sigmoid_cubic(x_2, *popt))**2)

print('a:',popt[0])
print('b:',popt[1])
print('c:',popt[2])
print('d:',popt[3])
print('A:',popt[4])
print('k:',popt[5])
print('x0:',popt[6])
print('SSR:', ssr)
# Out:
# a: -3.298902892284046e-05
# b: -18.059193716888437
# c: 5.176068349244534
# d: -0.0021768151979083637
# A: 2.117143946056908
# k: -0.762913204707039
# x0: -2.435302588153967
# SSR: 0.00037560385750393327

# %% [markdown]
# #### Q. Plot the data as <u><b>blue dots</u></b> and plot you fitted function as a <b><u>smooth solid red line</u></b>.

# %%
# Insert code here
x_range = np.linspace(min(x_2), max(x_2), 100)

plt.plot(x_range, sigmoid_cubic(x_range, *popt), 'r-')
plt.scatter(x_2, y_2)
plt.title("Data Set 2")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# #### Q. Load the `fit_data3.csv` dataset using pandas and print the dataframe.

# %%
# Insert code here
df_data3 = pd.read_csv('fit_data3.csv')
df_data3
# Out:
#             x          y
# 0  -12.566371   1.000000
# 1  -12.312505   0.470743
# 2  -12.058638   0.232564
# 3  -11.804772   0.126156
# 4  -11.550906   0.078146
# ..        ...        ...
# 95  11.550906  12.796559
# 96  11.804772   7.926702
# 97  12.058638   4.299893
# 98  12.312505   2.124303
# 99  12.566371   1.000000
#
# [100 rows x 2 columns]

# %% [markdown]
# #### Q. Create two variables `x` and `y` and assign the corresponding dataframe columns to them. Convert `x` and `y` into numpy arrays.

# %%
# Insert code here
x_3 = df_data3['x'] 
y_3 = df_data3['y']
x_3 = x_3.to_numpy()
y_3 = y_3.to_numpy()

# %% [markdown]
# #### Q. Plot a graph of the data as a <b><u>dashed blue line</u></b>. (you may also want to check what the plot looks like as dots)

# %%
# Insert code here
plt.plot(x_3, y_3, 'b--')
plt.title("Data Set 3")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# #### Q. Based on the plot above, choose an "appropriate" function to fit the data. Print the optimal parameters and SSR.

# %%
#Insert code here
def gausofsine(x_3, stdev, mean, A, B, C):
    return  (1/np.sqrt(2 * np.pi * stdev**2)) * np.exp((A * np.sin((2 * np.pi * B * x_3) + C) - mean)**2 / (2*stdev**2))

popt, pcov = curve_fit(gausofsine, x_3, y_3)

ssr = sum((y_3 - gausofsine(x_3, *popt))**2)

print('A:',popt[0])
print('B:',popt[1])
print('C:',popt[2])
print('D:',popt[3])
print('E:',popt[4])
print('SSR:', ssr)
# Out:
# A: 0.8956608415362607
# B: 1.9566530264264723
# C: -0.009834470133722416
# D: 1.005332860256146
# E: 1.4670851278827521
# SSR: 4312.051767908959

# %% [markdown]
# #### Q. Plot the data as <u><b>blue dots</u></b> and plot you fitted function as a <b><u>smooth solid red line</u></b>.

# %%
# Insert code here
x_range = np.linspace(min(x_3), max(x_3), 100)

plt.plot(x_range, gausofsine(x_range, *popt), 'r-')
plt.scatter(x_3, y_3)
plt.title("Data Set 3")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# #### Q. Load the `fit_data4.csv` dataset using pandas and print the dataframe.

# %%
# Insert code here
df_data4 = pd.read_csv('fit_data4.csv')
df_data4
# Out:
#           x         y
# 0  -5.00000  0.010799
# 1  -4.89899  0.005704
# 2  -4.79798  0.006033
# 3  -4.69697  0.059341
# 4  -4.59596  0.020562
# ..      ...       ...
# 95  4.59596  1.071575
# 96  4.69697  1.034006
# 97  4.79798  1.015753
# 98  4.89899  0.989731
# 99  5.00000  0.996418
#
# [100 rows x 2 columns]

# %% [markdown]
# #### Q. Create two variables `x` and `y` and assign the corresponding dataframe columns to them. Convert `x` and `y` into numpy arrays.

# %%
# Insert code here
x_4 = df_data4['x'] 
y_4 = df_data4['y']
x_4 = x_4.to_numpy()
y_4 = y_4.to_numpy()

# %% [markdown]
# #### Q. Plot a graph of the data as a <b><u>dashed blue line</u></b>. (you may also want to check what the plot looks like as dots)

# %%
# Insert code here
plt.plot(x_4, y_4, 'b--')
plt.title("Data Set 4")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# #### Q. Based on the plot above, choose an "appropriate" function to fit the data. Print the optimal parameters and SSR.

# %%
# Insert code here
def custom_function(x,sigm_A, sigm_k, sigm_x0,cubic_a, cubic_b, cubic_c, cubic_constant,sine_A, sine_f, sine_C, sine_constant,linear_m, linear_constant): 
    return (sigm_A/(1 + np.exp(-sigm_k * (x_4 - sigm_x0)))) + (((cubic_a * x_4**3) + (cubic_b * x_4**2) + (cubic_c * x_4) + cubic_constant)*(sine_A * np.sin((2 * np.pi * sine_f * x_4)+ sine_C))) + (linear_m * x_4 + linear_constant)

popt, pcov = curve_fit(custom_function, x_4, y_4)

ssr = sum((y_4 - custom_function(x_4, *popt))**2)

print('A:',popt[0])
print('F:',popt[1])
print('C:',popt[2])
print('a:',popt[3])
print('b:',popt[4])
print('c:',popt[5])
print('d:',popt[6])

print('SSR:', ssr)
# Out:
# A: 1.0266794454754176
# F: 1.996961986737237
# C: 0.006300123829192946
# a: -0.16847493361131785
# b: -0.2687254609397984
# c: 2.5539721121228283
# d: 1.186152450761826
# SSR: 0.12995330524477383
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:828: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %% [markdown]
# #### Q. Plot the data as <u><b>blue dots</u></b> and plot you fitted function as a <b><u>smooth solid red line</u></b>.

# %%
# Insert code here
x_range = np.linspace(min(x_4), max(x_4), 100)

plt.plot(x_range, custom_function(x_range, *popt), 'r-')
plt.scatter(x_4, y_4)
plt.title("Data Set 4")
plt.xlabel('x')
plt.ylabel('y')
plt.show()
