# %% [markdown]
# # Homework 2
#
# This homework should be submitted <b>by LT</b>.
#
# LT Number: 10
#
# Names: Janica Lae Batang, Mary Honeylie Buitre, Paolo Jose de Guzman, John Francis Gacal, Vincent John Rivera

# %% [markdown]
# Do <b><u>NOT</u></b> import any other libraries aside from those below.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

plt.rcParams['figure.figsize'] = [15, 5]

# %% [markdown]
# ## Curve Fitting
#
# For this homework, we will be using the following datasets: `fit_data1.csv`, `fit_data2.csv`, `fit_data3.csv`, `fit_data4.csv`.

# %% [markdown]
# #### Q. Load the `fit_data1.csv` dataset using pandas and print the dataframe.

# %%
# Insert code here
df_data1 = pd.read_csv('fit_data1.csv')
df_data1
# Out:
#             x           y
# 0    0.000000  292.073549
# 1    0.707071  214.164335
# 2    1.414141  230.606929
# 3    2.121212  303.335048
# 4    2.828283  251.714122
# ..        ...         ...
# 95  67.171717  428.026119
# 96  67.878788  397.565071
# 97  68.585859  337.196256
# 98  69.292929  403.412667
# 99  70.000000  432.073549
#
# [100 rows x 2 columns]

# %% [markdown]
# #### Q. Create two variables `x` and `y` and assign the corresponding dataframe columns to them. Convert `x` and `y` into numpy arrays.

# %%
# Insert code here
x_1 = df_data1['x'] 
y_1 = df_data1['y']
x_1 = x_1.to_numpy()
y_1 = y_1.to_numpy()

# %% [markdown]
# #### Q. Plot a graph of the data as a <b><u>dashed blue line</u></b>.

# %%
# Insert code here
plt.plot(x_1, y_1, 'b--')
plt.title("Dataset 1")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# #### Q. Based on the plot above, choose an "appropriate" function to fit the data. Print the optimal parameters and SSR.

# %%
# Insert code here
def sine_linear(x_1, A, F, C, D, E):
    return A * np.sin((2 * np.pi * F * x_1) + C) + (D*x_1 + E)

popt, pcov = curve_fit(sine_linear, x_1, y_1)

ssr = sum((y_1 - sine_linear(x_1, *popt))**2)

print('A:',popt[0])
print('F:',popt[1])
print('C:',popt[2])
print('D:',popt[3])
print('E:',popt[4])

print('SSR:', ssr)
# Out:
# A: 50.00000000000008
# F: 1.0
# C: 0.9999999999999969
# D: 1.9999999999999976
# E: 250.00000000000006
# SSR: 7.30511956396562e-23

# %% [markdown]
# #### Q. Plot the data as <u><b>blue dots</u></b> and plot you fitted function as a <b><u>smooth solid red line</u></b>.

# %%
# Insert code here
x_range = np.linspace(min(x_1), max(x_1), 100)

plt.plot(x_range, sine_linear(x_range, *popt), 'r-')
plt.scatter(x_1, y_1)
plt.title("Dataset 1")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# #### Q. Load the `fit_data2.csv` dataset using pandas and print the dataframe.

# %%
# Insert code here
df_data2 = pd.read_csv('fit_data2.csv')
df_data2
# Out:
#             x         y
# 0    0.000000  0.000000
# 1    0.008008  0.007944
# 2    0.016016  0.015762
# 3    0.024024  0.023454
# 4    0.032032  0.031022
# ..        ...       ...
# 995  7.967968  0.002760
# 996  7.975976  0.002741
# 997  7.983984  0.002722
# 998  7.991992  0.002703
# 999  8.000000  0.002684
#
# [1000 rows x 2 columns]

# %% [markdown]
# #### Q. Create two variables `x` and `y` and assign the corresponding dataframe columns to them. Convert `x` and `y` into numpy arrays.

# %%
# Insert code here
x_2 = df_data2['x'] 
y_2 = df_data2['y']
x_2 = x_2.to_numpy()
y_2 = y_2.to_numpy()

# %% [markdown]
# #### Q. Plot a graph of the data as a <b><u>dashed blue line</u></b>.

# %%
# Insert code here
plt.plot(x_2, y_2, 'b--')
plt.title("Data Set 2")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# #### Q. Based on the plot above, choose an "appropriate" function to fit the data. Print the optimal parameters and SSR.

# %%
# Insert code here
def exp_power(x_2, p, q, r, s):
    return (p * np.exp(-q * x_2)) / (r * (np.power(x_2, -s)))

np.seterr(divide='ignore')
popt, pcov = curve_fit(exp_power, x_2, y_2)

ssr = sum((y_2 - exp_power(x_2, *popt))**2)

print('p:',popt[0])
print('q:',popt[1])
print('r:',popt[2])
print('s:',popt[3])
print('SSR:', ssr)
# Out:
# p: 1.0
# q: 1.0
# r: 1.0
# s: 1.0
# SSR: 6.0676121971366055e-31

# %% [markdown]
# #### Q. Plot the data as <u><b>blue dots</u></b> and plot you fitted function as a <b><u>smooth solid red line</u></b>.

# %%
# Insert code here
x_range = np.linspace(min(x_2), max(x_2), 100)

plt.plot(x_range, exp_power(x_range, *popt), 'r-')
plt.scatter(x_2, y_2)
plt.title("Data Set 2")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# #### Q. Load the `fit_data3.csv` dataset using pandas and print the dataframe.

# %%
# Insert code here
df_data3 = pd.read_csv('fit_data3.csv')
df_data3
# Out:
#             x          y
# 0  -12.566371   1.000000
# 1  -12.312505   0.470743
# 2  -12.058638   0.232564
# 3  -11.804772   0.126156
# 4  -11.550906   0.078146
# ..        ...        ...
# 95  11.550906  12.796559
# 96  11.804772   7.926702
# 97  12.058638   4.299893
# 98  12.312505   2.124303
# 99  12.566371   1.000000
#
# [100 rows x 2 columns]

# %% [markdown]
# #### Q. Create two variables `x` and `y` and assign the corresponding dataframe columns to them. Convert `x` and `y` into numpy arrays.

# %%
# Insert code here
x_3 = df_data3['x'] 
y_3 = df_data3['y']
x_3 = x_3.to_numpy()
y_3 = y_3.to_numpy()

# %% [markdown]
# #### Q. Plot a graph of the data as a <b><u>dashed blue line</u></b>. (you may also want to check what the plot looks like as dots)

# %%
# Insert code here
plt.plot(x_3, y_3, 'b--')
plt.title("Data Set 3")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# #### Q. Based on the plot above, choose an "appropriate" function to fit the data. Print the optimal parameters and SSR.

# %%
#Insert code here
def custom_sine (x_3,a, h, i, j):
    return a ** ((np.sin(i * x_3 + j)) + h)

popt, pcov = curve_fit(custom_sine, x_3, y_3)

ssr = sum((y_3 - custom_sine(x_3, *popt))**2)

print('a:',popt[0])
print('h:',popt[1])
print('i:',popt[2])
print('j:',popt[3])
print('SSR:', ssr)
# Out:
# a: 20.085536969059483
# h: -5.759236820239239e-10
# i: 0.9999999999968932
# j: 3.1415926535958705
# SSR: 1.3903079424283303e-15

# %% [markdown]
# #### Q. Plot the data as <u><b>blue dots</u></b> and plot you fitted function as a <b><u>smooth solid red line</u></b>.

# %%
# Insert code here
x_range = np.linspace(min(x_3), max(x_3), 100)

plt.plot(x_range, custom_sine(x_range, *popt), 'r-')
plt.scatter(x_3, y_3)
plt.title("Data Set 3")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# #### Q. Load the `fit_data4.csv` dataset using pandas and print the dataframe.

# %%
# Insert code here
df_data4 = pd.read_csv('fit_data4.csv')
df_data4
# Out:
#           x         y
# 0  -5.00000  0.010799
# 1  -4.89899  0.005704
# 2  -4.79798  0.006033
# 3  -4.69697  0.059341
# 4  -4.59596  0.020562
# ..      ...       ...
# 95  4.59596  1.071575
# 96  4.69697  1.034006
# 97  4.79798  1.015753
# 98  4.89899  0.989731
# 99  5.00000  0.996418
#
# [100 rows x 2 columns]

# %% [markdown]
# #### Q. Create two variables `x` and `y` and assign the corresponding dataframe columns to them. Convert `x` and `y` into numpy arrays.

# %%
# Insert code here
x_4 = df_data4['x'] 
y_4 = df_data4['y']
x_4 = x_4.to_numpy()
y_4 = y_4.to_numpy()

# %% [markdown]
# #### Q. Plot a graph of the data as a <b><u>dashed blue line</u></b>. (you may also want to check what the plot looks like as dots)

# %%
# Insert code here
plt.plot(x_4, y_4, 'b--')
plt.title("Dataset 4")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# #### Q. Based on the plot above, choose an "appropriate" function to fit the data. Print the optimal parameters and SSR.

# %%
# Insert code here
def combo(x_4,d,e,f,g,v,w,z,u,t,h,i,j): 
     return ((d * x_4**3) + (e * x_4**2) + (f * x_4) + g)*(v/(1 + np.exp(-w * (x_4 - z))))+(1/np.sqrt(2 * np.pi *u**2)) * np.exp(-(x_4 - t)**2/(2*u**2))/(h * np.sin((2 * np.pi * i * x_4) + j))
    
popt,pcov = curve_fit(combo, x_4, y_4)

ssr = sum((y_4 - combo(x_4, *popt))**2)

print('d:',popt[0])
print('e:',popt[1])
print('f:',popt[2])
print('g:',popt[3])
print('v:',popt[4])
print('w:',popt[5])
print('z:',popt[6])
print('u:',popt[7])
print('t:',popt[8])
print('h:',popt[9])
print('i:',popt[10])
print('j:',popt[11])
print('SSR:', ssr)
# Out:
# d: 0.00024707449465876405
# e: -0.019369370321616758
# f: 0.13046870854080467
# g: -2.167109841929046
# v: -0.5147171212559636
# w: 1.9248621744039685
# z: 0.11139174094246056
# u: 0.34497314291837705
# t: 3.2656469400285646
# h: 55.756600995126455
# i: 0.9620911158190422
# j: 1.7399397017208122
# SSR: 0.1268788750620429

# %% [markdown]
# #### Q. Plot the data as <u><b>blue dots</u></b> and plot you fitted function as a <b><u>smooth solid red line</u></b>.

# %%
# Insert code here
x_range = np.linspace(min(x_4), max(x_4), 100)

plt.plot(x_range, combo(x_range, *popt), 'r-')
plt.scatter(x_4, y_4)
plt.title("Data Set 4")
plt.xlabel('x')
plt.ylabel('y')
plt.show()
