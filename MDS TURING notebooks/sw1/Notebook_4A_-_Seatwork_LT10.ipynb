# %% [markdown]
# ## Notebook 4A: Seatwork
#
# This seatwork should be submitted <b>by LT</b>.
#
# LT Number: 10
#
# Names: Janica Lae Batang, Mary Honeylie Buitre, Paolo Jose de Guzman, John Francis Gacal, Vincent John Rivera

# %% [markdown]
# #### Q1.
#
# Given the following:
#
# \begin{align*}
#     \begin{bmatrix}
#     1 & 3 & 3 & -2\\
#     2 & 2 & 1 & 1\\
#     4 & 2 & -1 & 5\\
#     -3 & 2 & -5 & 5
#     \end{bmatrix} \begin{bmatrix}
#     x_1\\
#     x_2\\
#     x_3\\
#     x_4
#     \end{bmatrix} =
#     \begin{bmatrix}
#     1\\
#     2\\
#     3\\
#     4
#     \end{bmatrix}
# \end{align*}

# %% [markdown]
# Do the following:
#
# 1) Calculate $\text{det}(A)$.
#
# 2) Solve for $x$ using Cramer's Rule.

# %% [markdown]
# \begin{align*}
#    \text{det}(A) = (1)(-1)^{1+1}
#    \begin{vmatrix}
#     2 & 1 & 1 \\
#     2 & -1 & 5 \\
#     2 & -5 & 5
#     \end{vmatrix}
#     + (3)(-1)^{1+2} \begin{vmatrix}
#     2 & 1 & 1 \\
#     4 & -1 & 5 \\
#     -3 & -5 & 5
#     \end{vmatrix}
#     + (3)(-1)^{1+3} \begin{vmatrix}
#     2 & 2 & 1 \\
#     4 & 2 & 5 \\
#     -3 & 2 & 5
#     \end{vmatrix}
#     + (-2)(-1)^{1+4} \begin{vmatrix}
#     2 & 2 & 1 \\
#     4 & 2 & -1 \\
#     -3 & 2 & -5
#     \end{vmatrix}
#     \quad
#     =
#     (1)\bigg((2)(-1)^{1+1}\begin{vmatrix}
#     -1 & 5 \\
#     -5 & 5
#     \end{vmatrix}
#     + (1)(-1)^{1+2}\begin{vmatrix}
#     2 & 5 \\
#     2 & 5
#     \end{vmatrix}
#     +(1)(-1)^{1+3}\begin{vmatrix}
#     2 & -1 \\
#     2 & -5
#     \end{vmatrix}\bigg)
#     - (3)\bigg((2)(-1)^{1+1}\begin{vmatrix}
#     -1 & 5 \\
#     -5 & 5
#     \end{vmatrix}
#     + (1)(-1)^{1+2}\begin{vmatrix}
#     4 & 5 \\
#     -3 & 5
#     \end{vmatrix}
#     + (1)(-1)^{1+3}\begin{vmatrix}
#     4 & -1 \\
#     -3 & -5
#     \end{vmatrix}\bigg)
#     + (3)\bigg((2)(-1)^{1+1}\begin{vmatrix}
#     2 & 5 \\
#     2 & 5
#     \end{vmatrix}
#     + (2)(-1)^{1+2}\begin{vmatrix}
#     4 & 5 \\
#     -3 & 5
#     \end{vmatrix}
#     + (1)(-1)^{1+3}\begin{vmatrix}
#     4 & 2 \\
#     -3 & 2
#     \end{vmatrix}\bigg)
#     + (2)\bigg((2)(-1)^{1+1}\begin{vmatrix}
#     2 & -1 \\
#     2 & -5
#     \end{vmatrix}
#     + (2)(-1)^{1+2}\begin{vmatrix}
#     4 & -1 \\
#     -3 & -5
#     \end{vmatrix}
#     + (1)(-1)^{1+3}\begin{vmatrix}
#     4 & 2 \\
#     -3 & 2
#     \end{vmatrix}\bigg)
#     \quad
#     = (1)\bigg((2)(20)-(1)(0)+(1)(-8)\bigg)
#     - (3)\bigg((2)(20)-(1)(35)+(1)(-23)\bigg)
#     + (3)\bigg((2)(0)-(2)(35)+(1)(14)\bigg)
#     + (2)\bigg((2)(-8)-(2)(-23)+(1)(14)\bigg)
#     = \underline{\textbf{6}}
# \end{align*}

# %% [markdown]
# \begin{align*}
#     \text{det}(A_1) = \begin{vmatrix}
#     1 & 3 & 3 & -2\\
#     2 & 2 & 1 & 1\\
#     3 & 2 & -1 & 5\\
#     4 & 2 & -5 & 5
#     \end{vmatrix}
#     \quad
#     \text{det}(A_2) = \begin{vmatrix}
#     1 & 1 & 3 & -2\\
#     2 & 2 & 1 & 1\\
#     4 & 3 & -1 & 5\\
#     -3 & 4 & -5 & 5
#     \end{vmatrix}
#     \quad
#     \text{det}(A_3) = \begin{vmatrix}
#     1 & 3 & 1 & -2\\
#     2 & 2 & 2 & 1\\
#     4 & 2 & 3 & 5\\
#     -3 & 2 & 4 & 5
#     \end{vmatrix}
#     \quad
#     \text{det}(A_4) = \begin{vmatrix}
#     1 & 3 & 3 & 1\\
#     2 & 2 & 1 & 2\\
#     4 & 2 & -1 & 3\\
#     -3 & 2 & -5 & 4
#     \end{vmatrix}
#     \\
#     \text{det}(A_1) = (1)(-1)^{1+1}
#    \begin{vmatrix}
#     2 & 1 & 1 \\
#     2 & -1 & 5 \\
#     2 & -5 & 5
#     \end{vmatrix}
#     + (3)(-1)^{1+2} \begin{vmatrix}
#     2 & 1 & 1 \\
#     3 & -1 & 5 \\
#     4 & -5 & 5
#     \end{vmatrix}
#     + (3)(-1)^{1+3} \begin{vmatrix}
#     2 & 2 & 1 \\
#     3 & 2 & 5 \\
#     4 & 2 & 5
#     \end{vmatrix}
#     + (-2)(-1)^{1+4} \begin{vmatrix}
#     2 & 2 & 1 \\
#     3 & 2 & -1 \\
#     4 & 2 & -5
#     \end{vmatrix}
#     \quad
#     \text{det}(A_2) = (1)(-1)^{1+1}
#     \begin{vmatrix}
#     2 & 1 & 1 \\
#     3 & -1 & 5 \\
#     4 & -5 & 5
#     \end{vmatrix}
#     + (1)(-1)^{1+2} \begin{vmatrix}
#     2 & 1 & 1 \\
#     4 & -1 & 5 \\
#     -3 & -5 & 5
#     \end{vmatrix}
#     + (3)(-1)^{1+3} \begin{vmatrix}
#     2 & 2 & 1 \\
#     4 & 3 & 5 \\
#     -3 & 4 & 5
#     \end{vmatrix}
#     + (-2)(-1)^{1+4} \begin{vmatrix}
#     2 & 2 & 1 \\
#     4 & 3 & -1 \\
#     -3 & 4 & -5
#     \end{vmatrix}
#     \quad
#     \text{det}(A_3) = (1)(-1)^{1+1}
#     \begin{vmatrix}
#     2 & 2 & 1 \\
#     2 & 3 & 5 \\
#     2 & 4 & 5
#     \end{vmatrix}
#     + (3)(-1)^{1+2} \begin{vmatrix}
#     2 & 2 & 1 \\
#     4 & 3 & 5 \\
#     -3 & 4 & 5
#     \end{vmatrix}
#     + (1)(-1)^{1+3} \begin{vmatrix}
#     2 & 2 & 1 \\
#     4 & 2 & 5 \\
#     -3 & 2 & 5
#     \end{vmatrix}
#     + (-2)(-1)^{1+4} \begin{vmatrix}
#     2 & 2 & 2 \\
#     4 & 2 & 3 \\
#     -3 & 2 & 4
#     \end{vmatrix}
#     \quad
#     \text{det}(A_4) = (1)(-1)^{1+1}
#     \begin{vmatrix}
#     2 & 1 & 2 \\
#     2 & -1 & 3 \\
#     2 & -5 & 4
#     \end{vmatrix}
#     + (3)(-1)^{1+2} \begin{vmatrix}
#     2 & 1 & 2 \\
#     4 & -1 & 3 \\
#     -3 & -5 & 4
#     \end{vmatrix}
#     + (3)(-1)^{1+3} \begin{vmatrix}
#     2 & 2 & 2 \\
#     4 & 2 & 3 \\
#     -3 & 2 & 4
#     \end{vmatrix}
#     + (1)(-1)^{1+4} \begin{vmatrix}
#     2 & 2 & 1 \\
#     4 & 2 & -1 \\
#     -3 & 2 & -5
#     \end{vmatrix}
#     \quad
# \end{align*}
# \begin{align*}
#     \text{det}(A_1) = -38\quad
#     \text{det}(A_2) = -15\quad
#     \text{det}(A_3) = 65\quad
#     \text{det}(A_4) = 53
# \end{align*}

# %% [markdown]
# \begin{align*}
#  \begin{bmatrix}
#     x_1\\
#     x_2\\
#     x_3\\
#     x_4
#   \end{bmatrix}
#   = \frac{1}{\text{det}(A)}
#   \begin{bmatrix}
#     \text{det}(A_1)\\
#     \text{det}(A_2)\\
#     \text{det}(A_3)\\
#     \text{det}(A_4)
#   \end{bmatrix}
#   = \begin{bmatrix}
#     \frac{-38}{6}\\
#     \frac{-15}{6}\\
#     \frac{65}{6}\\
#     \frac{53}{6}
#   \end{bmatrix}
#   = \begin{bmatrix}
#     \frac{-19}{3}\\
#     \frac{-5}{2}\\
#     \frac{65}{6}\\
#     \frac{53}{6}
#   \end{bmatrix}
# \end{align*}

# %% [markdown]
# #### Q2.
#
# Given the following:
#
# \begin{align*}
#     \begin{bmatrix}
#     1 & 3 & 5\\
#     2 & 2 & 2\\
#     2 & 3 & -1
#     \end{bmatrix} \begin{bmatrix}
#     x_1\\
#     x_2\\
#     x_3
#     \end{bmatrix} =
#     \begin{bmatrix}
#     1\\
#     2\\
#     3
#     \end{bmatrix}
# \end{align*}

# %% [markdown]
# Do the following:
#
# 1) Calculate $A^{-1}$ using the method of cofactors.
#
# 2) Solve for $x$ by evaluating $A^{-1}b$.

# %% [markdown]
# \begin{align*}
#     \text {det}(A) = (1)(-1)^{1+1}\begin{vmatrix}
#      2 & 2\\
#      3 & -1
#      \end{vmatrix}
#      + (3)(-1)^{1+2} \begin{vmatrix}
#      2 & 2\\
#      2 & -1
#      \end{vmatrix}
#      + (5)(-1)^{1+3} \begin{vmatrix}
#      2 & 2\\
#      2 & 3
#      \end{vmatrix}
#      = 20
# \end{align*}
#
# \begin{align*}
#     M_{11} = \begin{vmatrix} 2 & 2\\ 3 & -1\end{vmatrix} = -8\quad
#     M_{12} = \begin{vmatrix} 2 & 2\\ 2 & -1\end{vmatrix} = -6\quad
#     M_{13} = \begin{vmatrix} 2 & 2\\ 2 & 3\end{vmatrix} = 2\quad
#     M_{21} = \begin{vmatrix} 3 & 5\\ 3 & -1\end{vmatrix} = -18\quad
#     M_{22} = \begin{vmatrix} 1 & 5\\ 2 & -1\end{vmatrix} = -11\quad
#     M_{23} = \begin{vmatrix} 1 & 3\\ 2 & 3\end{vmatrix} = -3\quad
#     M_{31} = \begin{vmatrix} 3 & 5\\ 2 & 2\end{vmatrix} = -4\quad
#     M_{32} = \begin{vmatrix} 1 & 5\\ 2 & 2\end{vmatrix} = -8\quad
#     M_{33} = \begin{vmatrix} 1 & 3\\ 2 & 2\end{vmatrix} = -4\quad
# \end{align*}
#
# \begin{align*}
#     C = \begin{vmatrix}
#     (-1)^{1+1}-8 & (-1)^{1+2}-6 & (-1)^{1+3}2 \\
#     (-1)^{2+1}-18 & (-1)^{2+2}-11 & (-1)^{2+3}-3 \\
#     (-1)^{3+1}-4  & (-1)^{3+2}-8 & (-1)^{3+3}-4
#         \end{vmatrix}
#         = \begin{vmatrix} -8 & 6 & 2\\
#                           18 & -11 & 3\\
#                           -4 & 8 & -4
#        \end{vmatrix}
# \end{align*}
#
# \begin{align*}
#     C^{T} = \begin{vmatrix}
#             -8 & 18 & -4\\
#             6 & -11 & 8\\
#             2 & 3 & -4
#           \end{vmatrix}
# \end{align*}
#
# \begin{align*}
#     A^{-1} = (-\frac{1}{20})\begin{bmatrix}
#             -8 & 18 & -4\\
#             6 & -11 & 8\\
#             2 & 3 & -4
#           \end{bmatrix}
#           = \begin{bmatrix}
#            -\frac{2}{5} & \frac{9}{10} & -\frac{1}{5} \\
#             \frac{3}{10} & -\frac{11}{20} & \frac{2}{5} \\
#             \frac{1}{10} & \frac{3}{20} & -\frac{1}{5}
#           \end{bmatrix}
# \end{align*}

# %% [markdown]
# \begin{align*}
#     A^{-1}b = \begin{bmatrix}
#            -\frac{2}{5} & \frac{9}{10} & -\frac{1}{5} \\
#             \frac{3}{10} & -\frac{11}{20} & \frac{2}{5} \\
#             \frac{1}{10} & \frac{3}{20} & -\frac{1}{5}
#           \end{bmatrix}
#           \times\begin{bmatrix}
#           1 \\
#           2 \\
#           3
#           \end{bmatrix} \quad
#           = \begin{bmatrix}
#           \frac{4}{5} \\
#           \frac{2}{5} \\
#           -\frac{1}{5}
#           \end{bmatrix}
# \end{align*}
