# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.compose import ColumnTransformer
import seaborn as sns
import tqdm

# %matplotlib inline

import time
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error, make_scorer, f1_score


from collections import Counter

from sklearn.model_selection import train_test_split, KFold, GridSearchCV
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler
import shap
import optuna

# imblearn
from imblearn.over_sampling import ADASYN 
from imblearn.pipeline import Pipeline as ImbPipeline

# sklearn
from sklearn.ensemble import RandomForestClassifier

# %%
df_raw = pd.read_csv('survey_results_public.csv')
df_raw
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  Country    US_State  \
# 0                                               Slovakia         NaN
# 1                                            Netherlands         NaN
# 2                                     Russian Federation         NaN
# 3                                                Austria         NaN
# 4      United Kingdom of Great Britain and Northern I...         NaN
# ...                                                  ...         ...
# 83434                           United States of America       Texas
# 83435                                              Benin         NaN
# 83436                           United States of America  New Jersey
# 83437                                             Canada         NaN
# 83438                                             Brazil         NaN
#
#       UK_Country                                            EdLevel  \
# 0            NaN  Secondary school (e.g. American high school, G...
# 1            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3            NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4        England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...          ...                                                ...
# 83434        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436        NaN  Secondary school (e.g. American high school, G...
# 83437        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438        NaN                 Professional degree (JD, MD, etc.)
#
#           Age1stCode                                          LearnCode  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
#
#       YearsCode  ...              Age Gender Trans                Sexuality  \
# 0           NaN  ...  25-34 years old    Man    No  Straight / Heterosexual
# 1             7  ...  18-24 years old    Man    No  Straight / Heterosexual
# 2           NaN  ...  18-24 years old    Man    No        Prefer not to say
# 3           NaN  ...  35-44 years old    Man    No  Straight / Heterosexual
# 4            17  ...  25-34 years old    Man    No                      NaN
# ...         ...  ...              ...    ...   ...                      ...
# 83434         6  ...  25-34 years old    Man    No  Straight / Heterosexual
# 83435         4  ...  18-24 years old    Man    No  Straight / Heterosexual
# 83436        10  ...  25-34 years old    Man    No                      NaN
# 83437         5  ...  25-34 years old    Man    No  Straight / Heterosexual
# 83438        14  ...  18-24 years old    Man    No  Straight / Heterosexual
#
#                           Ethnicity                Accessibility  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MentalHealth  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SurveyLength                  SurveyEase ConvertedCompYearly
# 0      Appropriate in length                        Easy             62268.0
# 1      Appropriate in length                        Easy                 NaN
# 2      Appropriate in length                        Easy                 NaN
# 3      Appropriate in length  Neither easy nor difficult                 NaN
# 4      Appropriate in length                        Easy                 NaN
# ...                      ...                         ...                 ...
# 83434  Appropriate in length                        Easy            160500.0
# 83435  Appropriate in length                        Easy              3960.0
# 83436  Appropriate in length  Neither easy nor difficult             90000.0
# 83437  Appropriate in length  Neither easy nor difficult            816816.0
# 83438  Appropriate in length                        Easy             21168.0
#
# [83439 rows x 48 columns]

# %%
df_raw.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %% [markdown]
# # Cleaning
#
# ## Filtering Asian Countries

# %%
cols_drop = ['US_State', 'UK_Country', 'Age1stCode', 'LearnCode', 'Currency', 
             'CompTotal', 'CompFreq', 'LanguageWantToWorkWith', 
             'DatabaseWantToWorkWith', 'PlatformWantToWorkWith', 'WebframeWantToWorkWith', 
             'WebframeHaveWorkedWith', 'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
             'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith', 
             'NEWCollabToolsWantToWorkWith', 'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 
             'SOAccount', 'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
             'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
             'SurveyEase']

# %%
df_drop = df_raw.drop(columns=cols_drop, axis=0)
df_drop.dropna(inplace=True)
df_drop.Country.unique()
# Out:
# array(['Spain', 'Turkey', 'Canada', 'Germany', 'Israel', 'Brazil',
#        'Greece', 'Russian Federation', 'United States of America',
#        'United Kingdom of Great Britain and Northern Ireland', 'Poland',
#        'Switzerland', 'Hungary', 'Sweden', 'France', 'Nigeria', 'Italy',
#        'Albania', 'Bangladesh', 'Netherlands', 'Romania', 'Sri Lanka',
#        'India', 'Lithuania', 'Ukraine', 'Slovenia', 'Georgia', 'Denmark',
#        'Ireland', 'Egypt', 'Colombia', 'Australia', 'Indonesia',
#        'Iran, Islamic Republic of...', 'Portugal', 'Armenia',
#        'Hong Kong (S.A.R.)', 'Argentina', 'Finland', 'Peru', 'Japan',
#        'Belgium', 'United Arab Emirates', 'Bolivia', 'Austria',
#        'South Africa', 'Pakistan', 'Lebanon', 'Serbia', 'Malta',
#        'Czech Republic', 'Belarus', 'Kenya', 'Malaysia', 'Uruguay',
#        'The former Yugoslav Republic of Macedonia', 'Botswana', 'Algeria',
#        'Norway', 'China', 'Croatia', 'Mexico', 'Jordan', 'Chile',
#        'Luxembourg', 'Uzbekistan', 'Syrian Arab Republic', 'Zambia',
#        'Taiwan', 'Tunisia', 'South Korea', 'Dominican Republic',
#        'Paraguay', 'Iceland', 'Morocco', 'Viet Nam', 'Guatemala',
#        'Cameroon', 'Venezuela, Bolivarian Republic of...', 'Bulgaria',
#        'Panama', 'Ethiopia', 'Cuba', "Lao People's Democratic Republic",
#        'Thailand', 'Latvia', 'Republic of Moldova',
#        'Democratic Republic of the Congo', 'Nepal', 'Somalia', 'Iraq',
#        'Philippines', 'Costa Rica', 'Ecuador', 'Azerbaijan',
#        'Saudi Arabia', 'Honduras', 'Angola', 'Singapore',
#        'Bosnia and Herzegovina', 'United Republic of Tanzania',
#        'El Salvador', 'Kosovo', 'Slovakia', 'New Zealand', 'Dominica',
#        'Nomadic', 'Cyprus', 'Trinidad and Tobago', 'Estonia', 'Kuwait',
#        'Ghana', 'Congo, Republic of the...', 'Nicaragua', 'Myanmar',
#        'Kazakhstan', 'Cambodia', 'Uganda', 'Kyrgyzstan', 'Swaziland',
#        'Monaco', 'Afghanistan', 'Bahrain', 'Sudan', 'Montenegro',
#        'Mauritius', 'Isle of Man', 'Qatar', 'Haiti', 'Benin',
#        'Madagascar', 'Bhutan', 'Republic of Korea', 'Mongolia',
#        'Tajikistan', 'Rwanda', 'Cape Verde', 'Oman', 'Guyana', 'Namibia',
#        'Palestine', "Côte d'Ivoire", 'Togo', 'Lesotho', 'Guinea',
#        'Senegal', 'Jamaica', 'Liberia', 'Andorra', 'Suriname', 'Niger',
#        'Maldives', 'Saint Lucia', 'Zimbabwe', 'Malawi', 'Mozambique',
#        'Saint Vincent and the Grenadines', 'Barbados', 'Gambia', 'Belize',
#        'Burkina Faso', 'Mauritania', 'Burundi', 'Turkmenistan',
#        'Libyan Arab Jamahiriya', 'Yemen'], dtype=object)

# %%
asian_countries = ['Russian Federation', 'India', 'Indonesia', 'Iran', 'Sri Lanka',
                   'Georgia', 'Hong Kong (S.A.R.)', 'Japan', 'United Arab Emirates', 
                   'Turkey', 'Pakistan', 'Lebanon', 'Malaysia', 'China', 'Jordan', 'Uzbekistan', 
                   'Syrian Arab Republic', 'Taiwan', 'South Korea', 'Viet Nam', 
                   "Lao People's Democratic Republic", 'Nepal', 'Philippines', 'Azerbaijan', 
                   'Saudi Arabia', 'Singapore', 'Armenia', 'Cyprus', 'Kuwait', 'Thailand', 
                   'Myanmar', 'Kazakhstan', 'Iraq', 'Bahrain', 'Cambodia', 'Bhutan', 'Kyrgyzstan', 
                   'Republic of Korea', 'Tajikistan', 'Oman', 'Palestine', 'Afghanistan', 'Mongolia', 'Maldives',
                   'Qatar', 'Turkmenistan'
                  ]
df_asia = df_drop[df_drop['Country'].isin(asian_countries)]
df_asia
# Out:
#        ResponseId                                         MainBranch  \
# 16             17                     I am a developer by profession
# 58             59  I am not primarily a developer, but I write co...
# 148           149  I am not primarily a developer, but I write co...
# 154           155                     I am a developer by profession
# 168           169                     I am a developer by profession
# ...           ...                                                ...
# 83355       83356                     I am a developer by profession
# 83356       83357                     I am a developer by profession
# 83402       83403                     I am a developer by profession
# 83411       83412                     I am a developer by profession
# 83431       83432                     I am a developer by profession
#
#                                               Employment             Country  \
# 16                                    Employed full-time              Turkey
# 58                                    Employed full-time  Russian Federation
# 148    Independent contractor, freelancer, or self-em...           Sri Lanka
# 154    Independent contractor, freelancer, or self-em...               India
# 168    Independent contractor, freelancer, or self-em...             Georgia
# ...                                                  ...                 ...
# 83355                                 Employed full-time               Japan
# 83356  Independent contractor, freelancer, or self-em...           Indonesia
# 83402                                 Employed full-time         South Korea
# 83411                                 Employed full-time               India
# 83431  Independent contractor, freelancer, or self-em...            Pakistan
#
#                                                  EdLevel YearsCode  \
# 16          Bachelor’s degree (B.A., B.S., B.Eng., etc.)         6
# 58                    Professional degree (JD, MD, etc.)         5
# 148      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)         2
# 154         Bachelor’s degree (B.A., B.S., B.Eng., etc.)        20
# 168    Some college/university study without earning ...         4
# ...                                                  ...       ...
# 83355       Bachelor’s degree (B.A., B.S., B.Eng., etc.)         8
# 83356       Bachelor’s degree (B.A., B.S., B.Eng., etc.)        11
# 83402  Secondary school (e.g. American high school, G...         4
# 83411       Bachelor’s degree (B.A., B.S., B.Eng., etc.)         8
# 83431       Bachelor’s degree (B.A., B.S., B.Eng., etc.)         9
#
#            YearsCodePro                                            DevType  \
# 16                    2                              Developer, full-stack
# 58                    3  Developer, full-stack;Data scientist or machin...
# 148                   2    Database administrator;Data or business analyst
# 154                   7  Developer, front-end;Developer, full-stack;Dev...
# 168                   2  Developer, front-end;Engineer, data;Developer,...
# ...                 ...                                                ...
# 83355                 3  Developer, front-end;Developer, desktop or ent...
# 83356                 5  Developer, mobile;Developer, front-end;Develop...
# 83402  Less than 1 year  Developer, mobile;Developer, front-end;Develop...
# 83411                 5                                Developer, back-end
# 83431                 4  Developer, mobile;Developer, desktop or enterp...
#
#                                                  OrgSize  \
# 16                                  100 to 499 employees
# 58                                    20 to 99 employees
# 148    Just me - I am a freelancer, sole proprietor, ...
# 154    Just me - I am a freelancer, sole proprietor, ...
# 168    Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 83355                                 20 to 99 employees
# 83356  Just me - I am a freelancer, sole proprietor, ...
# 83402                                   2 to 9 employees
# 83411                               100 to 499 employees
# 83431                                   2 to 9 employees
#
#                                   LanguageHaveWorkedWith  \
# 16                   C#;HTML/CSS;Java;JavaScript;Node.js
# 58             Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 148                                                  SQL
# 154    HTML/CSS;JavaScript;Node.js;PHP;PowerShell;Pyt...
# 168                       HTML/CSS;JavaScript;Python;SQL
# ...                                                  ...
# 83355              C#;HTML/CSS;JavaScript;SQL;TypeScript
# 83356  Bash/Shell;C;C#;C++;Dart;Go;Java;JavaScript;Ju...
# 83402     C;Dart;HTML/CSS;Java;JavaScript;Kotlin;Node.js
# 83411                                Java;JavaScript;SQL
# 83431  C#;Dart;HTML/CSS;Java;JavaScript;Kotlin;Node.j...
#
#                                   DatabaseHaveWorkedWith  \
# 16               Microsoft SQL Server;MongoDB;PostgreSQL
# 58                                                Oracle
# 148                                               SQLite
# 154                 Firebase;MariaDB;MongoDB;MySQL;Redis
# 168                                               SQLite
# ...                                                  ...
# 83355                               Microsoft SQL Server
# 83356  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83402              Firebase;MariaDB;MongoDB;MySQL;Oracle
# 83411                                              MySQL
# 83431                              Firebase;MySQL;SQLite
#
#                                   PlatformHaveWorkedWith  \
# 16                             AWS;Google Cloud Platform
# 58                                                Heroku
# 148                                Google Cloud Platform
# 154                                               Heroku
# 168                                  DigitalOcean;Heroku
# ...                                                  ...
# 83355                                                AWS
# 83356  AWS;DigitalOcean;Google Cloud Platform;Heroku;...
# 83402                                         AWS;Heroku
# 83411                                                AWS
# 83431                              Google Cloud Platform
#
#                                    OpSys  \
# 16                               Windows
# 58                           Linux-based
# 148                              Windows
# 154                              Windows
# 168                          Linux-based
# ...                                  ...
# 83355                            Windows
# 83356  Windows Subsystem for Linux (WSL)
# 83402                              MacOS
# 83411                              MacOS
# 83431                            Windows
#
#                                               SOPartFreq  ConvertedCompYearly
# 16                                Multiple times per day              17748.0
# 58                   Less than once per month or monthly              22644.0
# 148                               Multiple times per day              36000.0
# 154                                Daily or almost daily               2340.0
# 168                                Daily or almost daily              14844.0
# ...                                                  ...                  ...
# 83355                Less than once per month or monthly                450.0
# 83356  I have never participated in Q&A on Stack Over...               7020.0
# 83402  I have never participated in Q&A on Stack Over...              18708.0
# 83411                Less than once per month or monthly              48866.0
# 83431                    A few times per month or weekly              11676.0
#
# [5090 rows x 15 columns]

# %%
df_asia.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'EdLevel',
#        'YearsCode', 'YearsCodePro', 'DevType', 'OrgSize',
#        'LanguageHaveWorkedWith', 'DatabaseHaveWorkedWith',
#        'PlatformHaveWorkedWith', 'OpSys', 'SOPartFreq', 'ConvertedCompYearly'],
#       dtype='object')

# %%
# OHE_list = []
# ordinal_list = []
# for col in df_asia.columns:
#     print(col, '\n--------------')
#     display(df_asia[col].unique())
#     ans = input('action')
#     if ans == 'cat':
#         OHE_list.append(col)
#     elif ans == 'ord':
#         ordinal_list.append(col)

# %%
OHE_list = ['Employment', 'Country', 'OpSys']

# %%
ordinal_list = ['MainBranch', 'EdLevel', 'OrgSize', 'SOPartFreq']

# %% [markdown]
# **Columns that need transformation**

# %%
df_asia[df_asia.columns.difference(OHE_list+ordinal_list)].head()
# Out:
#      ConvertedCompYearly                   DatabaseHaveWorkedWith  \
# 16               17748.0  Microsoft SQL Server;MongoDB;PostgreSQL
# 58               22644.0                                   Oracle
# 148              36000.0                                   SQLite
# 154               2340.0     Firebase;MariaDB;MongoDB;MySQL;Redis
# 168              14844.0                                   SQLite
#
#                                                DevType  \
# 16                               Developer, full-stack
# 58   Developer, full-stack;Data scientist or machin...
# 148    Database administrator;Data or business analyst
# 154  Developer, front-end;Developer, full-stack;Dev...
# 168  Developer, front-end;Engineer, data;Developer,...
#
#                                 LanguageHaveWorkedWith  \
# 16                 C#;HTML/CSS;Java;JavaScript;Node.js
# 58           Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 148                                                SQL
# 154  HTML/CSS;JavaScript;Node.js;PHP;PowerShell;Pyt...
# 168                     HTML/CSS;JavaScript;Python;SQL
#
#         PlatformHaveWorkedWith  ResponseId YearsCode YearsCodePro
# 16   AWS;Google Cloud Platform          17         6            2
# 58                      Heroku          59         5            3
# 148      Google Cloud Platform         149         2            2
# 154                     Heroku         155        20            7
# 168        DigitalOcean;Heroku         169         4            2

# %% [markdown]
# ## Prepping Features with top X filtering

# %%
def OHE_semicolon_vals(col_name, top_vals, prefix):
    li = []
    for row in df_asia[col_name].str.split(';'):
         li = li + row

    df_try = df_asia[col_name].copy().to_frame()
    top_12_lang = pd.Series(li).value_counts()[:top_vals].index
    # display(top_12_lang)
    
    df_out = df_try.copy()
    df_out.reset_index(inplace=True)
    for lang in top_12_lang:
        df_out[f'{prefix}_'+lang] = 0
    
    for idx, elem in enumerate(df_try.iloc[:,0].str.split(';')):
        for lang in top_12_lang:
            if lang in elem:
                df_out.loc[idx, f'{prefix}_' + lang] = 1 
    return df_out.set_index('index').drop(columns=col_name, axis=0)

# %%
lang_OHE = OHE_semicolon_vals('LanguageHaveWorkedWith', 12, 'Lang')
lang_OHE
# Out:
#        Lang_JavaScript  Lang_HTML/CSS  Lang_SQL  Lang_Python  Lang_Node.js  \
# index
# 16                   1              1         0            0             1
# 58                   1              1         1            1             0
# 148                  0              0         1            0             0
# 154                  1              1         1            1             1
# 168                  1              1         1            1             0
# ...                ...            ...       ...          ...           ...
# 83355                1              1         1            0             0
# 83356                1              0         1            1             1
# 83402                1              1         0            0             1
# 83411                1              0         1            0             0
# 83431                1              1         1            1             1
#
#        Lang_Java  Lang_TypeScript  Lang_PHP  Lang_C#  Lang_C++  \
# index
# 16             1                0         0        1         0
# 58             0                0         0        0         0
# 148            0                0         0        0         0
# 154            0                0         1        0         0
# 168            0                0         0        0         0
# ...          ...              ...       ...      ...       ...
# 83355          0                1         0        1         0
# 83356          1                1         1        1         1
# 83402          1                0         0        0         0
# 83411          1                0         0        0         0
# 83431          1                1         1        1         0
#
#        Lang_Bash/Shell  Lang_C
# index
# 16                   0       0
# 58                   1       0
# 148                  0       0
# 154                  0       0
# 168                  0       0
# ...                ...     ...
# 83355                0       0
# 83356                1       1
# 83402                0       1
# 83411                0       0
# 83431                0       0
#
# [5090 rows x 12 columns]

# %%
devtype_OHE = OHE_semicolon_vals('DevType', 10, 'Dev')
devtype_OHE
# Out:
#        Dev_Developer, full-stack  Dev_Developer, back-end  \
# index
# 16                             1                        0
# 58                             1                        0
# 148                            0                        0
# 154                            1                        1
# 168                            0                        1
# ...                          ...                      ...
# 83355                          1                        1
# 83356                          1                        1
# 83402                          0                        0
# 83411                          0                        1
# 83431                          0                        1
#
#        Dev_Developer, front-end  Dev_Developer, mobile  \
# index
# 16                            0                      0
# 58                            0                      0
# 148                           0                      0
# 154                           1                      0
# 168                           1                      0
# ...                         ...                    ...
# 83355                         1                      0
# 83356                         1                      1
# 83402                         1                      1
# 83411                         0                      0
# 83431                         0                      1
#
#        Dev_Developer, desktop or enterprise applications  \
# index
# 16                                                     0
# 58                                                     0
# 148                                                    0
# 154                                                    0
# 168                                                    0
# ...                                                  ...
# 83355                                                  1
# 83356                                                  1
# 83402                                                  1
# 83411                                                  0
# 83431                                                  1
#
#        Dev_DevOps specialist  Dev_Database administrator  \
# index
# 16                         0                           0
# 58                         0                           0
# 148                        0                           1
# 154                        1                           1
# 168                        0                           0
# ...                      ...                         ...
# 83355                      0                           0
# 83356                      0                           1
# 83402                      0                           0
# 83411                      0                           0
# 83431                      0                           0
#
#        Dev_System administrator  Dev_Engineer, data  \
# index
# 16                            0                   0
# 58                            0                   0
# 148                           0                   0
# 154                           1                   0
# 168                           0                   1
# ...                         ...                 ...
# 83355                         0                   0
# 83356                         1                   1
# 83402                         0                   0
# 83411                         0                   0
# 83431                         0                   0
#
#        Dev_Data scientist or machine learning specialist
# index
# 16                                                     0
# 58                                                     1
# 148                                                    0
# 154                                                    0
# 168                                                    0
# ...                                                  ...
# 83355                                                  0
# 83356                                                  1
# 83402                                                  0
# 83411                                                  0
# 83431                                                  1
#
# [5090 rows x 10 columns]

# %%
database_OHE = OHE_semicolon_vals('DatabaseHaveWorkedWith', 10, 'DB')
database_OHE
# Out:
#        DB_MySQL  DB_PostgreSQL  DB_MongoDB  DB_SQLite  DB_Redis  \
# index
# 16            0              1           1          0         0
# 58            0              0           0          0         0
# 148           0              0           0          1         0
# 154           1              0           1          0         1
# 168           0              0           0          1         0
# ...         ...            ...         ...        ...       ...
# 83355         0              0           0          0         0
# 83356         1              1           1          1         1
# 83402         1              0           1          0         0
# 83411         1              0           0          0         0
# 83431         1              0           0          1         0
#
#        DB_Microsoft SQL Server  DB_Firebase  DB_Elasticsearch  DB_MariaDB  \
# index
# 16                           1            0                 0           0
# 58                           0            0                 0           0
# 148                          0            0                 0           0
# 154                          0            1                 0           1
# 168                          0            0                 0           0
# ...                        ...          ...               ...         ...
# 83355                        1            0                 0           0
# 83356                        0            1                 0           1
# 83402                        0            1                 0           1
# 83411                        0            0                 0           0
# 83431                        0            1                 0           0
#
#        DB_Oracle
# index
# 16             0
# 58             1
# 148            0
# 154            0
# 168            0
# ...          ...
# 83355          0
# 83356          0
# 83402          1
# 83411          0
# 83431          0
#
# [5090 rows x 10 columns]

# %%
# PlatformHaveWorkedWith
platform_OHE = OHE_semicolon_vals('PlatformHaveWorkedWith', 10, 'Plat')
platform_OHE
# Out:
#        Plat_AWS  Plat_Google Cloud Platform  Plat_Microsoft Azure  \
# index
# 16            1                           1                     0
# 58            0                           0                     0
# 148           0                           1                     0
# 154           0                           0                     0
# 168           0                           0                     0
# ...         ...                         ...                   ...
# 83355         1                           0                     0
# 83356         1                           1                     1
# 83402         1                           0                     0
# 83411         1                           0                     0
# 83431         0                           1                     0
#
#        Plat_Heroku  Plat_DigitalOcean  Plat_IBM Cloud or Watson  \
# index
# 16               0                  0                         0
# 58               1                  0                         0
# 148              0                  0                         0
# 154              1                  0                         0
# 168              1                  1                         0
# ...            ...                ...                       ...
# 83355            0                  0                         0
# 83356            1                  1                         1
# 83402            1                  0                         0
# 83411            0                  0                         0
# 83431            0                  0                         0
#
#        Plat_Oracle Cloud Infrastructure
# index
# 16                                    0
# 58                                    0
# 148                                   0
# 154                                   0
# 168                                   0
# ...                                 ...
# 83355                                 0
# 83356                                 0
# 83402                                 0
# 83411                                 0
# 83431                                 0
#
# [5090 rows x 7 columns]

# %% [markdown]
# Changing `YearsCode` and `YearsCodeProd` to numeric

# %%
#YearsCode
df_asia['YearsCode'] = df_asia['YearsCode'].copy().apply(lambda x: 0.5 if x == 'Less than 1 year' else int(x))
#YearsCodePro
df_asia['YearsCodePro'] = df_asia['YearsCodePro'].copy().apply(lambda x: 0.5 if x == 'Less than 1 year' else int(x))
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## Ordinal Mapping

# %%
df_asia['MainBranch'].unique()
MainBranch_mapping = {'I am not primarily a developer, but I write code sometimes as part of my work': 0, 
                      'I am a developer by profession': 1}
df_asia['MainBranch'] = df_asia['MainBranch'].copy().map(MainBranch_mapping)
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# EdLevel
EdLevel_mapping = {'Something else':0, 
                   'Primary/elementary school': 1, 
                   'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)': 2, 
                   'Some college/university study without earning a degree': 3,
                   'Associate degree (A.A., A.S., etc.)':4,
                   'Bachelor’s degree (B.A., B.S., B.Eng., etc.)': 5, 
                   'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)':6, 
                   'Other doctoral degree (Ph.D., Ed.D., etc.)':7, 
                   'Professional degree (JD, MD, etc.)':8}

df_asia['EdLevel'] = df_asia['EdLevel'].copy().map(EdLevel_mapping)
# df_asia
# df_asia['EdLevel']
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
OrgSize_mapping = {
    'I don’t know':0,
    'Just me - I am a freelancer, sole proprietor, etc.':1,
    '2 to 9 employees':2,
    '10 to 19 employees':3,
    '20 to 99 employees':4,
    '100 to 499 employees':5,
    '500 to 999 employees':6,
    '1,000 to 4,999 employees':7,
    '5,000 to 9,999 employees':8,
    '10,000 or more employees':9
}

df_asia['OrgSize'] = df_asia['OrgSize'].copy().map(OrgSize_mapping)
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_asia['SOPartFreq'].unique()

SOPartFreq_mapping = {
    'I have never participated in Q&A on Stack Overflow': 0,
    'Less than once per month or monthly':1,
    'A few times per month or weekly':2,
    'A few times per week':3,
    'Daily or almost daily':4,
    'Multiple times per day':5
}
df_asia['SOPartFreq'] = df_asia['SOPartFreq'].copy().map(SOPartFreq_mapping)
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_asia[ordinal_list]
# Out:
#        MainBranch  EdLevel  OrgSize  SOPartFreq
# 16              1        5        5           5
# 58              0        8        4           1
# 148             0        6        1           5
# 154             1        5        1           4
# 168             1        3        1           4
# ...           ...      ...      ...         ...
# 83355           1        5        4           1
# 83356           1        5        1           0
# 83402           1        2        2           0
# 83411           1        5        5           1
# 83431           1        5        2           2
#
# [5090 rows x 4 columns]

# %% [markdown]
# ## OHE

# %%
df_asia[OHE_list]
# Out:
#                                               Employment             Country  \
# 16                                    Employed full-time              Turkey
# 58                                    Employed full-time  Russian Federation
# 148    Independent contractor, freelancer, or self-em...           Sri Lanka
# 154    Independent contractor, freelancer, or self-em...               India
# 168    Independent contractor, freelancer, or self-em...             Georgia
# ...                                                  ...                 ...
# 83355                                 Employed full-time               Japan
# 83356  Independent contractor, freelancer, or self-em...           Indonesia
# 83402                                 Employed full-time         South Korea
# 83411                                 Employed full-time               India
# 83431  Independent contractor, freelancer, or self-em...            Pakistan
#
#                                    OpSys
# 16                               Windows
# 58                           Linux-based
# 148                              Windows
# 154                              Windows
# 168                          Linux-based
# ...                                  ...
# 83355                            Windows
# 83356  Windows Subsystem for Linux (WSL)
# 83402                              MacOS
# 83411                              MacOS
# 83431                            Windows
#
# [5090 rows x 3 columns]

# %%
df_asia['ConvertedCompYearly'] = df_asia['ConvertedCompYearly'].astype(int)
numeric_data = df_asia.select_dtypes(['int', 'float'])
numeric_data.index.name='index'
numeric_data
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        ResponseId  MainBranch  EdLevel  YearsCode  YearsCodePro  OrgSize  \
# index
# 16             17           1        5        6.0           2.0        5
# 58             59           0        8        5.0           3.0        4
# 148           149           0        6        2.0           2.0        1
# 154           155           1        5       20.0           7.0        1
# 168           169           1        3        4.0           2.0        1
# ...           ...         ...      ...        ...           ...      ...
# 83355       83356           1        5        8.0           3.0        4
# 83356       83357           1        5       11.0           5.0        1
# 83402       83403           1        2        4.0           0.5        2
# 83411       83412           1        5        8.0           5.0        5
# 83431       83432           1        5        9.0           4.0        2
#
#        SOPartFreq  ConvertedCompYearly
# index
# 16              5                17748
# 58              1                22644
# 148             5                36000
# 154             4                 2340
# 168             4                14844
# ...           ...                  ...
# 83355           1                  450
# 83356           0                 7020
# 83402           0                18708
# 83411           1                48866
# 83431           2                11676
#
# [5090 rows x 8 columns]

# %%
OHE_data = pd.concat([lang_OHE,database_OHE, devtype_OHE, platform_OHE, pd.get_dummies(df_asia[OHE_list])], axis=1)
df_final = pd.merge(left=numeric_data, right=OHE_data, left_index=True, right_index=True)
df_final
# Out:
#        ResponseId  MainBranch  EdLevel  YearsCode  YearsCodePro  OrgSize  \
# index
# 16             17           1        5        6.0           2.0        5
# 58             59           0        8        5.0           3.0        4
# 148           149           0        6        2.0           2.0        1
# 154           155           1        5       20.0           7.0        1
# 168           169           1        3        4.0           2.0        1
# ...           ...         ...      ...        ...           ...      ...
# 83355       83356           1        5        8.0           3.0        4
# 83356       83357           1        5       11.0           5.0        1
# 83402       83403           1        2        4.0           0.5        2
# 83411       83412           1        5        8.0           5.0        5
# 83431       83432           1        5        9.0           4.0        2
#
#        SOPartFreq  ConvertedCompYearly  Lang_JavaScript  Lang_HTML/CSS  ...  \
# index                                                                   ...
# 16              5                17748                1              1  ...
# 58              1                22644                1              1  ...
# 148             5                36000                0              0  ...
# 154             4                 2340                1              1  ...
# 168             4                14844                1              1  ...
# ...           ...                  ...              ...            ...  ...
# 83355           1                  450                1              1  ...
# 83356           0                 7020                1              0  ...
# 83402           0                18708                1              1  ...
# 83411           1                48866                1              0  ...
# 83431           2                11676                1              1  ...
#
#        Country_Turkmenistan  Country_United Arab Emirates  Country_Uzbekistan  \
# index
# 16                        0                             0                   0
# 58                        0                             0                   0
# 148                       0                             0                   0
# 154                       0                             0                   0
# 168                       0                             0                   0
# ...                     ...                           ...                 ...
# 83355                     0                             0                   0
# 83356                     0                             0                   0
# 83402                     0                             0                   0
# 83411                     0                             0                   0
# 83431                     0                             0                   0
#
#        Country_Viet Nam  OpSys_BSD  OpSys_Linux-based  OpSys_MacOS  \
# index
# 16                    0          0                  0            0
# 58                    0          0                  1            0
# 148                   0          0                  0            0
# 154                   0          0                  0            0
# 168                   0          0                  1            0
# ...                 ...        ...                ...          ...
# 83355                 0          0                  0            0
# 83356                 0          0                  0            0
# 83402                 0          0                  0            1
# 83411                 0          0                  0            1
# 83431                 0          0                  0            0
#
#        OpSys_Other (please specify):  OpSys_Windows  \
# index
# 16                                 0              1
# 58                                 0              0
# 148                                0              1
# 154                                0              1
# 168                                0              0
# ...                              ...            ...
# 83355                              0              1
# 83356                              0              0
# 83402                              0              0
# 83411                              0              0
# 83431                              0              1
#
#        OpSys_Windows Subsystem for Linux (WSL)
# index
# 16                                           0
# 58                                           0
# 148                                          0
# 154                                          0
# 168                                          0
# ...                                        ...
# 83355                                        0
# 83356                                        1
# 83402                                        0
# 83411                                        0
# 83431                                        0
#
# [5090 rows x 101 columns]

# %% [markdown]
# PH Salary grade basis https://filipiknow.net/salary-grade/

# %%
def salary_banding(x):
    php_to_usd = 50.34 # as of nov 25 2021
    salary_grade_thresh = {
        1: 23877*12/php_to_usd,
        2: 68415*12/php_to_usd,
        3: 403620*12/php_to_usd,
    }
    if (x < salary_grade_thresh[1]):
        return 0
    elif (salary_grade_thresh[1] <= x < salary_grade_thresh[2]):
        return 1
    elif salary_grade_thresh[2] <= x < salary_grade_thresh[3]:
        return 2
    elif salary_grade_thresh[3] <= x :
        return 3
    
salary_banding(17748)
# Out:
# 2

# %%
df_final['ConvertedCompYearly'] = df_final['ConvertedCompYearly'].copy().apply(salary_banding)

# %%
df_final
# Out:
#        ResponseId  MainBranch  EdLevel  YearsCode  YearsCodePro  OrgSize  \
# index
# 16             17           1        5        6.0           2.0        5
# 58             59           0        8        5.0           3.0        4
# 148           149           0        6        2.0           2.0        1
# 154           155           1        5       20.0           7.0        1
# 168           169           1        3        4.0           2.0        1
# ...           ...         ...      ...        ...           ...      ...
# 83355       83356           1        5        8.0           3.0        4
# 83356       83357           1        5       11.0           5.0        1
# 83402       83403           1        2        4.0           0.5        2
# 83411       83412           1        5        8.0           5.0        5
# 83431       83432           1        5        9.0           4.0        2
#
#        SOPartFreq  ConvertedCompYearly  Lang_JavaScript  Lang_HTML/CSS  ...  \
# index                                                                   ...
# 16              5                    2                1              1  ...
# 58              1                    2                1              1  ...
# 148             5                    2                0              0  ...
# 154             4                    0                1              1  ...
# 168             4                    1                1              1  ...
# ...           ...                  ...              ...            ...  ...
# 83355           1                    0                1              1  ...
# 83356           0                    1                1              0  ...
# 83402           0                    2                1              1  ...
# 83411           1                    2                1              0  ...
# 83431           2                    1                1              1  ...
#
#        Country_Turkmenistan  Country_United Arab Emirates  Country_Uzbekistan  \
# index
# 16                        0                             0                   0
# 58                        0                             0                   0
# 148                       0                             0                   0
# 154                       0                             0                   0
# 168                       0                             0                   0
# ...                     ...                           ...                 ...
# 83355                     0                             0                   0
# 83356                     0                             0                   0
# 83402                     0                             0                   0
# 83411                     0                             0                   0
# 83431                     0                             0                   0
#
#        Country_Viet Nam  OpSys_BSD  OpSys_Linux-based  OpSys_MacOS  \
# index
# 16                    0          0                  0            0
# 58                    0          0                  1            0
# 148                   0          0                  0            0
# 154                   0          0                  0            0
# 168                   0          0                  1            0
# ...                 ...        ...                ...          ...
# 83355                 0          0                  0            0
# 83356                 0          0                  0            0
# 83402                 0          0                  0            1
# 83411                 0          0                  0            1
# 83431                 0          0                  0            0
#
#        OpSys_Other (please specify):  OpSys_Windows  \
# index
# 16                                 0              1
# 58                                 0              0
# 148                                0              1
# 154                                0              1
# 168                                0              0
# ...                              ...            ...
# 83355                              0              1
# 83356                              0              0
# 83402                              0              0
# 83411                              0              0
# 83431                              0              1
#
#        OpSys_Windows Subsystem for Linux (WSL)
# index
# 16                                           0
# 58                                           0
# 148                                          0
# 154                                          0
# 168                                          0
# ...                                        ...
# 83355                                        0
# 83356                                        1
# 83402                                        0
# 83411                                        0
# 83431                                        0
#
# [5090 rows x 101 columns]

# %% [markdown]
# # EDA

# %%
sns.pairplot(data=df_final[['EdLevel', 'YearsCode', 'YearsCodePro', 'OrgSize', 'SOPartFreq', 'ConvertedCompYearly']], diag_kind='hist')
plt.show()

# %%
df_final['ConvertedCompYearly'].value_counts().sort_index().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(15,7))
sns.boxplot(df_final['ConvertedCompYearly'])
# Out:
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='ConvertedCompYearly'>

# %%
# df_final[df_final['ConvertedCompYearly']>2000]

# %% [markdown]
# # ML

# %%
X = df_final[df_final.columns.difference(['ConvertedCompYearly', 'ResponseId'])]
y = df_final['ConvertedCompYearly']

# %% [markdown]
# ## Train-Test Split

# %%
(X_trainval, X_holdout, y_trainval, y_holdout) = train_test_split(X, y, 
                                           random_state=11, test_size=0.25, stratify=y)

# %% [markdown]
# ## CV

# %%
def tune_RF(X, y, n_trials):
    # from optuna.samplers import RandomSampler
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.model_selection import cross_validate
    
    def optimize(trial):
        # Definition of space search
        n_estimators = trial.suggest_int('n_estimators', 10,500, step=10)
        max_depth = trial.suggest_int('max_depth', 2,15)
        max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2'])
        
        # Classifier definition
        model = RandomForestClassifier(n_estimators=n_estimators,
                                       max_depth=max_depth,
                                       max_features=max_features)
        scaler = MinMaxScaler()
        resampler = ADASYN()
        rf_pipe = ImbPipeline(steps = [['scale', scaler], ['resample', resampler], ['rf', model]])
        
        cr_val = cross_val_score(rf_pipe, X, y, cv=5, scoring=make_scorer(f1_score, average='weighted'))
        # cr_val = cross_val_score(model, X, y, cv=5, scoring='r2')
        return np.mean(cr_val)
    
    study = optuna.create_study(direction='maximize')
    study.optimize(optimize, n_trials=n_trials, n_jobs=4)
    return study, optimize

# %%
rf_study, rf_optimize = tune_RF(X_trainval, y_trainval)
# Out:
# [I 2021-11-25 20:19:25,561] A new study created in memory with name: no-name-c490011c-a26e-4701-a6ed-c22b0c00725e
# `n_jobs` argument has been deprecated in v2.7.0. This feature will be removed in v4.0.0. See https://github.com/optuna/optuna/releases/tag/v2.7.0.
# [I 2021-11-25 20:19:27,711] Trial 0 finished with value: 0.5463150737985691 and parameters: {'n_estimators': 10, 'max_depth': 11, 'max_features': 'log2'}. Best is trial 0 with value: 0.5463150737985691.
# [I 2021-11-25 20:19:38,251] Trial 3 finished with value: 0.5688962765221646 and parameters: {'n_estimators': 230, 'max_depth': 6, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.5688962765221646.
# [I 2021-11-25 20:19:38,966] Trial 1 finished with value: 0.6084718858423789 and parameters: {'n_estimators': 140, 'max_depth': 15, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6084718858423789.
# [I 2021-11-25 20:19:39,657] Trial 2 finished with value: 0.60860340455209 and parameters: {'n_estimators': 160, 'max_depth': 13, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.60860340455209.
# [I 2021-11-25 20:19:43,316] Trial 4 finished with value: 0.6083586396112606 and parameters: {'n_estimators': 220, 'max_depth': 13, 'max_features': 'log2'}. Best is trial 2 with value: 0.60860340455209.
# [I 2021-11-25 20:19:45,401] Trial 8 finished with value: 0.42903038108327307 and parameters: {'n_estimators': 10, 'max_depth': 3, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.60860340455209.
# [I 2021-11-25 20:19:46,479] Trial 5 finished with value: 0.5767359185459268 and parameters: {'n_estimators': 110, 'max_depth': 7, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.60860340455209.
# [I 2021-11-25 20:19:49,724] Trial 7 finished with value: 0.5118670035707844 and parameters: {'n_estimators': 250, 'max_depth': 4, 'max_features': 'log2'}. Best is trial 2 with value: 0.60860340455209.
# [I 2021-11-25 20:20:06,615] Trial 10 finished with value: 0.5718608332115636 and parameters: {'n_estimators': 390, 'max_depth': 6, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.60860340455209.
# [I 2021-11-25 20:20:07,473] Trial 9 finished with value: 0.5914273746630976 and parameters: {'n_estimators': 360, 'max_depth': 8, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.60860340455209.
# [I 2021-11-25 20:20:16,387] Trial 6 finished with value: 0.6134233996451888 and parameters: {'n_estimators': 470, 'max_depth': 12, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.6134233996451888.
# [I 2021-11-25 20:20:20,232] Trial 11 finished with value: 0.6094830116453906 and parameters: {'n_estimators': 470, 'max_depth': 13, 'max_features': 'log2'}. Best is trial 6 with value: 0.6134233996451888.
# [I 2021-11-25 20:20:31,318] Trial 12 finished with value: 0.590896979698304 and parameters: {'n_estimators': 410, 'max_depth': 8, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.6134233996451888.
# [I 2021-11-25 20:20:34,090] Trial 13 finished with value: 0.6063917477664594 and parameters: {'n_estimators': 440, 'max_depth': 11, 'max_features': 'log2'}. Best is trial 6 with value: 0.6134233996451888.
# [I 2021-11-25 20:20:49,315] Trial 15 finished with value: 0.60477618492412 and parameters: {'n_estimators': 490, 'max_depth': 10, 'max_features': 'log2'}. Best is trial 6 with value: 0.6134233996451888.
# [I 2021-11-25 20:20:53,180] Trial 14 finished with value: 0.6039016206386831 and parameters: {'n_estimators': 500, 'max_depth': 11, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.6134233996451888.
# [I 2021-11-25 20:21:01,693] Trial 16 finished with value: 0.6093807726370863 and parameters: {'n_estimators': 490, 'max_depth': 11, 'max_features': 'log2'}. Best is trial 6 with value: 0.6134233996451888.
# [I 2021-11-25 20:21:03,779] Trial 17 finished with value: 0.6069084527970136 and parameters: {'n_estimators': 480, 'max_depth': 11, 'max_features': 'log2'}. Best is trial 6 with value: 0.6134233996451888.
# [I 2021-11-25 20:21:13,961] Trial 18 finished with value: 0.6084489430713794 and parameters: {'n_estimators': 320, 'max_depth': 15, 'max_features': 'log2'}. Best is trial 6 with value: 0.6134233996451888.
# [I 2021-11-25 20:21:16,615] Trial 19 finished with value: 0.6102889344651402 and parameters: {'n_estimators': 310, 'max_depth': 15, 'max_features': 'log2'}. Best is trial 6 with value: 0.6134233996451888.
# [I 2021-11-25 20:21:27,118] Trial 20 finished with value: 0.6129397821471908 and parameters: {'n_estimators': 340, 'max_depth': 15, 'max_features': 'log2'}. Best is trial 6 with value: 0.6134233996451888.
# [I 2021-11-25 20:21:28,539] Trial 21 finished with value: 0.6089345962564303 and parameters: {'n_estimators': 340, 'max_depth': 15, 'max_features': 'log2'}. Best is trial 6 with value: 0.6134233996451888.
# [I 2021-11-25 20:21:34,757] Trial 22 finished with value: 0.6106896432696731 and parameters: {'n_estimators': 320, 'max_depth': 13, 'max_features': 'log2'}. Best is trial 6 with value: 0.6134233996451888.
# [I 2021-11-25 20:21:42,538] Trial 23 finished with value: 0.6096566003925447 and parameters: {'n_estimators': 320, 'max_depth': 14, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.6134233996451888.
# [I 2021-11-25 20:21:48,772] Trial 24 finished with value: 0.6136762708388165 and parameters: {'n_estimators': 310, 'max_depth': 14, 'max_features': 'log2'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:21:49,788] Trial 25 finished with value: 0.6072991914170316 and parameters: {'n_estimators': 300, 'max_depth': 14, 'max_features': 'log2'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:21:54,965] Trial 26 finished with value: 0.6118893404428555 and parameters: {'n_estimators': 280, 'max_depth': 13, 'max_features': 'log2'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:22:02,645] Trial 27 finished with value: 0.6123945365378545 and parameters: {'n_estimators': 270, 'max_depth': 13, 'max_features': 'log2'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:22:16,050] Trial 29 finished with value: 0.6099030541277298 and parameters: {'n_estimators': 380, 'max_depth': 12, 'max_features': 'log2'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:22:16,261] Trial 28 finished with value: 0.6129260544691624 and parameters: {'n_estimators': 380, 'max_depth': 14, 'max_features': 'log2'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:22:20,477] Trial 30 finished with value: 0.6135114084254333 and parameters: {'n_estimators': 380, 'max_depth': 12, 'max_features': 'log2'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:22:28,780] Trial 31 finished with value: 0.6005257822006282 and parameters: {'n_estimators': 390, 'max_depth': 9, 'max_features': 'sqrt'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:22:44,752] Trial 33 finished with value: 0.6013243255714141 and parameters: {'n_estimators': 430, 'max_depth': 9, 'max_features': 'sqrt'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:22:44,811] Trial 32 finished with value: 0.602061417088154 and parameters: {'n_estimators': 420, 'max_depth': 10, 'max_features': 'sqrt'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:22:45,884] Trial 34 finished with value: 0.6020906526846146 and parameters: {'n_estimators': 430, 'max_depth': 10, 'max_features': 'log2'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:22:58,885] Trial 35 finished with value: 0.6119549647444572 and parameters: {'n_estimators': 430, 'max_depth': 12, 'max_features': 'log2'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:22:59,601] Trial 38 finished with value: 0.6023920855996364 and parameters: {'n_estimators': 180, 'max_depth': 12, 'max_features': 'log2'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:23:14,647] Trial 39 finished with value: 0.610331151154036 and parameters: {'n_estimators': 210, 'max_depth': 12, 'max_features': 'log2'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:23:17,190] Trial 36 finished with value: 0.609219317095028 and parameters: {'n_estimators': 440, 'max_depth': 12, 'max_features': 'log2'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:23:18,109] Trial 37 finished with value: 0.6087898882571148 and parameters: {'n_estimators': 450, 'max_depth': 12, 'max_features': 'log2'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:23:26,611] Trial 40 finished with value: 0.6136084375846119 and parameters: {'n_estimators': 360, 'max_depth': 14, 'max_features': 'log2'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:23:41,241] Trial 41 finished with value: 0.612244791766621 and parameters: {'n_estimators': 360, 'max_depth': 14, 'max_features': 'log2'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:23:47,268] Trial 42 finished with value: 0.6075962058335321 and parameters: {'n_estimators': 350, 'max_depth': 14, 'max_features': 'sqrt'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:23:47,898] Trial 43 finished with value: 0.6127475134992849 and parameters: {'n_estimators': 350, 'max_depth': 14, 'max_features': 'sqrt'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:23:52,278] Trial 44 finished with value: 0.6074739963680924 and parameters: {'n_estimators': 350, 'max_depth': 14, 'max_features': 'log2'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:23:54,216] Trial 47 finished with value: 0.5981447394914341 and parameters: {'n_estimators': 70, 'max_depth': 15, 'max_features': 'log2'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:24:06,346] Trial 46 finished with value: 0.6100118888911092 and parameters: {'n_estimators': 240, 'max_depth': 15, 'max_features': 'log2'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:24:08,183] Trial 45 finished with value: 0.6121126365080213 and parameters: {'n_estimators': 350, 'max_depth': 14, 'max_features': 'log2'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:24:11,402] Trial 48 finished with value: 0.6096081984653707 and parameters: {'n_estimators': 240, 'max_depth': 15, 'max_features': 'log2'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:24:15,256] Trial 49 finished with value: 0.6051558419191093 and parameters: {'n_estimators': 280, 'max_depth': 13, 'max_features': 'log2'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:24:21,889] Trial 51 finished with value: 0.5076263767239605 and parameters: {'n_estimators': 290, 'max_depth': 4, 'max_features': 'sqrt'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:24:34,805] Trial 53 finished with value: 0.5429598690032428 and parameters: {'n_estimators': 410, 'max_depth': 5, 'max_features': 'sqrt'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:24:41,791] Trial 50 finished with value: 0.6112494224112888 and parameters: {'n_estimators': 400, 'max_depth': 13, 'max_features': 'sqrt'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:24:50,136] Trial 52 finished with value: 0.6088276216387462 and parameters: {'n_estimators': 460, 'max_depth': 13, 'max_features': 'sqrt'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:24:50,427] Trial 54 finished with value: 0.6134787832986743 and parameters: {'n_estimators': 400, 'max_depth': 13, 'max_features': 'log2'}. Best is trial 24 with value: 0.6136762708388165.
# [I 2021-11-25 20:25:04,014] Trial 55 finished with value: 0.6141839441959828 and parameters: {'n_estimators': 390, 'max_depth': 13, 'max_features': 'log2'}. Best is trial 55 with value: 0.6141839441959828.
# [I 2021-11-25 20:25:04,995] Trial 58 finished with value: 0.4231450829316331 and parameters: {'n_estimators': 470, 'max_depth': 2, 'max_features': 'log2'}. Best is trial 55 with value: 0.6141839441959828.
# [I 2021-11-25 20:25:13,230] Trial 56 finished with value: 0.6138869455246307 and parameters: {'n_estimators': 380, 'max_depth': 15, 'max_features': 'log2'}. Best is trial 55 with value: 0.6141839441959828.
# [I 2021-11-25 20:25:15,482] Trial 59 finished with value: 0.4233745748296024 and parameters: {'n_estimators': 370, 'max_depth': 2, 'max_features': 'log2'}. Best is trial 55 with value: 0.6141839441959828.
# [I 2021-11-25 20:25:22,283] Trial 57 finished with value: 0.6150701826025745 and parameters: {'n_estimators': 380, 'max_depth': 15, 'max_features': 'log2'}. Best is trial 57 with value: 0.6150701826025745.
# [I 2021-11-25 20:25:29,900] Trial 60 finished with value: 0.6040847392302301 and parameters: {'n_estimators': 370, 'max_depth': 11, 'max_features': 'log2'}. Best is trial 57 with value: 0.6150701826025745.
# [I 2021-11-25 20:25:34,784] Trial 62 finished with value: 0.5814625235298626 and parameters: {'n_estimators': 400, 'max_depth': 7, 'max_features': 'log2'}. Best is trial 57 with value: 0.6150701826025745.
# [I 2021-11-25 20:25:42,031] Trial 61 finished with value: 0.6062197850594969 and parameters: {'n_estimators': 370, 'max_depth': 15, 'max_features': 'log2'}. Best is trial 57 with value: 0.6150701826025745.
# [I 2021-11-25 20:25:47,700] Trial 63 finished with value: 0.608325823017843 and parameters: {'n_estimators': 330, 'max_depth': 15, 'max_features': 'log2'}. Best is trial 57 with value: 0.6150701826025745.
# [I 2021-11-25 20:25:59,114] Trial 65 finished with value: 0.6059689347995134 and parameters: {'n_estimators': 320, 'max_depth': 15, 'max_features': 'log2'}. Best is trial 57 with value: 0.6150701826025745.
# [I 2021-11-25 20:26:00,544] Trial 64 finished with value: 0.6092551360692054 and parameters: {'n_estimators': 400, 'max_depth': 15, 'max_features': 'log2'}. Best is trial 57 with value: 0.6150701826025745.
# [I 2021-11-25 20:26:07,519] Trial 66 finished with value: 0.6150650254272781 and parameters: {'n_estimators': 330, 'max_depth': 14, 'max_features': 'log2'}. Best is trial 57 with value: 0.6150701826025745.
# [I 2021-11-25 20:26:14,332] Trial 67 finished with value: 0.6134692713275092 and parameters: {'n_estimators': 390, 'max_depth': 13, 'max_features': 'log2'}. Best is trial 57 with value: 0.6150701826025745.
# [I 2021-11-25 20:26:23,075] Trial 68 finished with value: 0.6116416007229766 and parameters: {'n_estimators': 400, 'max_depth': 14, 'max_features': 'log2'}. Best is trial 57 with value: 0.6150701826025745.
# [I 2021-11-25 20:26:23,358] Trial 69 finished with value: 0.6119348194631165 and parameters: {'n_estimators': 390, 'max_depth': 14, 'max_features': 'log2'}. Best is trial 57 with value: 0.6150701826025745.

# %%
rf_study.best_params
# Out:
# {'n_estimators': 380, 'max_depth': 15, 'max_features': 'log2'}

# %%
rf_study.best_value
# Out:
# 0.6150701826025745

# %%
rf = RandomForestClassifier(**rf_study.best_params)
rf.fit(X_trainval, y_trainval)
rf_pred = rf.predict(X_holdout)

f1_score(y_holdout, rf_pred, average='weighted') # 29278.242137076086 if outliers are not removed
# 23178.36998786975 at 40 trials
# 23220.71876838312 at 70 trials
# Out:
# 0.5782498516756449

# %% [markdown]
# Looping Models

# %%
def automl(X, y, n_trials):
    rf_study, rf_optimize = tune_RF(X, y, n_trials)

# %%
y_holdout_plot = y_holdout.reset_index().drop(columns='index', axis=0)


fig, ax = plt.subplots(figsize=(15,7))
plt.scatter(y_holdout_plot.index, np.exp(y_holdout_plot), label='actual')
plt.scatter(y_holdout_plot.index, np.exp(rf_pred), label='preds')
plt.legend()
# plt.ylim(0, 400000)

# %%
fig, ax = plt.subplots(figsize=(15,7))
plt.scatter(range(len(rf_pred)), np.exp(y_holdout) - np.exp(rf_pred))

# %%
np.exp(y_holdout) - np.exp(rf_pred)
# Out:
# index
# 71995    -6106.631191
# 33937      745.881019
# 22596    24317.298852
# 40292    -1913.289220
# 22987     5910.995477
#              ...
# 4427     55657.555511
# 32644    -7538.920480
# 40778    -9285.612326
# 54255     8987.431989
# 75879    -7925.975785
# Name: ConvertedCompYearly, Length: 1272, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(20,20))
plt.barh(X.columns[rf.feature_importances_.argsort()], rf.feature_importances_[rf.feature_importances_.argsort()])
plt.autoscale()
plt.savefig('rf_feat_imp')

# %%
rf.feature_importances_
# Out:
# array([8.93522555e-05, 3.30505314e-04, 3.51356259e-04, 7.79032532e-04,
#        1.30134262e-05, 9.12848372e-04, 7.05293809e-03, 1.06776108e-03,
#        7.30520411e-04, 2.62686281e-03, 1.67441858e-02, 6.21438429e-03,
#        3.21320205e-04, 1.59801511e-02, 4.76014856e-04, 1.34976701e-04,
#        2.38589719e-04, 1.37917068e-05, 1.15943626e-04, 1.82042817e-03,
#        1.71602335e-03, 7.68549942e-05, 2.17655774e-04, 5.92601722e-04,
#        3.38539005e-03, 2.59890384e-04, 9.49682905e-03, 1.78412687e-04,
#        1.83344526e-03, 2.61358884e-04, 6.16552352e-03, 6.89549281e-03,
#        1.62329704e-03, 7.97149335e-03, 5.36905929e-03, 2.75321418e-03,
#        2.99819621e-04, 2.16445391e-03, 8.89460542e-06, 2.06033695e-03,
#        5.11644909e-03, 0.00000000e+00, 1.57179504e-03, 5.14426858e-04,
#        1.87016241e-03, 1.45066361e-02, 1.12939501e-02, 9.61071957e-03,
#        8.00560043e-03, 1.10871148e-02, 1.57983768e-02, 6.92693882e-03,
#        1.33849764e-02, 2.18323855e-02, 1.21055782e-02, 5.95300010e-03,
#        6.27057387e-03, 6.61967211e-03, 1.13095134e-02, 6.50859724e-03,
#        1.17260358e-02, 1.20550107e-02, 9.74610608e-03, 5.81056480e-03,
#        6.26871038e-03, 3.44653267e-02, 8.56443228e-03, 6.22434917e-03,
#        8.15417774e-03, 1.12031899e-02, 8.41495837e-03, 7.58411761e-03,
#        8.62370774e-03, 1.41340051e-02, 1.13886953e-02, 1.06992926e-02,
#        1.10647572e-02, 1.88001911e-02, 1.24444600e-02, 1.15482448e-02,
#        1.07034721e-02, 5.78073442e-03, 1.74092582e-03, 9.10147415e-03,
#        3.19650506e-02, 5.93146714e-04, 1.65016182e-02, 1.76883300e-03,
#        4.87508618e-02, 1.41645467e-02, 9.76507149e-03, 1.17270035e-02,
#        1.72446712e-02, 3.62535195e-03, 1.00670673e-02, 6.25457665e-03,
#        2.58378134e-02, 1.20397134e-01, 1.45459823e-01])
