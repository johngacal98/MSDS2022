# %%
import requests
from bs4 import BeautifulSoup as BS

# %%
page = requests.get('https://msds.datascience.aim.edu/')

# %%
page.status_code
# Out:
# 200

# %%
page.content #use when data is not actually text (images, videos)
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n    <head>\n      <meta http-equiv="content-type" content="text/html; charset=UTF-8">\n      <meta charset="utf-8">\n      <meta name="viewport" content="width=device-width, initial-scale=1.0">\n      <title>Master of Science in Data Science, Asian Institute of Management</title>\n      <meta name="description" content="AIM\'s Master of Science in Data Science (MSDS) program is a 14-month intensive course designed to produce experts in the fastest-growing, most sought-after specialization worldwide."/>\n      <meta name="keywords" content="msds,ds,data science,philippines,asia,ph,machine learning,aim,analytics,complex system,data mining"/>\n      <meta name="robots" content="index,follow">\n      <link rel="stylesheet" id="customstyle-css" href="css/aim.css" type="text/css" media="all">\n      <link rel="stylesheet" href="css/tiny-slider.css" type="text/css" media="all">\n\n      <!--[if IE 7]>\n      <!--<link rel=\'stylesheet\' id=\'fontawesome-ie
# ...

# %%
page.text
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n    <head>\n      <meta http-equiv="content-type" content="text/html; charset=UTF-8">\n      <meta charset="utf-8">\n      <meta name="viewport" content="width=device-width, initial-scale=1.0">\n      <title>Master of Science in Data Science, Asian Institute of Management</title>\n      <meta name="description" content="AIM\'s Master of Science in Data Science (MSDS) program is a 14-month intensive course designed to produce experts in the fastest-growing, most sought-after specialization worldwide."/>\n      <meta name="keywords" content="msds,ds,data science,philippines,asia,ph,machine learning,aim,analytics,complex system,data mining"/>\n      <meta name="robots" content="index,follow">\n      <link rel="stylesheet" id="customstyle-css" href="css/aim.css" type="text/css" media="all">\n      <link rel="stylesheet" href="css/tiny-slider.css" type="text/css" media="all">\n\n      <!--[if IE 7]>\n      <!--<link rel=\'stylesheet\' id=\'fontawesome-ie-
# ...

# %%
with open('sample.html', 'w', encoding='utf-8') as f:
    f.write(page.text)

# %%
#prof chris's image
with open('chris.jpeg', 'wb') as f:
    f.write(requests.get('https://msds.datascience.aim.edu/img/profile/chris.jpeg').content)

# %% [markdown]
# Beautiful soup

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
soup = BS(html_doc)
soup
# Out:
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html>

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
soup.p #give first p tag
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
soup.a #return first a tag
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.p.name
# Out:
# 'p'

# %%
soup.p.string
# Out:
# "The Dormouse's story"

# %%
soup.p['class']
# Out:
# ['title']

# %%
soup.find_all('p')[1]
# Out:
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>

# %%
soup.find('p', class_='story')
# Out:
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>

# %%
soup.find('p', class_='story').find_all('a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
for i in soup.find_all('p'):
    print(list(i.children))
    print()
# Out:
# [<b>The Dormouse's story</b>]
#
# ['Once upon a time there were three little sisters; and their names were\n', <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, ',\n', <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, ' and\n', <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>, ';\nand they lived at the bottom of a well.']
#
# ['...']

# %%
soup.select('p')
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>,
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <p class="story">...</p>]

# %%
#returns a's that are descendants of p
#u can chain lots of tags ie 'p a b' 
soup.select('p a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %% [markdown]
# CSS - Cascading style sheet
#
# ex.
#
# p { font-color: red};<br><br>
# p.story {font-weight: bold}

# %%
#.select passes css selectors
# use . for classes, # for ids
soup.select('.story')
# Out:
# [<p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <p class="story">...</p>]

# %%
soup.find_all('p', attrs={'class':'story'})
# Out:
# [<p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <p class="story">...</p>]

# %%
soup.find_all('a', attrs={'class':'sister', 'id':'link1'})
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>]

# %%
soup.find_all('a', attrs={'class':'sister', 'id':'link1'})[0]['href']
# Out:
# 'http://example.com/elsie'

# %%
soup.find_all('p', class_='story')
# Out:
# [<p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <p class="story">...</p>]

# %%
soup.select('#link1')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>]

# %%
soup.select_one('#link1')
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.select_one('#link1').string
# Out:
# 'Elsie'

# %%
soup.select_one('#link1')['class']
# Out:
# ['sister']

# %%
soup.select_one('.sister')
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.select('p>a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.select('p.story>a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.select('a~a') #returns 2nd and 3rd a
# Out:
# [<a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.select('a:nth-child(3), a:nth-child(2)')
# Out:
# [<a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.select('a#link2 ~a')
# Out:
# [<a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.select('p > a, a > b') # p>a or a>b
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.select('p > a, b') # a or b whos parent is p
# Out:
# [<b>The Dormouse's story</b>,
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.select('a[href]')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.select('a[href="http://example.com/tillie"]')
# Out:
# [<a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.select('a[href^="http://example.com"]') #starts with
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.select('a[href$="lacie"]') #ends with
# Out:
# [<a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>]

# %%
soup.select('a[href*="example"]') #contains 'example'
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
import re

# %%
#all elements with class that start with s
soup.find_all(class_=re.compile(r'^s'))
# Out:
# [<p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>,
#  <p class="story">...</p>]

# %% [markdown]
# scraping msds website

# %%
ds_soup = BS(page.text, 'html.parser')

# %%
for div in ds_soup.find_all('div', class_='course-list'):
    print([i.text for i in div.find_all('h3')],'\n\n')
# Out:
# ['Programming for Data Science', 'Mathematics for Data Science', 'Intro to Data Science and the Fundamentals of Data Privacy', 'Data Viz and Storytelling', 'Design Thinking', 'Human Behavior in Organizations']
#
#
# ['Applied Computational Statistics', 'Data Mining and Wrangling', 'Machine Learning', 'Managerial Accounting', 'Digital Marketing and Analytics I', 'Economics for Business', 'Econometrics']
#
#
# ['Big Data & Cloud Computing', 'Deep Learning', 'Managing for Sustainable Development Impact']
#
#
# ['Network Science', 'Data Engineering', 'Strategic Management']

# %%
[elem.text for elem in ds_soup.select('.course-list h3')]
# Out:
# ['Programming for Data Science',
#  'Mathematics for Data Science',
#  'Intro to Data Science and the Fundamentals of Data Privacy',
#  'Data Viz and Storytelling',
#  'Design Thinking',
#  'Human Behavior in Organizations',
#  'Applied Computational Statistics',
#  'Data Mining and Wrangling',
#  'Machine Learning',
#  'Managerial Accounting',
#  'Digital Marketing and Analytics I',
#  'Economics for Business',
#  'Econometrics',
#  'Big Data & Cloud Computing',
#  'Deep Learning',
#  'Managing for Sustainable Development Impact',
#  'Network Science',
#  'Data Engineering',
#  'Strategic Management']

# %% [markdown]
# ## choosing user agents

# %%
requests.get('https://customs.gov.ph', headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246'})
# Out:
# <Response [200]>

# %%
cus = requests.get('https://customs.gov.ph',
             headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'
                      ' AppleWebKit/537.36 (KHTML, like Gecko) '
                      'Chrome/42.0.2311.135 Safari/537.36 Edge/12.246'},
            params={'s':'drugs'}
            )

# %%
customs_soup = BS(cus.text)

# %%
print(customs_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    drugs | Search Results  | Bureau of Customs
#   </title>
#   <link href="http://gmpg.org/xfn/11" rel="profile"/>
#   <link href="https://customs.gov.ph/wp-content/themes/gwt-wordpress-25.3.2-new/favicon.ico" rel="icon"/>
#   <link href="https://fonts.googleapis.com/css?family=Merriweather|Nunito" rel="stylesheet"/>
#   <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.7.1/css/all.css" integrity="sha384-fnmOCqbTlWIlj8LyTjo7mOUStjsKC4pOpQbqyi7RrhN7udi9RwhKkMHpvLbHG9Sr" rel="stylesheet"/>
#   <meta content="noindex, follow, max-image-preview:large" name="robots"/>
#   <link href="//s.w.org" rel="dns-prefetch"/>
#   <link href="https://customs.gov.ph/feed/" rel="alternate" title="Bureau of Customs » Feed" type="application/rss+xml"/>
# ...

# %%
[entry.string for entry in customs_soup.select('h2.entry-title')]
# Out:
# ['BOC NAIA, PDEA, NAIA-IADITG Nab Claimant of Php3.11M Worth of Ketamine “Party Drugs” Concealed in Coffee Sachets',
#  'BOC, PDEA, NAIA-IADITG seizes Php15.7 million worth of “party drugs” and arrests two claimants',
#  'BOC NAIA intercepts 20,000 tablets of undeclared IVERMECTIN and other regulated drugs',
#  'BOC NAIA, PDEA ,NAIA-IADITG intercept Php4.9 million worth of “party ECSTASY drugs”, apprehend claimant',
#  'BOC NAIA, PDEA , NAIA IATG  intercepts Php839,800 worth of ECSTACY party drugs, nabs 2 claimants in Davao city',
#  'BOC Port of Surigao and PDEA RO XIII team-up to fight Illegal Drugs in CARAGA']
